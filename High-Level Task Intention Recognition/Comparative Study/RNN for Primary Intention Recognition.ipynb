# %%
import pandas as pd

import torch
import torch.nn as nn
import torch.nn.functional as F

from sklearn.preprocessing import OneHotEncoder

# %% [markdown]
# ## 1. 读取结构化数据集

# %%
df = pd.read_csv(f'../Dataset/Final_Dataset_2.csv')
df = df.drop(columns=['Time', 'Secondary Intent'])
df.head()
# Out:
#    User  ID  Hotas_Axis_X  Hotas_Axis_Y  Hotas_Axis_Z  Hotas_Btn_Create_Fleet  \
# 0     1   1           0.0           0.0     -0.307087                   False
# 1     1   1           0.0           0.0     -0.307087                   False
# 2     1   1           0.0           0.0     -0.307087                   False
# 3     1   1           0.0           0.0     -0.307087                   False
# 4     1   1           0.0           0.0     -0.307087                   False
#
#    Hotas_Btn_Select_UAV1  Hotas_Btn_Select_UAV2  Hotas_Btn_Select_UAV3  \
# 0                  False                  False                  False
# 1                  False                  False                  False
# 2                  False                  False                  False
# 3                  False                  False                  False
# 4                  False                  False                  False
#
#    Hotas_Btn_Select_UAV4  ...  Target_Area_State  Target_Area_Pos_X  \
# 0                  False  ...              False               -1.0
# 1                  False  ...              False               -1.0
# 2                  False  ...              False               -1.0
# 3                  False  ...              False               -1.0
# 4                  False  ...              False               -1.0
#
#    Target_Area_Pos_Y  Trapped_People_State  Trapped_People_Pos_X  \
# 0               -1.0                 False                  -1.0
# 1               -1.0                 False                  -1.0
# 2               -1.0                 False                  -1.0
# 3               -1.0                 False                  -1.0
# 4               -1.0                 False                  -1.0
#
#    Trapped_People_Pos_Y  Gaze point X  Gaze point Y  AOI  Primary Intent
# 0                  -1.0        2067.0        1195.0    4        Intent_0
# 1                  -1.0        2046.0        1204.0    4        Intent_0
# 2                  -1.0        2046.0        1200.0    4        Intent_0
# 3                  -1.0        2053.0        1221.0    4        Intent_0
# 4                  -1.0        2068.0        1209.0    4        Intent_0
#
# [5 rows x 55 columns]

# %%
df['New Intent'] = None
for index, row in df.iterrows():
    if row['Primary Intent'] == 'Intent_0':
        df.at[index, 'New Intent'] = '00'
    if row['Primary Intent'] == 'Intent_1':
        df.at[index, 'New Intent'] = '01'
    if row['Primary Intent'] == 'Intent_2':
        df.at[index, 'New Intent'] = '02'
    if row['Primary Intent'] == 'Intent_3':
        df.at[index, 'New Intent'] = '03'
    if row['Primary Intent'] == 'Intent_4':
        df.at[index, 'New Intent'] = '04'
    if row['Primary Intent'] == 'Intent_5':
        df.at[index, 'New Intent'] = '05'
   

df.drop(columns=['Primary Intent'], inplace=True)
df.rename(columns={'New Intent': 'Intent'}, inplace=True)
df.head()
# Out:
#    User  ID  Hotas_Axis_X  Hotas_Axis_Y  Hotas_Axis_Z  Hotas_Btn_Create_Fleet  \
# 0     1   1           0.0           0.0     -0.307087                   False
# 1     1   1           0.0           0.0     -0.307087                   False
# 2     1   1           0.0           0.0     -0.307087                   False
# 3     1   1           0.0           0.0     -0.307087                   False
# 4     1   1           0.0           0.0     -0.307087                   False
#
#    Hotas_Btn_Select_UAV1  Hotas_Btn_Select_UAV2  Hotas_Btn_Select_UAV3  \
# 0                  False                  False                  False
# 1                  False                  False                  False
# 2                  False                  False                  False
# 3                  False                  False                  False
# 4                  False                  False                  False
#
#    Hotas_Btn_Select_UAV4  ...  Target_Area_State  Target_Area_Pos_X  \
# 0                  False  ...              False               -1.0
# 1                  False  ...              False               -1.0
# 2                  False  ...              False               -1.0
# 3                  False  ...              False               -1.0
# 4                  False  ...              False               -1.0
#
#    Target_Area_Pos_Y  Trapped_People_State  Trapped_People_Pos_X  \
# 0               -1.0                 False                  -1.0
# 1               -1.0                 False                  -1.0
# 2               -1.0                 False                  -1.0
# 3               -1.0                 False                  -1.0
# 4               -1.0                 False                  -1.0
#
#    Trapped_People_Pos_Y  Gaze point X  Gaze point Y  AOI  Intent
# 0                  -1.0        2067.0        1195.0    4      00
# 1                  -1.0        2046.0        1204.0    4      00
# 2                  -1.0        2046.0        1200.0    4      00
# 3                  -1.0        2053.0        1221.0    4      00
# 4                  -1.0        2068.0        1209.0    4      00
#
# [5 rows x 55 columns]

# %%
# 离散特征变量使用One-Hot编码，通过DataFrame实现
df = pd.get_dummies(df, columns=['Flight_Fleet_State', 'Flight_Fly_Mode', 'UAV_Selected_Now', 'UAV1_Task_State', 'UAV2_Task_State',
                                 'UAV3_Task_State', 'UAV4_Task_State', 'AOI', 'Intent'])
df.head()
# Out:
#    User  ID  Hotas_Axis_X  Hotas_Axis_Y  Hotas_Axis_Z  Hotas_Btn_Create_Fleet  \
# 0     1   1           0.0           0.0     -0.307087                   False
# 1     1   1           0.0           0.0     -0.307087                   False
# 2     1   1           0.0           0.0     -0.307087                   False
# 3     1   1           0.0           0.0     -0.307087                   False
# 4     1   1           0.0           0.0     -0.307087                   False
#
#    Hotas_Btn_Select_UAV1  Hotas_Btn_Select_UAV2  Hotas_Btn_Select_UAV3  \
# 0                  False                  False                  False
# 1                  False                  False                  False
# 2                  False                  False                  False
# 3                  False                  False                  False
# 4                  False                  False                  False
#
#    Hotas_Btn_Select_UAV4  ...  AOI_3  AOI_4  AOI_5  AOI_6  Intent_00  \
# 0                  False  ...  False   True  False  False       True
# 1                  False  ...  False   True  False  False       True
# 2                  False  ...  False   True  False  False       True
# 3                  False  ...  False   True  False  False       True
# 4                  False  ...  False   True  False  False       True
#
#    Intent_01  Intent_02  Intent_03  Intent_04  Intent_05
# 0      False      False      False      False      False
# 1      False      False      False      False      False
# 2      False      False      False      False      False
# 3      False      False      False      False      False
# 4      False      False      False      False      False
#
# [5 rows x 85 columns]

# %%
# 设置训练集和测试集
train_ids = [i for i in range(1, 51) if i % 5 != 0]
test_ids = [i for i in range(1, 51) if i % 5 == 0]
print("train IDs:", train_ids)
print("test IDs:", test_ids)

df_train = df[df['ID'].isin(train_ids)]
df_test = df[df['ID'].isin(test_ids)]
print(df_train.shape, df_test.shape)
# Out:
# train IDs: [1, 2, 3, 4, 6, 7, 8, 9, 11, 12, 13, 14, 16, 17, 18, 19, 21, 22, 23, 24, 26, 27, 28, 29, 31, 32, 33, 34, 36, 37, 38, 39, 41, 42, 43, 44, 46, 47, 48, 49]
# test IDs: [5, 10, 15, 20, 25, 30, 35, 40, 45, 50]
# (941603, 85) (233086, 85)

# %%
# 数据归一化-训练集
df_train.loc[:, 'Hotas_Axis_X']  = (df_train['Hotas_Axis_X']+1)/2
df_train.loc[:, 'Hotas_Axis_Y']  = (df_train['Hotas_Axis_Y']+1)/2
df_train.loc[:, 'Hotas_Axis_Z']  = (df_train['Hotas_Axis_Z']+1)/2

df_train.loc[:, 'Flight_Pos_X']  = (df_train['Flight_Pos_X']-df_train['Flight_Pos_X'].min())/(df_train['Flight_Pos_X'].max()-df_train['Flight_Pos_X'].min())
df_train.loc[:, 'Flight_Pos_Y']  = (df_train['Flight_Pos_Y']-df_train['Flight_Pos_Y'].min())/(df_train['Flight_Pos_Y'].max()-df_train['Flight_Pos_Y'].min())
df_train.loc[:, 'Flight_Speed']  = (df_train['Flight_Speed']-df_train['Flight_Speed'].min())/(df_train['Flight_Speed'].max()-df_train['Flight_Speed'].min())
df_train.loc[:, 'Flight_Height']  = (df_train['Flight_Height']-df_train['Flight_Height'].min())/(df_train['Flight_Height'].max()-df_train['Flight_Height'].min())
df_train.loc[:, 'Flight_Heading']  = (df_train['Flight_Heading']-df_train['Flight_Heading'].min())/(df_train['Flight_Heading'].max()-df_train['Flight_Heading'].min())

df_train.loc[:, 'UAV1_Pos_X']  = df_train['UAV1_Pos_X']/3840
df_train.loc[:, 'UAV1_Pos_Y']  = df_train['UAV1_Pos_Y']/2160
df_train.loc[:, 'UAV2_Pos_X']  = df_train['UAV2_Pos_X']/3840
df_train.loc[:, 'UAV2_Pos_Y']  = df_train['UAV2_Pos_Y']/2160
df_train.loc[:, 'UAV3_Pos_X']  = df_train['UAV3_Pos_X']/3840
df_train.loc[:, 'UAV3_Pos_Y']  = df_train['UAV3_Pos_Y']/2160
df_train.loc[:, 'UAV4_Pos_X']  = df_train['UAV4_Pos_X']/3840
df_train.loc[:, 'UAV4_Pos_Y']  = df_train['UAV4_Pos_Y']/2160

df_train.loc[:, 'Target_Area_Pos_X']  = (df_train['Target_Area_Pos_X']-df_train['Target_Area_Pos_X'].min())/(df_train['Target_Area_Pos_X'].max()-df_train['Target_Area_Pos_X'].min())
df_train.loc[:, 'Target_Area_Pos_Y']  = (df_train['Target_Area_Pos_Y']-df_train['Target_Area_Pos_Y'].min())/(df_train['Target_Area_Pos_Y'].max()-df_train['Target_Area_Pos_Y'].min())
df_train.loc[:, 'Trapped_People_Pos_X']  = (df_train['Trapped_People_Pos_X']-df_train['Trapped_People_Pos_X'].min())/(df_train['Trapped_People_Pos_X'].max()-df_train['Trapped_People_Pos_X'].min())
df_train.loc[:, 'Trapped_People_Pos_Y']  = (df_train['Trapped_People_Pos_Y']-df_train['Trapped_People_Pos_Y'].min())/(df_train['Trapped_People_Pos_Y'].max()-df_train['Trapped_People_Pos_Y'].min())

df_train.loc[:, 'Gaze point X']  = df_train['Gaze point X']/3840
df_train.loc[:, 'Gaze point Y']  = df_train['Gaze point Y']/2160

# 数据归一化-测试集
df_test.loc[:, 'Hotas_Axis_X']  = (df_test['Hotas_Axis_X']+1)/2
df_test.loc[:, 'Hotas_Axis_Y']  = (df_test['Hotas_Axis_Y']+1)/2
df_test.loc[:, 'Hotas_Axis_Z']  = (df_test['Hotas_Axis_Z']+1)/2

df_test.loc[:, 'Flight_Pos_X']  = (df_test['Flight_Pos_X']-df_test['Flight_Pos_X'].min())/(df_test['Flight_Pos_X'].max()-df_test['Flight_Pos_X'].min())
df_test.loc[:, 'Flight_Pos_Y']  = (df_test['Flight_Pos_Y']-df_train['Flight_Pos_Y'].min())/(df_test['Flight_Pos_Y'].max()-df_test['Flight_Pos_Y'].min())
df_test.loc[:, 'Flight_Speed']  = (df_test['Flight_Speed']-df_train['Flight_Speed'].min())/(df_test['Flight_Speed'].max()-df_test['Flight_Speed'].min())
df_test.loc[:, 'Flight_Height']  = (df_test['Flight_Height']-df_test['Flight_Height'].min())/(df_test['Flight_Height'].max()-df_test['Flight_Height'].min())
df_test.loc[:, 'Flight_Heading']  = (df_test['Flight_Heading']-df_test['Flight_Heading'].min())/(df_test['Flight_Heading'].max()-df_test['Flight_Heading'].min())

df_test.loc[:, 'UAV1_Pos_X']  = df_test['UAV1_Pos_X']/3840
df_test.loc[:, 'UAV1_Pos_Y']  = df_test['UAV1_Pos_Y']/2160
df_test.loc[:, 'UAV2_Pos_X']  = df_test['UAV2_Pos_X']/3840
df_test.loc[:, 'UAV2_Pos_Y']  = df_test['UAV2_Pos_Y']/2160
df_test.loc[:, 'UAV3_Pos_X']  = df_test['UAV3_Pos_X']/3840
df_test.loc[:, 'UAV3_Pos_Y']  = df_test['UAV3_Pos_Y']/2160
df_test.loc[:, 'UAV4_Pos_X']  = df_test['UAV4_Pos_X']/3840
df_test.loc[:, 'UAV4_Pos_Y']  = df_test['UAV4_Pos_Y']/2160

df_test.loc[:, 'Target_Area_Pos_X']  = (df_test['Target_Area_Pos_X']-df_test['Target_Area_Pos_X'].min())/(df_test['Target_Area_Pos_X'].max()-df_test['Target_Area_Pos_X'].min())
df_test.loc[:, 'Target_Area_Pos_Y']  = (df_test['Target_Area_Pos_Y']-df_test['Target_Area_Pos_Y'].min())/(df_test['Target_Area_Pos_Y'].max()-df_test['Target_Area_Pos_Y'].min())
df_test.loc[:, 'Trapped_People_Pos_X']  = (df_test['Trapped_People_Pos_X']-df_test['Trapped_People_Pos_X'].min())/(df_test['Trapped_People_Pos_X'].max()-df_test['Trapped_People_Pos_X'].min())
df_test.loc[:, 'Trapped_People_Pos_Y']  = (df_test['Trapped_People_Pos_Y']-df_test['Trapped_People_Pos_Y'].min())/(df_test['Trapped_People_Pos_Y'].max()-df_test['Trapped_People_Pos_Y'].min())

df_test.loc[:, 'Gaze point X']  = df_test['Gaze point X']/3840
df_test.loc[:, 'Gaze point Y']  = df_test['Gaze point Y']/2160

pd.set_option('display.max_columns', None)
df_train.head()
# Out:
#    User  ID  Hotas_Axis_X  Hotas_Axis_Y  Hotas_Axis_Z  Hotas_Btn_Create_Fleet  \
# 0     1   1           0.5           0.5      0.346457                   False
# 1     1   1           0.5           0.5      0.346457                   False
# 2     1   1           0.5           0.5      0.346457                   False
# 3     1   1           0.5           0.5      0.346457                   False
# 4     1   1           0.5           0.5      0.346457                   False
#
#    Hotas_Btn_Select_UAV1  Hotas_Btn_Select_UAV2  Hotas_Btn_Select_UAV3  \
# 0                  False                  False                  False
# 1                  False                  False                  False
# 2                  False                  False                  False
# 3                  False                  False                  False
# 4                  False                  False                  False
#
#    Hotas_Btn_Select_UAV4  Hotas_Btn_Assign_Up  Hotas_Btn_Assign_Down  \
# 0                  False                False                  False
# 1                  False                False                  False
# 2                  False                False                  False
# 3                  False                False                  False
# 4                  False                False                  False
#
#    Hotas_Btn_Assign_Left  Hotas_Btn_Assign_Right  Hotas_Btn_Change_Mode  \
# 0                  False                   False                  False
# 1                  False                   False                  False
# 2                  False                   False                  False
# 3                  False                   False                  False
# 4                  False                   False                  False
#
#    Hotas_Btn_Open_UAV_Sensor  Hotas_Btn_Open_Helicopter_Sensor  \
# 0                      False                             False
# 1                      False                             False
# 2                      False                             False
# 3                      False                             False
# 4                      False                             False
#
#    Hotas_Btn_Select_Normal  Hotas_Btn_Select_Fire  Hotas_Btn_Select_Person  \
# 0                    False                  False                    False
# 1                    False                  False                    False
# 2                    False                  False                    False
# 3                    False                  False                    False
# 4                    False                  False                    False
#
#    Hotas_Btn_Submit_Result  Hotas_Btn_Area_Assign  Flight_Pos_X  Flight_Pos_Y  \
# 0                    False                  False        0.4499      0.127802
# 1                    False                  False        0.4499      0.127802
# 2                    False                  False        0.4499      0.127802
# 3                    False                  False        0.4499      0.127802
# 4                    False                  False        0.4499      0.127802
#
#    Flight_Speed  Flight_Height  Flight_Heading  Flight_Sensor  UAV1_Pos_X  \
# 0           0.0        0.40634        0.000016          False    0.495825
# 1           0.0        0.40634        0.000016          False    0.495825
# 2           0.0        0.40634        0.000016          False    0.495825
# 3           0.0        0.40634        0.000016          False    0.495825
# 4           0.0        0.40634        0.000016          False    0.495825
#
#    UAV1_Pos_Y  UAV2_Pos_X  UAV2_Pos_Y  UAV3_Pos_X  UAV3_Pos_Y  UAV4_Pos_X  \
# 0      0.1839    0.534825      0.1839    0.495825    0.130567    0.534825
# 1      0.1839    0.534825      0.1839    0.495825    0.130567    0.534825
# 2      0.1839    0.534825      0.1839    0.495825    0.130567    0.534825
# 3      0.1839    0.534825      0.1839    0.495825    0.130567    0.534825
# 4      0.1839    0.534825      0.1839    0.495825    0.130567    0.534825
#
#    UAV4_Pos_Y  UAV_Sensor_State  Task_List_State  Target_Area_State  \
# 0    0.130567             False             True              False
# 1    0.130567             False             True              False
# 2    0.130567             False             True              False
# 3    0.130567             False             True              False
# 4    0.130567             False             True              False
#
#    Target_Area_Pos_X  Target_Area_Pos_Y  Trapped_People_State  \
# 0                0.0                0.0                 False
# 1                0.0                0.0                 False
# 2                0.0                0.0                 False
# 3                0.0                0.0                 False
# 4                0.0                0.0                 False
#
#    Trapped_People_Pos_X  Trapped_People_Pos_Y  Gaze point X  Gaze point Y  \
# 0                   0.0                   0.0      0.538281      0.553241
# 1                   0.0                   0.0      0.532813      0.557407
# 2                   0.0                   0.0      0.532813      0.555556
# 3                   0.0                   0.0      0.534635      0.565278
# 4                   0.0                   0.0      0.538542      0.559722
#
#    Flight_Fleet_State_0  Flight_Fleet_State_1  Flight_Fleet_State_2  \
# 0                  True                 False                 False
# 1                  True                 False                 False
# 2                  True                 False                 False
# 3                  True                 False                 False
# 4                  True                 False                 False
#
#    Flight_Fly_Mode_0  Flight_Fly_Mode_1  UAV_Selected_Now_-1.0  \
# 0               True              False                   True
# 1               True              False                   True
# 2               True              False                   True
# 3               True              False                   True
# 4               True              False                   True
#
#    UAV_Selected_Now_1.0  UAV_Selected_Now_2.0  UAV_Selected_Now_3.0  \
# 0                 False                 False                 False
# 1                 False                 False                 False
# 2                 False                 False                 False
# 3                 False                 False                 False
# 4                 False                 False                 False
#
#    UAV_Selected_Now_4.0  UAV1_Task_State_0  UAV1_Task_State_1  \
# 0                 False               True              False
# 1                 False               True              False
# 2                 False               True              False
# 3                 False               True              False
# 4                 False               True              False
#
#    UAV1_Task_State_2  UAV1_Task_State_3  UAV2_Task_State_0  UAV2_Task_State_1  \
# 0              False              False               True              False
# 1              False              False               True              False
# 2              False              False               True              False
# 3              False              False               True              False
# 4              False              False               True              False
#
#    UAV2_Task_State_2  UAV2_Task_State_3  UAV3_Task_State_0  UAV3_Task_State_1  \
# 0              False              False               True              False
# 1              False              False               True              False
# 2              False              False               True              False
# 3              False              False               True              False
# 4              False              False               True              False
#
#    UAV3_Task_State_2  UAV3_Task_State_3  UAV4_Task_State_0  UAV4_Task_State_1  \
# 0              False              False               True              False
# 1              False              False               True              False
# 2              False              False               True              False
# 3              False              False               True              False
# 4              False              False               True              False
#
#    UAV4_Task_State_2  UAV4_Task_State_3  AOI_0  AOI_1  AOI_2  AOI_3  AOI_4  \
# 0              False              False  False  False  False  False   True
# 1              False              False  False  False  False  False   True
# 2              False              False  False  False  False  False   True
# 3              False              False  False  False  False  False   True
# 4              False              False  False  False  False  False   True
#
#    AOI_5  AOI_6  Intent_00  Intent_01  Intent_02  Intent_03  Intent_04  \
# 0  False  False       True      False      False      False      False
# 1  False  False       True      False      False      False      False
# 2  False  False       True      False      False      False      False
# 3  False  False       True      False      False      False      False
# 4  False  False       True      False      False      False      False
#
#    Intent_05
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False

# %% [markdown]
# ## 2. 定义Dataset和DataLoader

# %%
from torch.utils.data import DataLoader, Dataset
import numpy as np

class MyDataset(Dataset):
    # 实例化调用，数据集初始化
    def __init__(self, df, time_step):
        # 初始化输入输出
        x = []
        y = []
        num_intent_0 = 0
        
        # 根据test_id划分DataFrame
        grouped = df.groupby('ID')
        
        for _, group in grouped:
            # test_id放在最后
            origin_data = group.drop(columns=['ID', 'User'])
            # 将表格中的bool型转换为int型
            for column in origin_data.columns:
                if origin_data[column].dtype == bool:
                    origin_data[column] = origin_data[column].astype(int)
            # 将表格数据转换为Numpy
            dataset = (origin_data).to_numpy()
            for i in range(len(dataset) - time_step):
                input_seq = dataset[i:(i+time_step), 0:-6]
                output_seq = dataset[i+time_step-1, -6:]
                
#                 x.append(input_seq)
#                 y.append(output_seq)
                
                if output_seq[0] == 1:
                    num_intent_0 += 1
                else:
                    x.append(input_seq)
                    y.append(output_seq[1:])
        
        x = np.array(x)
        y = np.array(y)
        print(f'shape_input:{x.shape},shape_output:{y.shape}')
        print(f'delete Intent_0:{num_intent_0}')
        
        self.data_tensor = torch.tensor(x, dtype=torch.float32)
        self.label_tensor = torch.tensor(y, dtype=torch.float32)
    
    # 返回数据集的长度    
    def __len__(self):
        return self.data_tensor.shape[0]
    
    # 根据指定下标返回数据集内容    
    def __getitem__(self, i):
        # 读取数据
        data = self.data_tensor[i]
        # 读取标签
        label = self.label_tensor[i]

        return data, label  # 返回数据和标签
  
train_dataset = MyDataset(df_train, 20)
test_dataset = MyDataset(df_test, 20)

# 加载数据集
train_data = DataLoader(train_dataset, batch_size=64, shuffle=False) # shuffle是否打乱
test_data = DataLoader(test_dataset, batch_size=64, shuffle=False)

print(f'输入张量：{train_dataset.data_tensor.shape} 输出张量：{train_dataset.label_tensor.shape}')
# Out:
# shape_input:(827893, 20, 77),shape_output:(827893, 5)
# delete Intent_0:112910
# shape_input:(211997, 20, 77),shape_output:(211997, 5)
# delete Intent_0:20889
# 输入张量：torch.Size([827893, 20, 77]) 输出张量：torch.Size([827893, 5])

# %% [markdown]
# ## 3. 定义LSTM模型

# %% [markdown]
# ### 模型1: RNN模型

# %%
class RNN(nn.Module):
    def __init__(self, input_size=77, hidden_size=128, output_size=5, num_layers=1):
        super().__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.num_layers = num_layers
        
        self.rnn = nn.RNN(self.input_size, self.hidden_size, self.num_layers, batch_first=True)
        self.linear = nn.Linear(self.hidden_size, self.output_size)

    def forward(self, input_seq):
        batch_size, seq_len = input_seq.shape[0], input_seq.shape[1]
        h_0 = torch.randn(self.num_layers, batch_size, self.hidden_size).to(device)
        
        rnn_out, self.hidden_cell = self.rnn(input_seq, h_0)
        predictions = self.linear(rnn_out[:,-1,:])
        return predictions

# %% [markdown]
# ## 4. 实例化模型，定义超参数

# %%
device = 'cuda'
model = RNN().to(device)
# 损失函数
loss_function = nn.CrossEntropyLoss()
# 优化器
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %% [markdown]
# ## 5. 训练模型

# %%
epochs = 100
train_loss_record = []
train_accuracy_record = []
val_loss_record = []
val_accuracy_record = []

for i in range(epochs):
    # 模型训练
    model.train()
    train_loss = 0
    train_accuracy = 0
    
    for seq, labels in train_data:
        optimizer.zero_grad()
        x,y = seq.to(device), labels.to(device)
        y_pred = model(x)
        y_pred = torch.squeeze(y_pred, dim=1) # 去除额外维度
        loss = loss_function(y_pred, y)
        loss.backward()
        optimizer.step()
        
        # 计算训练准确率
        train_loss += loss.item()
        train_correct = torch.eq(y.argmax(dim=1), y_pred.argmax(dim=1))
        train_accuracy += train_correct.sum().item()/ y.shape[0]

    # if i%1 == 1:
    avg_train_loss = train_loss / len(train_data)
    print(f'epoch: {i:3} train_loss: {avg_train_loss:10.8f}')
    train_loss_record.append(avg_train_loss)
    
    avg_train_accuracy = train_accuracy / len(train_data)
    print(f'epoch: {i:3} train_accuracy: {avg_train_accuracy:10.8f}')
    train_accuracy_record.append(avg_train_accuracy)
    

    # 模型验证
    model.eval()
    val_loss = 0
    val_accuracy = 0
    
    with torch.no_grad():
        for seq, labels in test_data:
            x,y = seq.to(device), labels.to(device)
            y_pred = model(x)
            y_pred = torch.squeeze(y_pred, dim=1) # 去除额外维度
            loss = loss_function(y_pred, y)
            val_loss += loss.item()
            val_correct = torch.eq(y.argmax(dim=1), y_pred.argmax(dim=1))
            val_accuracy += val_correct.sum().item()/ y.shape[0]
    
    avg_val_loss = val_loss / len(test_data)
    print(f'epoch: {i:3} val_loss: {avg_val_loss:10.8f}')
    val_loss_record.append(avg_val_loss)
    
    avg_val_accuracy = val_accuracy / len(test_data)
    print(f'epoch: {i:3} val_accuracy: {avg_val_accuracy:10.8f}')
    val_accuracy_record.append(avg_val_accuracy)
# Out:
# epoch:   0 train_loss: 0.53522002
# epoch:   0 train_accuracy: 0.82691471
# epoch:   0 val_loss: 0.89220461
# epoch:   0 val_accuracy: 0.71298672
# epoch:   1 train_loss: 0.36273848
# epoch:   1 train_accuracy: 0.88893736
# epoch:   1 val_loss: 0.77424173
# epoch:   1 val_accuracy: 0.75233455
# epoch:   2 train_loss: 0.30564760
# epoch:   2 train_accuracy: 0.90878049
# epoch:   2 val_loss: 0.46099577
# epoch:   2 val_accuracy: 0.85884678
# epoch:   3 train_loss: 0.27791439
# epoch:   3 train_accuracy: 0.91781897
# epoch:   3 val_loss: 0.37380878
# epoch:   3 val_accuracy: 0.90712251
# epoch:   4 train_loss: 0.25088639
# epoch:   4 train_accuracy: 0.92491521
# epoch:   4 val_loss: 0.31408850
# epoch:   4 val_accuracy: 0.92236549
# epoch:   5 train_loss: 0.23401011
# epoch:   5 train_accuracy: 0.93399597
# epoch:   5 val_loss: 0.75740361
# epoch:   5 val_accuracy: 0.81897072
# epoch:   6 train_loss: 0.22283459
# epoch:   6 train_accuracy: 0.93958961
# epoch:   6 val_loss: 0.25284572
# epoch:   6 val_accuracy: 0.92855324
# epoch:   7 train_loss: 0.21348125
# epoch:   7 train_accuracy: 0.93760025
# epoch:   7 val_loss: 0.34643988
# epoch:   7 val_accuracy: 0.92385112
# epoch:   8 train_loss: 0.26161362
# epoch:   8 train_accuracy: 0.92735752
# epoch:   8 val_loss: 0.60670765
# epoch:   8 val_accuracy: 0.83647280
# epoch:   9 train_loss: 0.25733945
# epoch:   9 train_accuracy: 0.93283762
# epoch:   9 val_loss: 0.48072686
# epoch:   9 val_accuracy: 0.89957648
# epoch:  10 train_loss: 0.23708346
# epoch:  10 train_accuracy: 0.93630904
# epoch:  10 val_loss: 0.23767287
# epoch:  10 val_accuracy: 0.94585251
# epoch:  11 train_loss: 0.21507442
# epoch:  11 train_accuracy: 0.94163091
# epoch:  11 val_loss: 0.21008430
# epoch:  11 val_accuracy: 0.95007829
# epoch:  12 train_loss: 0.20945781
# epoch:  12 train_accuracy: 0.94314075
# epoch:  12 val_loss: 0.22870400
# epoch:  12 val_accuracy: 0.94703630
# epoch:  13 train_loss: 0.22402532
# epoch:  13 train_accuracy: 0.94065979
# epoch:  13 val_loss: 0.20343566
# epoch:  13 val_accuracy: 0.95399751
# epoch:  14 train_loss: 0.20837417
# epoch:  14 train_accuracy: 0.94159226
# epoch:  14 val_loss: 0.18322363
# epoch:  14 val_accuracy: 0.95420031
# epoch:  15 train_loss: 0.19677916
# epoch:  15 train_accuracy: 0.94439573
# epoch:  15 val_loss: 0.27021679
# epoch:  15 val_accuracy: 0.91921502
# epoch:  16 train_loss: 0.23381410
# epoch:  16 train_accuracy: 0.93671005
# epoch:  16 val_loss: 0.22463960
# epoch:  16 val_accuracy: 0.94248981
# epoch:  17 train_loss: 0.24564342
# epoch:  17 train_accuracy: 0.93426412
# epoch:  17 val_loss: 0.30176740
# epoch:  17 val_accuracy: 0.91958761
# epoch:  18 train_loss: 0.22221839
# epoch:  18 train_accuracy: 0.93868975
# epoch:  18 val_loss: 0.23265180
# epoch:  18 val_accuracy: 0.93917428
# epoch:  19 train_loss: 0.26189752
# epoch:  19 train_accuracy: 0.92748193
# epoch:  19 val_loss: 0.53514601
# epoch:  19 val_accuracy: 0.87319839
# epoch:  20 train_loss: 0.24847544
# epoch:  20 train_accuracy: 0.92823081
# epoch:  20 val_loss: 0.50635179
# epoch:  20 val_accuracy: 0.88550313
# epoch:  21 train_loss: 0.27664598
# epoch:  21 train_accuracy: 0.92490434
# epoch:  21 val_loss: 0.29965579
# epoch:  21 val_accuracy: 0.92954365
# epoch:  22 train_loss: 0.26203407
# epoch:  22 train_accuracy: 0.92904974
# epoch:  22 val_loss: 0.66102148
# epoch:  22 val_accuracy: 0.88188575
# epoch:  23 train_loss: 0.26267322
# epoch:  23 train_accuracy: 0.93144495
# epoch:  23 val_loss: 0.46014734
# epoch:  23 val_accuracy: 0.91127754
# epoch:  24 train_loss: 0.24394257
# epoch:  24 train_accuracy: 0.93131812
# epoch:  24 val_loss: 0.32743939
# epoch:  24 val_accuracy: 0.88740379
# epoch:  25 train_loss: 0.23185908
# epoch:  25 train_accuracy: 0.93605539
# epoch:  25 val_loss: 0.63128392
# epoch:  25 val_accuracy: 0.89340288
# epoch:  26 train_loss: 0.24618560
# epoch:  26 train_accuracy: 0.93583918
# epoch:  26 val_loss: 0.22119443
# epoch:  26 val_accuracy: 0.94535730
# epoch:  27 train_loss: 0.22370352
# epoch:  27 train_accuracy: 0.93695887
# epoch:  27 val_loss: 0.31350840
# epoch:  27 val_accuracy: 0.92539805
# epoch:  28 train_loss: 0.25247858
# epoch:  28 train_accuracy: 0.93397906
# epoch:  28 val_loss: 0.58281784
# epoch:  28 val_accuracy: 0.90096778
# epoch:  29 train_loss: 0.24656897
# epoch:  29 train_accuracy: 0.93334131
# epoch:  29 val_loss: 0.28966591
# epoch:  29 val_accuracy: 0.92316254
# epoch:  30 train_loss: 0.23608044
# epoch:  30 train_accuracy: 0.93885281
# epoch:  30 val_loss: 0.31346196
# epoch:  30 val_accuracy: 0.92428030
# epoch:  31 train_loss: 0.23653310
# epoch:  31 train_accuracy: 0.93700598
# epoch:  31 val_loss: 0.39171248
# epoch:  31 val_accuracy: 0.91647487
# epoch:  32 train_loss: 0.24174023
# epoch:  32 train_accuracy: 0.93679098
# epoch:  32 val_loss: 0.59888827
# epoch:  32 val_accuracy: 0.88538994
# epoch:  33 train_loss: 0.23144972
# epoch:  33 train_accuracy: 0.93683446
# epoch:  33 val_loss: 0.74931950
# epoch:  33 val_accuracy: 0.88306954
# epoch:  34 train_loss: 0.22869071
# epoch:  34 train_accuracy: 0.93846267
# epoch:  34 val_loss: 0.50381476
# epoch:  34 val_accuracy: 0.89497340
# epoch:  35 train_loss: 0.22425112
# epoch:  35 train_accuracy: 0.94185437
# epoch:  35 val_loss: 0.32421913
# epoch:  35 val_accuracy: 0.91182463
# epoch:  36 train_loss: 0.21841392
# epoch:  36 train_accuracy: 0.94487525
# epoch:  36 val_loss: 0.38049359
# epoch:  36 val_accuracy: 0.93026524
# epoch:  37 train_loss: 0.21498462
# epoch:  37 train_accuracy: 0.94144490
# epoch:  37 val_loss: 0.26962198
# epoch:  37 val_accuracy: 0.94011753
# epoch:  38 train_loss: 0.22306311
# epoch:  38 train_accuracy: 0.94132170
# epoch:  38 val_loss: 0.52349985
# epoch:  38 val_accuracy: 0.90939104
# epoch:  39 train_loss: 0.21947482
# epoch:  39 train_accuracy: 0.94130720
# epoch:  39 val_loss: 0.21162368
# epoch:  39 val_accuracy: 0.95366737
# epoch:  40 train_loss: 0.23945118
# epoch:  40 train_accuracy: 0.93903279
# epoch:  40 val_loss: 0.27703836
# epoch:  40 val_accuracy: 0.92746378
# epoch:  41 train_loss: 0.21905617
# epoch:  41 train_accuracy: 0.94418435
# epoch:  41 val_loss: 0.30655164
# epoch:  41 val_accuracy: 0.92586968
# epoch:  42 train_loss: 0.21925194
# epoch:  42 train_accuracy: 0.94287260
# epoch:  42 val_loss: 0.27214719
# epoch:  42 val_accuracy: 0.92794012
# epoch:  43 train_loss: 0.24989855
# epoch:  43 train_accuracy: 0.93076371
# epoch:  43 val_loss: 0.36877414
# epoch:  43 val_accuracy: 0.89214364
# epoch:  44 train_loss: 0.23458587
# epoch:  44 train_accuracy: 0.94250903
# epoch:  44 val_loss: 0.25400556
# epoch:  44 val_accuracy: 0.92376151
# epoch:  45 train_loss: 0.21768369
# epoch:  45 train_accuracy: 0.94667739
# epoch:  45 val_loss: 0.38231541
# epoch:  45 val_accuracy: 0.92031863
# epoch:  46 train_loss: 0.19497590
# epoch:  46 train_accuracy: 0.94812321
# epoch:  46 val_loss: 0.35774537
# epoch:  46 val_accuracy: 0.92460100
# epoch:  47 train_loss: 0.19616100
# epoch:  47 train_accuracy: 0.94800726
# epoch:  47 val_loss: 0.17734012
# epoch:  47 val_accuracy: 0.96006263
# epoch:  48 train_loss: 0.20904274
# epoch:  48 train_accuracy: 0.94368308
# epoch:  48 val_loss: 0.24143653
# epoch:  48 val_accuracy: 0.94717778
# epoch:  49 train_loss: 0.19639444
# epoch:  49 train_accuracy: 0.94990240
# epoch:  49 val_loss: 0.29851372
# epoch:  49 val_accuracy: 0.93829705
# epoch:  50 train_loss: 0.19290585
# epoch:  50 train_accuracy: 0.94857616
# epoch:  50 val_loss: 0.27330534
# epoch:  50 val_accuracy: 0.94646563
# epoch:  51 train_loss: 0.22223524
# epoch:  51 train_accuracy: 0.94507455
# epoch:  51 val_loss: 0.30059218
# epoch:  51 val_accuracy: 0.93574555
# epoch:  52 train_loss: 0.20551441
# epoch:  52 train_accuracy: 0.94900858
# epoch:  52 val_loss: 0.40200411
# epoch:  52 val_accuracy: 0.92647808
# epoch:  53 train_loss: 0.20262122
# epoch:  53 train_accuracy: 0.94838774
# epoch:  53 val_loss: 0.35457437
# epoch:  53 val_accuracy: 0.92210610
# epoch:  54 train_loss: 0.18238888
# epoch:  54 train_accuracy: 0.95085904
# epoch:  54 val_loss: 0.17148327
# epoch:  54 val_accuracy: 0.96666069
# epoch:  55 train_loss: 0.19871108
# epoch:  55 train_accuracy: 0.95065128
# epoch:  55 val_loss: 0.19235750
# epoch:  55 val_accuracy: 0.95208270
# epoch:  56 train_loss: 0.18591118
# epoch:  56 train_accuracy: 0.95379778
# epoch:  56 val_loss: 0.15921323
# epoch:  56 val_accuracy: 0.95791201
# epoch:  57 train_loss: 0.19888257
# epoch:  57 train_accuracy: 0.95193646
# epoch:  57 val_loss: 0.26652898
# epoch:  57 val_accuracy: 0.94270204
# epoch:  58 train_loss: 0.18552026
# epoch:  58 train_accuracy: 0.95233264
# epoch:  58 val_loss: 0.27637527
# epoch:  58 val_accuracy: 0.94430558
# epoch:  59 train_loss: 0.19546329
# epoch:  59 train_accuracy: 0.95006909
# epoch:  59 val_loss: 0.22416659
# epoch:  59 val_accuracy: 0.95819499
# epoch:  60 train_loss: 0.19269412
# epoch:  60 train_accuracy: 0.95193766
# epoch:  60 val_loss: 0.30786685
# epoch:  60 val_accuracy: 0.92908146
# epoch:  61 train_loss: 0.18537007
# epoch:  61 train_accuracy: 0.95116946
# epoch:  61 val_loss: 0.22499843
# epoch:  61 val_accuracy: 0.95427577
# epoch:  62 train_loss: 0.21096790
# epoch:  62 train_accuracy: 0.94967170
# epoch:  62 val_loss: 0.26969980
# epoch:  62 val_accuracy: 0.93485417
# epoch:  63 train_loss: 0.22275050
# epoch:  63 train_accuracy: 0.93981911
# epoch:  63 val_loss: 0.31523226
# epoch:  63 val_accuracy: 0.92202592
# epoch:  64 train_loss: 0.21793660
# epoch:  64 train_accuracy: 0.94427977
# epoch:  64 val_loss: 0.53551868
# epoch:  64 val_accuracy: 0.84350004
# epoch:  65 train_loss: 0.22146314
# epoch:  65 train_accuracy: 0.94593214
# epoch:  65 val_loss: 0.17386597
# epoch:  65 val_accuracy: 0.96139262
# epoch:  66 train_loss: 0.23233526
# epoch:  66 train_accuracy: 0.94216117
# epoch:  66 val_loss: 0.21827887
# epoch:  66 val_accuracy: 0.94977173
# epoch:  67 train_loss: 0.28412881
# epoch:  67 train_accuracy: 0.92517490
# epoch:  67 val_loss: 0.20631999
# epoch:  67 val_accuracy: 0.94834270
# epoch:  68 train_loss: 0.33553228
# epoch:  68 train_accuracy: 0.91598784
# epoch:  68 val_loss: 0.54320297
# epoch:  68 val_accuracy: 0.86344514
# epoch:  69 train_loss: 0.36393202
# epoch:  69 train_accuracy: 0.89969127
# epoch:  69 val_loss: 0.30893806
# epoch:  69 val_accuracy: 0.91572498
# epoch:  70 train_loss: 0.32281206
# epoch:  70 train_accuracy: 0.90868144
# epoch:  70 val_loss: 0.20942120
# epoch:  70 val_accuracy: 0.94234832
# epoch:  71 train_loss: 0.30494588
# epoch:  71 train_accuracy: 0.91885895
# epoch:  71 val_loss: 0.32184443
# epoch:  71 val_accuracy: 0.92257301
# epoch:  72 train_loss: 0.28571989
# epoch:  72 train_accuracy: 0.92031177
# epoch:  72 val_loss: 0.37421429
# epoch:  72 val_accuracy: 0.84808897
# epoch:  73 train_loss: 0.26524140
# epoch:  73 train_accuracy: 0.92816317
# epoch:  73 val_loss: 0.32704587
# epoch:  73 val_accuracy: 0.92164390
# epoch:  74 train_loss: 0.30217688
# epoch:  74 train_accuracy: 0.91906308
# epoch:  74 val_loss: 0.24405338
# epoch:  74 val_accuracy: 0.95504924
# epoch:  75 train_loss: 0.23313219
# epoch:  75 train_accuracy: 0.94332193
# epoch:  75 val_loss: 0.18099232
# epoch:  75 val_accuracy: 0.95924672
# epoch:  76 train_loss: 0.29617662
# epoch:  76 train_accuracy: 0.92001609
# epoch:  76 val_loss: 0.60459016
# epoch:  76 val_accuracy: 0.83435991
# epoch:  77 train_loss: 0.25746680
# epoch:  77 train_accuracy: 0.92779356
# epoch:  77 val_loss: 0.35663835
# epoch:  77 val_accuracy: 0.89715703
# epoch:  78 train_loss: 0.23042602
# epoch:  78 train_accuracy: 0.93700477
# epoch:  78 val_loss: 0.23641460
# epoch:  78 val_accuracy: 0.94465458
# epoch:  79 train_loss: 0.21833991
# epoch:  79 train_accuracy: 0.94321322
# epoch:  79 val_loss: 0.24965156
# epoch:  79 val_accuracy: 0.94377735
# epoch:  80 train_loss: 0.23457763
# epoch:  80 train_accuracy: 0.94171546
# epoch:  80 val_loss: 0.20117637
# epoch:  80 val_accuracy: 0.95454460
# epoch:  81 train_loss: 0.22631735
# epoch:  81 train_accuracy: 0.94351519
# epoch:  81 val_loss: 0.28285986
# epoch:  81 val_accuracy: 0.94297087
# epoch:  82 train_loss: 0.22067542
# epoch:  82 train_accuracy: 0.94560239
# epoch:  82 val_loss: 0.27825348
# epoch:  82 val_accuracy: 0.94314066
# epoch:  83 train_loss: 0.30037147
# epoch:  83 train_accuracy: 0.92038087
# epoch:  83 val_loss: 0.17746612
# epoch:  83 val_accuracy: 0.95955327
# epoch:  84 train_loss: 0.24117176
# epoch:  84 train_accuracy: 0.93790343
# epoch:  84 val_loss: 0.24004069
# epoch:  84 val_accuracy: 0.93745755
# epoch:  85 train_loss: 0.23025343
# epoch:  85 train_accuracy: 0.94431601
# epoch:  85 val_loss: 0.28663560
# epoch:  85 val_accuracy: 0.93624547
# epoch:  86 train_loss: 0.21669145
# epoch:  86 train_accuracy: 0.94542000
# epoch:  86 val_loss: 0.28288744
# epoch:  86 val_accuracy: 0.92031863
# epoch:  87 train_loss: 0.22728564
# epoch:  87 train_accuracy: 0.94219861
# epoch:  87 val_loss: 0.21365655
# epoch:  87 val_accuracy: 0.94366416
# epoch:  88 train_loss: 0.22373114
# epoch:  88 train_accuracy: 0.94228679
# epoch:  88 val_loss: 0.21385018
# epoch:  88 val_accuracy: 0.94719193
# epoch:  89 train_loss: 0.19944184
# epoch:  89 train_accuracy: 0.94885035
# epoch:  89 val_loss: 0.34889995
# epoch:  89 val_accuracy: 0.93518903
# epoch:  90 train_loss: 0.20213334
# epoch:  90 train_accuracy: 0.94948207
# epoch:  90 val_loss: 0.20937510
# epoch:  90 val_accuracy: 0.95380414
# epoch:  91 train_loss: 0.19003376
# epoch:  91 train_accuracy: 0.95168280
# epoch:  91 val_loss: 0.24586291
# epoch:  91 val_accuracy: 0.94018827
# epoch:  92 train_loss: 0.20830276
# epoch:  92 train_accuracy: 0.94830198
# epoch:  92 val_loss: 0.22800587
# epoch:  92 val_accuracy: 0.95125736
# epoch:  93 train_loss: 0.25380806
# epoch:  93 train_accuracy: 0.93786115
# epoch:  93 val_loss: 0.22149141
# epoch:  93 val_accuracy: 0.95328535
# epoch:  94 train_loss: 0.37585942
# epoch:  94 train_accuracy: 0.88837353
# epoch:  94 val_loss: 1.12555966
# epoch:  94 val_accuracy: 0.79502151
# epoch:  95 train_loss: 0.38595283
# epoch:  95 train_accuracy: 0.88682867
# epoch:  95 val_loss: 0.34195026
# epoch:  95 val_accuracy: 0.89918974
# epoch:  96 train_loss: 0.32492947
# epoch:  96 train_accuracy: 0.91206468
# epoch:  96 val_loss: 0.49395510
# epoch:  96 val_accuracy: 0.88081988
# epoch:  97 train_loss: 0.31641663
# epoch:  97 train_accuracy: 0.91770181
# epoch:  97 val_loss: 0.30525694
# epoch:  97 val_accuracy: 0.89530826
# epoch:  98 train_loss: 0.32882942
# epoch:  98 train_accuracy: 0.91053552
# epoch:  98 val_loss: 0.38453441
# epoch:  98 val_accuracy: 0.84686745
# epoch:  99 train_loss: 0.33138675
# epoch:  99 train_accuracy: 0.91660265
# epoch:  99 val_loss: 0.52171983
# epoch:  99 val_accuracy: 0.87284938

# %%
import matplotlib.pyplot as plt

print('训练过程的损失随epoch变化趋势：')
plt.plot(train_loss_record, label='train_loss')
plt.plot(val_loss_record, label='val_loss')
plt.legend()
plt.show()

print('训练过程的准确率随epoch变化趋势：')
plt.plot(train_accuracy_record, label='train_accuracy')
plt.plot(val_accuracy_record, label='val_accuracy')
plt.legend()
plt.show()
# Out:
# 训练过程的损失随epoch变化趋势：
# 训练过程的准确率随epoch变化趋势：

# %% [markdown]
# ## 6. 验证模型，绘制结果

# %%
epoch_loss = 0
epoch_acc = 0
predicted_labels = []  # 模型结果标签，用于混淆矩阵
true_labels = []  # 模型真值标签，用于混淆矩阵

model.eval()
with torch.no_grad():
    for seq, labels in test_data:
        x,y = seq.to(device), labels.to(device)
        y_pred = model(x)
        y_pred = torch.squeeze(y_pred, dim=1) # 去除额外维度
        single_loss = loss_function(y_pred, y)
        
        # 获取预测正确的样本个数，由于pred为最大值所在位置的索引，
        # 因此不需要将label_test转换为one_hot编码
        # 当tensor为标量的时候，tensor.item()可以将其转换为ndarray类型
        # correct = pred.eq(label_test).sum().float().item()
        correct = torch.eq(y.argmax(dim=1), y_pred.argmax(dim=1))
        predicted_labels += y_pred.argmax(dim=1).tolist()
        true_labels += y.argmax(dim=1).tolist()
        
        epoch_acc += correct.sum().item()/ y.shape[0]
        epoch_loss += single_loss.item()

# 去平均
epoch_loss /= len(test_data)
epoch_acc /= len(test_data)

print(f'测试集平均损失：{epoch_loss}, \n测试集平均准确率：{epoch_acc}')
# Out:
# 测试集平均损失：0.521439762482898,
# 测试集平均准确率：0.8726135677633565

# %% [markdown]
# ### 修改结果储存路径，并存储结果

# %%
# 绘制混淆矩阵
# 混淆矩阵
from sklearn.metrics import confusion_matrix
# 初始化混淆矩阵
num_classes = 5
conf_matrix = np.zeros((num_classes, num_classes), dtype=int)
# 更新混淆矩阵
conf_matrix += confusion_matrix(true_labels, predicted_labels, labels=range(num_classes))
# 打印混淆矩阵
print("Confusion Matrix:")
print(conf_matrix)

plt.figure(figsize=(12, 9))
# 设置颜色映射
cmap = plt.cm.Blues
# 绘制混淆矩阵图
plt.imshow(conf_matrix, interpolation='nearest', cmap=cmap)
# 添加文字标签
for i in range(len(conf_matrix)):
    for j in range(len(conf_matrix)):
        plt.text(j, i, conf_matrix[i, j], ha='center', va='center', color='black')
# 添加颜色条
plt.colorbar()
# 添加标题和标签
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
# 显示图形
plt.show()
# Out:
# Confusion Matrix:
# [[ 2673    10     0   520     0]
#  [    0 21496  1632   564   444]
#  [    0  1438 61222 19464  1030]
#  [    0   239  1017 62347   172]
#  [    0    31    35   414 37249]]

# %%
# 绘制百分比混淆矩阵
from sklearn.metrics import confusion_matrix

num_classes = 5
conf_matrix = np.zeros((num_classes, num_classes), dtype=int)
conf_matrix += confusion_matrix(true_labels, predicted_labels, labels=range(num_classes))

# 转换为百分比混淆矩阵
conf_matrix_percentage = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis] * 100

# 打印混淆矩阵
print("Confusion Matrix (Percentage):")
print(conf_matrix_percentage)

# 绘制百分比混淆矩阵
plt.figure(figsize=(16, 12))
cmap = plt.cm.Blues
plt.imshow(conf_matrix_percentage, interpolation='nearest', cmap=cmap)

# 添加文字标签
for i in range(num_classes):
    for j in range(num_classes):
        plt.text(j, i, f'{conf_matrix_percentage[i, j]:.1f}%', ha='center', va='center', color='black')

# 添加颜色条
plt.colorbar()

# 添加标题和标签
plt.title('Confusion Matrix (Percentage)')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')

# 显示图形
plt.show()
# Out:
# Confusion Matrix (Percentage):
# [[8.34530128e+01 3.12207306e-01 0.00000000e+00 1.62347799e+01
#   0.00000000e+00]
#  [0.00000000e+00 8.90619821e+01 6.76168379e+00 2.33675837e+00
#   1.83957574e+00]
#  [0.00000000e+00 1.72932150e+00 7.36248407e+01 2.34071722e+01
#   1.23866561e+00]
#  [0.00000000e+00 3.74754998e-01 1.59466876e+00 9.77608781e+01
#   2.69698158e-01]
#  [0.00000000e+00 8.21649129e-02 9.27668372e-02 1.09729916e+00
#   9.87277691e+01]]

# %%
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# 计算总体的准确率、精确率、召回率、F1分数
def calculate_metrics_overall_by_sklearn(matrix):
    # 提取真实标签和预测标签
    true_labels = []
    pred_labels = []

    num_classes = matrix.shape[0]

    for i in range(num_classes):
        for j in range(num_classes):
            true_labels.extend([i] * matrix[i, j])
            pred_labels.extend([j] * matrix[i, j])

    # 计算总体的准确率、精确率、召回率和F1分数
    overall_accuracy = accuracy_score(true_labels, pred_labels)
    overall_precision = precision_score(true_labels, pred_labels, average='macro')
    overall_recall = recall_score(true_labels, pred_labels, average='macro')
    overall_f1 = f1_score(true_labels, pred_labels, average='macro')

    return overall_precision, overall_recall, overall_f1, overall_accuracy

real_overall_precision, real_overall_recall, real_overall_f1_score, real_overall_accuracy = calculate_metrics_overall_by_sklearn(conf_matrix)
print("总体精确率（Precision）: ", real_overall_precision)
print("总体召回率（Recall）: ", real_overall_recall)
print("总体F1 分数（F1 Score）: ", real_overall_f1_score)
print("总体准确率（Accuracy）: ", real_overall_accuracy)
# Out:
# 总体精确率（Precision）:  0.9180114425087611
# 总体召回率（Recall）:  0.8852569654722668
# 总体F1 分数（F1 Score）:  0.8940810592449772
# 总体准确率（Accuracy）:  0.8725925366868399
