# %%
import pandas as pd

import torch
import torch.nn as nn
import torch.nn.functional as F

from sklearn.preprocessing import OneHotEncoder

# %% [markdown]
# ## 1. 读取结构化数据集

# %%
df = pd.read_csv(f'../Dataset/Final_Dataset_2.csv')
df = df.drop(columns=['Time', 'Secondary Intent'])
df.head()
# Out:
#    User  ID  Hotas_Axis_X  Hotas_Axis_Y  Hotas_Axis_Z  Hotas_Btn_Create_Fleet  \
# 0     1   1           0.0           0.0     -0.307087                   False
# 1     1   1           0.0           0.0     -0.307087                   False
# 2     1   1           0.0           0.0     -0.307087                   False
# 3     1   1           0.0           0.0     -0.307087                   False
# 4     1   1           0.0           0.0     -0.307087                   False
#
#    Hotas_Btn_Select_UAV1  Hotas_Btn_Select_UAV2  Hotas_Btn_Select_UAV3  \
# 0                  False                  False                  False
# 1                  False                  False                  False
# 2                  False                  False                  False
# 3                  False                  False                  False
# 4                  False                  False                  False
#
#    Hotas_Btn_Select_UAV4  ...  Target_Area_State  Target_Area_Pos_X  \
# 0                  False  ...              False               -1.0
# 1                  False  ...              False               -1.0
# 2                  False  ...              False               -1.0
# 3                  False  ...              False               -1.0
# 4                  False  ...              False               -1.0
#
#    Target_Area_Pos_Y  Trapped_People_State  Trapped_People_Pos_X  \
# 0               -1.0                 False                  -1.0
# 1               -1.0                 False                  -1.0
# 2               -1.0                 False                  -1.0
# 3               -1.0                 False                  -1.0
# 4               -1.0                 False                  -1.0
#
#    Trapped_People_Pos_Y  Gaze point X  Gaze point Y  AOI  Primary Intent
# 0                  -1.0        2067.0        1195.0    4        Intent_0
# 1                  -1.0        2046.0        1204.0    4        Intent_0
# 2                  -1.0        2046.0        1200.0    4        Intent_0
# 3                  -1.0        2053.0        1221.0    4        Intent_0
# 4                  -1.0        2068.0        1209.0    4        Intent_0
#
# [5 rows x 55 columns]

# %%
df['New Intent'] = None
for index, row in df.iterrows():
    if row['Primary Intent'] == 'Intent_0':
        df.at[index, 'New Intent'] = '00'
    if row['Primary Intent'] == 'Intent_1':
        df.at[index, 'New Intent'] = '01'
    if row['Primary Intent'] == 'Intent_2':
        df.at[index, 'New Intent'] = '02'
    if row['Primary Intent'] == 'Intent_3':
        df.at[index, 'New Intent'] = '03'
    if row['Primary Intent'] == 'Intent_4':
        df.at[index, 'New Intent'] = '04'
    if row['Primary Intent'] == 'Intent_5':
        df.at[index, 'New Intent'] = '05'
   

df.drop(columns=['Primary Intent'], inplace=True)
df.rename(columns={'New Intent': 'Intent'}, inplace=True)
df.head()
# Out:
#    User  ID  Hotas_Axis_X  Hotas_Axis_Y  Hotas_Axis_Z  Hotas_Btn_Create_Fleet  \
# 0     1   1           0.0           0.0     -0.307087                   False
# 1     1   1           0.0           0.0     -0.307087                   False
# 2     1   1           0.0           0.0     -0.307087                   False
# 3     1   1           0.0           0.0     -0.307087                   False
# 4     1   1           0.0           0.0     -0.307087                   False
#
#    Hotas_Btn_Select_UAV1  Hotas_Btn_Select_UAV2  Hotas_Btn_Select_UAV3  \
# 0                  False                  False                  False
# 1                  False                  False                  False
# 2                  False                  False                  False
# 3                  False                  False                  False
# 4                  False                  False                  False
#
#    Hotas_Btn_Select_UAV4  ...  Target_Area_State  Target_Area_Pos_X  \
# 0                  False  ...              False               -1.0
# 1                  False  ...              False               -1.0
# 2                  False  ...              False               -1.0
# 3                  False  ...              False               -1.0
# 4                  False  ...              False               -1.0
#
#    Target_Area_Pos_Y  Trapped_People_State  Trapped_People_Pos_X  \
# 0               -1.0                 False                  -1.0
# 1               -1.0                 False                  -1.0
# 2               -1.0                 False                  -1.0
# 3               -1.0                 False                  -1.0
# 4               -1.0                 False                  -1.0
#
#    Trapped_People_Pos_Y  Gaze point X  Gaze point Y  AOI  Intent
# 0                  -1.0        2067.0        1195.0    4      00
# 1                  -1.0        2046.0        1204.0    4      00
# 2                  -1.0        2046.0        1200.0    4      00
# 3                  -1.0        2053.0        1221.0    4      00
# 4                  -1.0        2068.0        1209.0    4      00
#
# [5 rows x 55 columns]

# %%
# 离散特征变量使用One-Hot编码，通过DataFrame实现
df = pd.get_dummies(df, columns=['Flight_Fleet_State', 'Flight_Fly_Mode', 'UAV_Selected_Now', 'UAV1_Task_State', 'UAV2_Task_State',
                                 'UAV3_Task_State', 'UAV4_Task_State', 'AOI', 'Intent'])
df.head()
# Out:
#    User  ID  Hotas_Axis_X  Hotas_Axis_Y  Hotas_Axis_Z  Hotas_Btn_Create_Fleet  \
# 0     1   1           0.0           0.0     -0.307087                   False
# 1     1   1           0.0           0.0     -0.307087                   False
# 2     1   1           0.0           0.0     -0.307087                   False
# 3     1   1           0.0           0.0     -0.307087                   False
# 4     1   1           0.0           0.0     -0.307087                   False
#
#    Hotas_Btn_Select_UAV1  Hotas_Btn_Select_UAV2  Hotas_Btn_Select_UAV3  \
# 0                  False                  False                  False
# 1                  False                  False                  False
# 2                  False                  False                  False
# 3                  False                  False                  False
# 4                  False                  False                  False
#
#    Hotas_Btn_Select_UAV4  ...  AOI_3  AOI_4  AOI_5  AOI_6  Intent_00  \
# 0                  False  ...  False   True  False  False       True
# 1                  False  ...  False   True  False  False       True
# 2                  False  ...  False   True  False  False       True
# 3                  False  ...  False   True  False  False       True
# 4                  False  ...  False   True  False  False       True
#
#    Intent_01  Intent_02  Intent_03  Intent_04  Intent_05
# 0      False      False      False      False      False
# 1      False      False      False      False      False
# 2      False      False      False      False      False
# 3      False      False      False      False      False
# 4      False      False      False      False      False
#
# [5 rows x 85 columns]

# %%
# 设置训练集和测试集
train_ids = [i for i in range(1, 51) if i % 5 != 0]
test_ids = [i for i in range(1, 51) if i % 5 == 0]
print("train IDs:", train_ids)
print("test IDs:", test_ids)

df_train = df[df['ID'].isin(train_ids)]
df_test = df[df['ID'].isin(test_ids)]
print(df_train.shape, df_test.shape)
# Out:
# train IDs: [1, 2, 3, 4, 6, 7, 8, 9, 11, 12, 13, 14, 16, 17, 18, 19, 21, 22, 23, 24, 26, 27, 28, 29, 31, 32, 33, 34, 36, 37, 38, 39, 41, 42, 43, 44, 46, 47, 48, 49]
# test IDs: [5, 10, 15, 20, 25, 30, 35, 40, 45, 50]
# (941603, 85) (233086, 85)

# %%
# 数据归一化-训练集
df_train.loc[:, 'Hotas_Axis_X']  = (df_train['Hotas_Axis_X']+1)/2
df_train.loc[:, 'Hotas_Axis_Y']  = (df_train['Hotas_Axis_Y']+1)/2
df_train.loc[:, 'Hotas_Axis_Z']  = (df_train['Hotas_Axis_Z']+1)/2

df_train.loc[:, 'Flight_Pos_X']  = (df_train['Flight_Pos_X']-df_train['Flight_Pos_X'].min())/(df_train['Flight_Pos_X'].max()-df_train['Flight_Pos_X'].min())
df_train.loc[:, 'Flight_Pos_Y']  = (df_train['Flight_Pos_Y']-df_train['Flight_Pos_Y'].min())/(df_train['Flight_Pos_Y'].max()-df_train['Flight_Pos_Y'].min())
df_train.loc[:, 'Flight_Speed']  = (df_train['Flight_Speed']-df_train['Flight_Speed'].min())/(df_train['Flight_Speed'].max()-df_train['Flight_Speed'].min())
df_train.loc[:, 'Flight_Height']  = (df_train['Flight_Height']-df_train['Flight_Height'].min())/(df_train['Flight_Height'].max()-df_train['Flight_Height'].min())
df_train.loc[:, 'Flight_Heading']  = (df_train['Flight_Heading']-df_train['Flight_Heading'].min())/(df_train['Flight_Heading'].max()-df_train['Flight_Heading'].min())

df_train.loc[:, 'UAV1_Pos_X']  = df_train['UAV1_Pos_X']/3840
df_train.loc[:, 'UAV1_Pos_Y']  = df_train['UAV1_Pos_Y']/2160
df_train.loc[:, 'UAV2_Pos_X']  = df_train['UAV2_Pos_X']/3840
df_train.loc[:, 'UAV2_Pos_Y']  = df_train['UAV2_Pos_Y']/2160
df_train.loc[:, 'UAV3_Pos_X']  = df_train['UAV3_Pos_X']/3840
df_train.loc[:, 'UAV3_Pos_Y']  = df_train['UAV3_Pos_Y']/2160
df_train.loc[:, 'UAV4_Pos_X']  = df_train['UAV4_Pos_X']/3840
df_train.loc[:, 'UAV4_Pos_Y']  = df_train['UAV4_Pos_Y']/2160

df_train.loc[:, 'Target_Area_Pos_X']  = (df_train['Target_Area_Pos_X']-df_train['Target_Area_Pos_X'].min())/(df_train['Target_Area_Pos_X'].max()-df_train['Target_Area_Pos_X'].min())
df_train.loc[:, 'Target_Area_Pos_Y']  = (df_train['Target_Area_Pos_Y']-df_train['Target_Area_Pos_Y'].min())/(df_train['Target_Area_Pos_Y'].max()-df_train['Target_Area_Pos_Y'].min())
df_train.loc[:, 'Trapped_People_Pos_X']  = (df_train['Trapped_People_Pos_X']-df_train['Trapped_People_Pos_X'].min())/(df_train['Trapped_People_Pos_X'].max()-df_train['Trapped_People_Pos_X'].min())
df_train.loc[:, 'Trapped_People_Pos_Y']  = (df_train['Trapped_People_Pos_Y']-df_train['Trapped_People_Pos_Y'].min())/(df_train['Trapped_People_Pos_Y'].max()-df_train['Trapped_People_Pos_Y'].min())

df_train.loc[:, 'Gaze point X']  = df_train['Gaze point X']/3840
df_train.loc[:, 'Gaze point Y']  = df_train['Gaze point Y']/2160

# 数据归一化-测试集
df_test.loc[:, 'Hotas_Axis_X']  = (df_test['Hotas_Axis_X']+1)/2
df_test.loc[:, 'Hotas_Axis_Y']  = (df_test['Hotas_Axis_Y']+1)/2
df_test.loc[:, 'Hotas_Axis_Z']  = (df_test['Hotas_Axis_Z']+1)/2

df_test.loc[:, 'Flight_Pos_X']  = (df_test['Flight_Pos_X']-df_test['Flight_Pos_X'].min())/(df_test['Flight_Pos_X'].max()-df_test['Flight_Pos_X'].min())
df_test.loc[:, 'Flight_Pos_Y']  = (df_test['Flight_Pos_Y']-df_train['Flight_Pos_Y'].min())/(df_test['Flight_Pos_Y'].max()-df_test['Flight_Pos_Y'].min())
df_test.loc[:, 'Flight_Speed']  = (df_test['Flight_Speed']-df_train['Flight_Speed'].min())/(df_test['Flight_Speed'].max()-df_test['Flight_Speed'].min())
df_test.loc[:, 'Flight_Height']  = (df_test['Flight_Height']-df_test['Flight_Height'].min())/(df_test['Flight_Height'].max()-df_test['Flight_Height'].min())
df_test.loc[:, 'Flight_Heading']  = (df_test['Flight_Heading']-df_test['Flight_Heading'].min())/(df_test['Flight_Heading'].max()-df_test['Flight_Heading'].min())

df_test.loc[:, 'UAV1_Pos_X']  = df_test['UAV1_Pos_X']/3840
df_test.loc[:, 'UAV1_Pos_Y']  = df_test['UAV1_Pos_Y']/2160
df_test.loc[:, 'UAV2_Pos_X']  = df_test['UAV2_Pos_X']/3840
df_test.loc[:, 'UAV2_Pos_Y']  = df_test['UAV2_Pos_Y']/2160
df_test.loc[:, 'UAV3_Pos_X']  = df_test['UAV3_Pos_X']/3840
df_test.loc[:, 'UAV3_Pos_Y']  = df_test['UAV3_Pos_Y']/2160
df_test.loc[:, 'UAV4_Pos_X']  = df_test['UAV4_Pos_X']/3840
df_test.loc[:, 'UAV4_Pos_Y']  = df_test['UAV4_Pos_Y']/2160

df_test.loc[:, 'Target_Area_Pos_X']  = (df_test['Target_Area_Pos_X']-df_test['Target_Area_Pos_X'].min())/(df_test['Target_Area_Pos_X'].max()-df_test['Target_Area_Pos_X'].min())
df_test.loc[:, 'Target_Area_Pos_Y']  = (df_test['Target_Area_Pos_Y']-df_test['Target_Area_Pos_Y'].min())/(df_test['Target_Area_Pos_Y'].max()-df_test['Target_Area_Pos_Y'].min())
df_test.loc[:, 'Trapped_People_Pos_X']  = (df_test['Trapped_People_Pos_X']-df_test['Trapped_People_Pos_X'].min())/(df_test['Trapped_People_Pos_X'].max()-df_test['Trapped_People_Pos_X'].min())
df_test.loc[:, 'Trapped_People_Pos_Y']  = (df_test['Trapped_People_Pos_Y']-df_test['Trapped_People_Pos_Y'].min())/(df_test['Trapped_People_Pos_Y'].max()-df_test['Trapped_People_Pos_Y'].min())

df_test.loc[:, 'Gaze point X']  = df_test['Gaze point X']/3840
df_test.loc[:, 'Gaze point Y']  = df_test['Gaze point Y']/2160

pd.set_option('display.max_columns', None)
df_train.head()
# Out:
#    User  ID  Hotas_Axis_X  Hotas_Axis_Y  Hotas_Axis_Z  Hotas_Btn_Create_Fleet  \
# 0     1   1           0.5           0.5      0.346457                   False
# 1     1   1           0.5           0.5      0.346457                   False
# 2     1   1           0.5           0.5      0.346457                   False
# 3     1   1           0.5           0.5      0.346457                   False
# 4     1   1           0.5           0.5      0.346457                   False
#
#    Hotas_Btn_Select_UAV1  Hotas_Btn_Select_UAV2  Hotas_Btn_Select_UAV3  \
# 0                  False                  False                  False
# 1                  False                  False                  False
# 2                  False                  False                  False
# 3                  False                  False                  False
# 4                  False                  False                  False
#
#    Hotas_Btn_Select_UAV4  Hotas_Btn_Assign_Up  Hotas_Btn_Assign_Down  \
# 0                  False                False                  False
# 1                  False                False                  False
# 2                  False                False                  False
# 3                  False                False                  False
# 4                  False                False                  False
#
#    Hotas_Btn_Assign_Left  Hotas_Btn_Assign_Right  Hotas_Btn_Change_Mode  \
# 0                  False                   False                  False
# 1                  False                   False                  False
# 2                  False                   False                  False
# 3                  False                   False                  False
# 4                  False                   False                  False
#
#    Hotas_Btn_Open_UAV_Sensor  Hotas_Btn_Open_Helicopter_Sensor  \
# 0                      False                             False
# 1                      False                             False
# 2                      False                             False
# 3                      False                             False
# 4                      False                             False
#
#    Hotas_Btn_Select_Normal  Hotas_Btn_Select_Fire  Hotas_Btn_Select_Person  \
# 0                    False                  False                    False
# 1                    False                  False                    False
# 2                    False                  False                    False
# 3                    False                  False                    False
# 4                    False                  False                    False
#
#    Hotas_Btn_Submit_Result  Hotas_Btn_Area_Assign  Flight_Pos_X  Flight_Pos_Y  \
# 0                    False                  False        0.4499      0.127802
# 1                    False                  False        0.4499      0.127802
# 2                    False                  False        0.4499      0.127802
# 3                    False                  False        0.4499      0.127802
# 4                    False                  False        0.4499      0.127802
#
#    Flight_Speed  Flight_Height  Flight_Heading  Flight_Sensor  UAV1_Pos_X  \
# 0           0.0        0.40634        0.000016          False    0.495825
# 1           0.0        0.40634        0.000016          False    0.495825
# 2           0.0        0.40634        0.000016          False    0.495825
# 3           0.0        0.40634        0.000016          False    0.495825
# 4           0.0        0.40634        0.000016          False    0.495825
#
#    UAV1_Pos_Y  UAV2_Pos_X  UAV2_Pos_Y  UAV3_Pos_X  UAV3_Pos_Y  UAV4_Pos_X  \
# 0      0.1839    0.534825      0.1839    0.495825    0.130567    0.534825
# 1      0.1839    0.534825      0.1839    0.495825    0.130567    0.534825
# 2      0.1839    0.534825      0.1839    0.495825    0.130567    0.534825
# 3      0.1839    0.534825      0.1839    0.495825    0.130567    0.534825
# 4      0.1839    0.534825      0.1839    0.495825    0.130567    0.534825
#
#    UAV4_Pos_Y  UAV_Sensor_State  Task_List_State  Target_Area_State  \
# 0    0.130567             False             True              False
# 1    0.130567             False             True              False
# 2    0.130567             False             True              False
# 3    0.130567             False             True              False
# 4    0.130567             False             True              False
#
#    Target_Area_Pos_X  Target_Area_Pos_Y  Trapped_People_State  \
# 0                0.0                0.0                 False
# 1                0.0                0.0                 False
# 2                0.0                0.0                 False
# 3                0.0                0.0                 False
# 4                0.0                0.0                 False
#
#    Trapped_People_Pos_X  Trapped_People_Pos_Y  Gaze point X  Gaze point Y  \
# 0                   0.0                   0.0      0.538281      0.553241
# 1                   0.0                   0.0      0.532813      0.557407
# 2                   0.0                   0.0      0.532813      0.555556
# 3                   0.0                   0.0      0.534635      0.565278
# 4                   0.0                   0.0      0.538542      0.559722
#
#    Flight_Fleet_State_0  Flight_Fleet_State_1  Flight_Fleet_State_2  \
# 0                  True                 False                 False
# 1                  True                 False                 False
# 2                  True                 False                 False
# 3                  True                 False                 False
# 4                  True                 False                 False
#
#    Flight_Fly_Mode_0  Flight_Fly_Mode_1  UAV_Selected_Now_-1.0  \
# 0               True              False                   True
# 1               True              False                   True
# 2               True              False                   True
# 3               True              False                   True
# 4               True              False                   True
#
#    UAV_Selected_Now_1.0  UAV_Selected_Now_2.0  UAV_Selected_Now_3.0  \
# 0                 False                 False                 False
# 1                 False                 False                 False
# 2                 False                 False                 False
# 3                 False                 False                 False
# 4                 False                 False                 False
#
#    UAV_Selected_Now_4.0  UAV1_Task_State_0  UAV1_Task_State_1  \
# 0                 False               True              False
# 1                 False               True              False
# 2                 False               True              False
# 3                 False               True              False
# 4                 False               True              False
#
#    UAV1_Task_State_2  UAV1_Task_State_3  UAV2_Task_State_0  UAV2_Task_State_1  \
# 0              False              False               True              False
# 1              False              False               True              False
# 2              False              False               True              False
# 3              False              False               True              False
# 4              False              False               True              False
#
#    UAV2_Task_State_2  UAV2_Task_State_3  UAV3_Task_State_0  UAV3_Task_State_1  \
# 0              False              False               True              False
# 1              False              False               True              False
# 2              False              False               True              False
# 3              False              False               True              False
# 4              False              False               True              False
#
#    UAV3_Task_State_2  UAV3_Task_State_3  UAV4_Task_State_0  UAV4_Task_State_1  \
# 0              False              False               True              False
# 1              False              False               True              False
# 2              False              False               True              False
# 3              False              False               True              False
# 4              False              False               True              False
#
#    UAV4_Task_State_2  UAV4_Task_State_3  AOI_0  AOI_1  AOI_2  AOI_3  AOI_4  \
# 0              False              False  False  False  False  False   True
# 1              False              False  False  False  False  False   True
# 2              False              False  False  False  False  False   True
# 3              False              False  False  False  False  False   True
# 4              False              False  False  False  False  False   True
#
#    AOI_5  AOI_6  Intent_00  Intent_01  Intent_02  Intent_03  Intent_04  \
# 0  False  False       True      False      False      False      False
# 1  False  False       True      False      False      False      False
# 2  False  False       True      False      False      False      False
# 3  False  False       True      False      False      False      False
# 4  False  False       True      False      False      False      False
#
#    Intent_05
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False

# %% [markdown]
# ## 2. 定义Dataset和DataLoader

# %%
from torch.utils.data import DataLoader, Dataset
import numpy as np

class MyDataset(Dataset):
    # 实例化调用，数据集初始化
    def __init__(self, df, time_step):
        # 初始化输入输出
        x = []
        y = []
        num_intent_0 = 0
        
        # 根据test_id划分DataFrame
        grouped = df.groupby('ID')
        
        for _, group in grouped:
            # test_id放在最后
            origin_data = group.drop(columns=['ID', 'User'])
            # 将表格中的bool型转换为int型
            for column in origin_data.columns:
                if origin_data[column].dtype == bool:
                    origin_data[column] = origin_data[column].astype(int)
            # 将表格数据转换为Numpy
            dataset = (origin_data).to_numpy()
            for i in range(len(dataset) - time_step):
                input_seq = dataset[i:(i+time_step), 0:-6]
                output_seq = dataset[i+time_step-1, -6:]
                
#                 x.append(input_seq)
#                 y.append(output_seq)
                
                if output_seq[0] == 1:
                    num_intent_0 += 1
                else:
                    x.append(input_seq)
                    y.append(output_seq[1:])
        
        x = np.array(x)
        y = np.array(y)
        print(f'shape_input:{x.shape},shape_output:{y.shape}')
        print(f'delete Intent_0:{num_intent_0}')
        
        self.data_tensor = torch.tensor(x, dtype=torch.float32)
        self.label_tensor = torch.tensor(y, dtype=torch.float32)
    
    # 返回数据集的长度    
    def __len__(self):
        return self.data_tensor.shape[0]
    
    # 根据指定下标返回数据集内容    
    def __getitem__(self, i):
        # 读取数据
        data = self.data_tensor[i]
        # 读取标签
        label = self.label_tensor[i]

        return data, label  # 返回数据和标签
  
train_dataset = MyDataset(df_train, 20)
test_dataset = MyDataset(df_test, 20)

# 加载数据集
train_data = DataLoader(train_dataset, batch_size=64, shuffle=False) # shuffle是否打乱
test_data = DataLoader(test_dataset, batch_size=64, shuffle=False)

print(f'输入张量：{train_dataset.data_tensor.shape} 输出张量：{train_dataset.label_tensor.shape}')
# Out:
# shape_input:(827893, 20, 77),shape_output:(827893, 5)
# delete Intent_0:112910
# shape_input:(211997, 20, 77),shape_output:(211997, 5)
# delete Intent_0:20889
# 输入张量：torch.Size([827893, 20, 77]) 输出张量：torch.Size([827893, 5])

# %% [markdown]
# ## 3. 定义LSTM模型

# %% [markdown]
# ### 模型1: GRU模型

# %%
class GRU(nn.Module):
    def __init__(self, input_size=77, hidden_size=128, output_size=5, num_layers=1, bidirectional=False):
        super().__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.num_layers = num_layers
        self.bidirectional = bidirectional
        self.num_directions = 2 if bidirectional else 1 # 单向LSTM模型
        
        self.gru = nn.GRU(self.input_size, self.hidden_size, self.num_layers, batch_first=True, bidirectional=self.bidirectional)
        self.linear = nn.Linear(self.hidden_size * self.num_directions, self.output_size)

    def forward(self, input_seq):
        batch_size, seq_len = input_seq.shape[0], input_seq.shape[1]
        h_0 = torch.randn(self.num_directions * self.num_layers, batch_size, self.hidden_size).to(device)
        
        gru_out, self.hidden_cell = self.gru(input_seq, h_0)
        predictions = self.linear(gru_out[:,-1,:])# LSTM只输出最后一个时间步
        return predictions

# %% [markdown]
# ## 4. 实例化模型，定义超参数

# %%
device = 'cuda'
model = GRU().to(device)
# 损失函数
loss_function = nn.CrossEntropyLoss()
# 优化器
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %% [markdown]
# ## 5. 训练模型

# %%
epochs = 100
train_loss_record = []
train_accuracy_record = []
val_loss_record = []
val_accuracy_record = []

for i in range(epochs):
    # 模型训练
    model.train()
    train_loss = 0
    train_accuracy = 0
    
    for seq, labels in train_data:
        optimizer.zero_grad()
        x,y = seq.to(device), labels.to(device)
        y_pred = model(x)
        y_pred = torch.squeeze(y_pred, dim=1) # 去除额外维度
        loss = loss_function(y_pred, y)
        loss.backward()
        optimizer.step()
        
        # 计算训练准确率
        train_loss += loss.item()
        train_correct = torch.eq(y.argmax(dim=1), y_pred.argmax(dim=1))
        train_accuracy += train_correct.sum().item()/ y.shape[0]

    # if i%1 == 1:
    avg_train_loss = train_loss / len(train_data)
    print(f'epoch: {i:3} train_loss: {avg_train_loss:10.8f}')
    train_loss_record.append(avg_train_loss)
    
    avg_train_accuracy = train_accuracy / len(train_data)
    print(f'epoch: {i:3} train_accuracy: {avg_train_accuracy:10.8f}')
    train_accuracy_record.append(avg_train_accuracy)
    

    # 模型验证
    model.eval()
    val_loss = 0
    val_accuracy = 0
    
    with torch.no_grad():
        for seq, labels in test_data:
            x,y = seq.to(device), labels.to(device)
            y_pred = model(x)
            y_pred = torch.squeeze(y_pred, dim=1) # 去除额外维度
            loss = loss_function(y_pred, y)
            val_loss += loss.item()
            val_correct = torch.eq(y.argmax(dim=1), y_pred.argmax(dim=1))
            val_accuracy += val_correct.sum().item()/ y.shape[0]
    
    avg_val_loss = val_loss / len(test_data)
    print(f'epoch: {i:3} val_loss: {avg_val_loss:10.8f}')
    val_loss_record.append(avg_val_loss)
    
    avg_val_accuracy = val_accuracy / len(test_data)
    print(f'epoch: {i:3} val_accuracy: {avg_val_accuracy:10.8f}')
    val_accuracy_record.append(avg_val_accuracy)
# Out:
# epoch:   0 train_loss: 0.29047161
# epoch:   0 train_accuracy: 0.89665468
# epoch:   0 val_loss: 0.17547974
# epoch:   0 val_accuracy: 0.95178558
# epoch:   1 train_loss: 0.17958996
# epoch:   1 train_accuracy: 0.94539705
# epoch:   1 val_loss: 0.14201853
# epoch:   1 val_accuracy: 0.96268959
# epoch:   2 train_loss: 0.15425962
# epoch:   2 train_accuracy: 0.95386059
# epoch:   2 val_loss: 0.12283819
# epoch:   2 val_accuracy: 0.96643903
# epoch:   3 train_loss: 0.13906147
# epoch:   3 train_accuracy: 0.95800479
# epoch:   3 val_loss: 0.11178654
# epoch:   3 val_accuracy: 0.96850004
# epoch:   4 train_loss: 0.12909203
# epoch:   4 train_accuracy: 0.96197023
# epoch:   4 val_loss: 0.11325977
# epoch:   4 val_accuracy: 0.96997623
# epoch:   5 train_loss: 0.11573542
# epoch:   5 train_accuracy: 0.96575328
# epoch:   5 val_loss: 0.10660249
# epoch:   5 val_accuracy: 0.97082987
# epoch:   6 train_loss: 0.10702625
# epoch:   6 train_accuracy: 0.96867874
# epoch:   6 val_loss: 0.10866366
# epoch:   6 val_accuracy: 0.97049030
# epoch:   7 train_loss: 0.09401569
# epoch:   7 train_accuracy: 0.97195448
# epoch:   7 val_loss: 0.10983398
# epoch:   7 val_accuracy: 0.96986776
# epoch:   8 train_loss: 0.09049200
# epoch:   8 train_accuracy: 0.97325898
# epoch:   8 val_loss: 0.10187365
# epoch:   8 val_accuracy: 0.97209855
# epoch:   9 train_loss: 0.08597631
# epoch:   9 train_accuracy: 0.97513117
# epoch:   9 val_loss: 0.10054408
# epoch:   9 val_accuracy: 0.97380584
# epoch:  10 train_loss: 0.08010971
# epoch:  10 train_accuracy: 0.97638374
# epoch:  10 val_loss: 0.10137599
# epoch:  10 val_accuracy: 0.97446612
# epoch:  11 train_loss: 0.07636899
# epoch:  11 train_accuracy: 0.97703478
# epoch:  11 val_loss: 0.10074477
# epoch:  11 val_accuracy: 0.97521601
# epoch:  12 train_loss: 0.07620045
# epoch:  12 train_accuracy: 0.97758315
# epoch:  12 val_loss: 0.08992132
# epoch:  12 val_accuracy: 0.97546125
# epoch:  13 train_loss: 0.07263420
# epoch:  13 train_accuracy: 0.97847093
# epoch:  13 val_loss: 0.10389155
# epoch:  13 val_accuracy: 0.97446140
# epoch:  14 train_loss: 0.07119496
# epoch:  14 train_accuracy: 0.97904950
# epoch:  14 val_loss: 0.10657971
# epoch:  14 val_accuracy: 0.97483399
# epoch:  15 train_loss: 0.07137322
# epoch:  15 train_accuracy: 0.97864487
# epoch:  15 val_loss: 0.09770047
# epoch:  15 val_accuracy: 0.97645167
# epoch:  16 train_loss: 0.06714685
# epoch:  16 train_accuracy: 0.98012934
# epoch:  16 val_loss: 0.11210565
# epoch:  16 val_accuracy: 0.97470193
# epoch:  17 train_loss: 0.06807225
# epoch:  17 train_accuracy: 0.97965223
# epoch:  17 val_loss: 0.11113330
# epoch:  17 val_accuracy: 0.97486228
# epoch:  18 train_loss: 0.07038287
# epoch:  18 train_accuracy: 0.97934060
# epoch:  18 val_loss: 0.11258893
# epoch:  18 val_accuracy: 0.97531976
# epoch:  19 train_loss: 0.06744456
# epoch:  19 train_accuracy: 0.98001338
# epoch:  19 val_loss: 0.11327649
# epoch:  19 val_accuracy: 0.97485757
# epoch:  20 train_loss: 0.06640986
# epoch:  20 train_accuracy: 0.98039507
# epoch:  20 val_loss: 0.10991895
# epoch:  20 val_accuracy: 0.97576309
# epoch:  21 train_loss: 0.06588038
# epoch:  21 train_accuracy: 0.98025254
# epoch:  21 val_loss: 0.10288889
# epoch:  21 val_accuracy: 0.97538579
# epoch:  22 train_loss: 0.06688226
# epoch:  22 train_accuracy: 0.98011968
# epoch:  22 val_loss: 0.12241203
# epoch:  22 val_accuracy: 0.97345212
# epoch:  23 train_loss: 0.06969868
# epoch:  23 train_accuracy: 0.97902655
# epoch:  23 val_loss: 0.10159857
# epoch:  23 val_accuracy: 0.97540466
# epoch:  24 train_loss: 0.06743828
# epoch:  24 train_accuracy: 0.98007136
# epoch:  24 val_loss: 0.09464505
# epoch:  24 val_accuracy: 0.97616398
# epoch:  25 train_loss: 0.07105712
# epoch:  25 train_accuracy: 0.97853012
# epoch:  25 val_loss: 0.10586661
# epoch:  25 val_accuracy: 0.97599419
# epoch:  26 train_loss: 0.07047695
# epoch:  26 train_accuracy: 0.97925243
# epoch:  26 val_loss: 0.10950523
# epoch:  26 val_accuracy: 0.97484342
# epoch:  27 train_loss: 0.06958672
# epoch:  27 train_accuracy: 0.97949158
# epoch:  27 val_loss: 0.09976204
# epoch:  27 val_accuracy: 0.97560274
# epoch:  28 train_loss: 0.07060720
# epoch:  28 train_accuracy: 0.97890456
# epoch:  28 val_loss: 0.11712304
# epoch:  28 val_accuracy: 0.97591401
# epoch:  29 train_loss: 0.07890786
# epoch:  29 train_accuracy: 0.97662652
# epoch:  29 val_loss: 0.10637688
# epoch:  29 val_accuracy: 0.97618756
# epoch:  30 train_loss: 0.07431340
# epoch:  30 train_accuracy: 0.97812790
# epoch:  30 val_loss: 0.12499942
# epoch:  30 val_accuracy: 0.97248529
# epoch:  31 train_loss: 0.07338465
# epoch:  31 train_accuracy: 0.97859776
# epoch:  31 val_loss: 0.10569347
# epoch:  31 val_accuracy: 0.97561217
# epoch:  32 train_loss: 0.07605770
# epoch:  32 train_accuracy: 0.97820399
# epoch:  32 val_loss: 0.10698671
# epoch:  32 val_accuracy: 0.97542352
# epoch:  33 train_loss: 0.07018883
# epoch:  33 train_accuracy: 0.97975007
# epoch:  33 val_loss: 0.10666016
# epoch:  33 val_accuracy: 0.97573008
# epoch:  34 train_loss: 0.06992465
# epoch:  34 train_accuracy: 0.97935630
# epoch:  34 val_loss: 0.10153276
# epoch:  34 val_accuracy: 0.97614039
# epoch:  35 train_loss: 0.07139736
# epoch:  35 train_accuracy: 0.97861346
# epoch:  35 val_loss: 0.09655234
# epoch:  35 val_accuracy: 0.97653184
# epoch:  36 train_loss: 0.07243163
# epoch:  36 train_accuracy: 0.97880551
# epoch:  36 val_loss: 0.11206251
# epoch:  36 val_accuracy: 0.97383885
# epoch:  37 train_loss: 0.07604775
# epoch:  37 train_accuracy: 0.97698405
# epoch:  37 val_loss: 0.12005162
# epoch:  37 val_accuracy: 0.97241454
# epoch:  38 train_loss: 0.07416073
# epoch:  38 train_accuracy: 0.97842383
# epoch:  38 val_loss: 0.10564735
# epoch:  38 val_accuracy: 0.97716854
# epoch:  39 train_loss: 0.07924536
# epoch:  39 train_accuracy: 0.97681978
# epoch:  39 val_loss: 0.09933572
# epoch:  39 val_accuracy: 0.97485285
# epoch:  40 train_loss: 0.08077786
# epoch:  40 train_accuracy: 0.97592354
# epoch:  40 val_loss: 0.10652216
# epoch:  40 val_accuracy: 0.97329648
# epoch:  41 train_loss: 0.08240319
# epoch:  41 train_accuracy: 0.97573511
# epoch:  41 val_loss: 0.11230458
# epoch:  41 val_accuracy: 0.97458874
# epoch:  42 train_loss: 0.08801383
# epoch:  42 train_accuracy: 0.97437626
# epoch:  42 val_loss: 0.10931728
# epoch:  42 val_accuracy: 0.97483399
# epoch:  43 train_loss: 0.09145118
# epoch:  43 train_accuracy: 0.97310195
# epoch:  43 val_loss: 0.10616296
# epoch:  43 val_accuracy: 0.97313141
# epoch:  44 train_loss: 0.09053918
# epoch:  44 train_accuracy: 0.97402839
# epoch:  44 val_loss: 0.10812584
# epoch:  44 val_accuracy: 0.97307482
# epoch:  45 train_loss: 0.08760901
# epoch:  45 train_accuracy: 0.97427963
# epoch:  45 val_loss: 0.10974174
# epoch:  45 val_accuracy: 0.97319273
# epoch:  46 train_loss: 0.08822671
# epoch:  46 train_accuracy: 0.97373488
# epoch:  46 val_loss: 0.09380930
# epoch:  46 val_accuracy: 0.97465949
# epoch:  47 train_loss: 0.08095829
# epoch:  47 train_accuracy: 0.97630039
# epoch:  47 val_loss: 0.09708184
# epoch:  47 val_accuracy: 0.97457459
# epoch:  48 train_loss: 0.07560037
# epoch:  48 train_accuracy: 0.97776433
# epoch:  48 val_loss: 0.10966415
# epoch:  48 val_accuracy: 0.97394261
# epoch:  49 train_loss: 0.07557246
# epoch:  49 train_accuracy: 0.97801194
# epoch:  49 val_loss: 0.10686569
# epoch:  49 val_accuracy: 0.97417371
# epoch:  50 train_loss: 0.07665593
# epoch:  50 train_accuracy: 0.97692245
# epoch:  50 val_loss: 0.10055290
# epoch:  50 val_accuracy: 0.97305124
# epoch:  51 train_loss: 0.07835829
# epoch:  51 train_accuracy: 0.97734037
# epoch:  51 val_loss: 0.09128141
# epoch:  51 val_accuracy: 0.97380584
# epoch:  52 train_loss: 0.07508305
# epoch:  52 train_accuracy: 0.97831270
# epoch:  52 val_loss: 0.11047834
# epoch:  52 val_accuracy: 0.97394261
# epoch:  53 train_loss: 0.07890728
# epoch:  53 train_accuracy: 0.97650694
# epoch:  53 val_loss: 0.09967963
# epoch:  53 val_accuracy: 0.97329177
# epoch:  54 train_loss: 0.08325679
# epoch:  54 train_accuracy: 0.97528941
# epoch:  54 val_loss: 0.09641624
# epoch:  54 val_accuracy: 0.97384829
# epoch:  55 train_loss: 0.08577241
# epoch:  55 train_accuracy: 0.97416367
# epoch:  55 val_loss: 0.09041362
# epoch:  55 val_accuracy: 0.97534334
# epoch:  56 train_loss: 0.08404623
# epoch:  56 train_accuracy: 0.97613008
# epoch:  56 val_loss: 0.08733407
# epoch:  56 val_accuracy: 0.97454158
# epoch:  57 train_loss: 0.08008117
# epoch:  57 train_accuracy: 0.97682944
# epoch:  57 val_loss: 0.09489393
# epoch:  57 val_accuracy: 0.97560746
# epoch:  58 train_loss: 0.08003577
# epoch:  58 train_accuracy: 0.97672073
# epoch:  58 val_loss: 0.08176586
# epoch:  58 val_accuracy: 0.97803633
# epoch:  59 train_loss: 0.07979518
# epoch:  59 train_accuracy: 0.97818105
# epoch:  59 val_loss: 0.10278374
# epoch:  59 val_accuracy: 0.97359361
# epoch:  60 train_loss: 0.08172715
# epoch:  60 train_accuracy: 0.97621584
# epoch:  60 val_loss: 0.09795500
# epoch:  60 val_accuracy: 0.97567348
# epoch:  61 train_loss: 0.07197597
# epoch:  61 train_accuracy: 0.97867869
# epoch:  61 val_loss: 0.09189397
# epoch:  61 val_accuracy: 0.97625358
# epoch:  62 train_loss: 0.07142224
# epoch:  62 train_accuracy: 0.97864245
# epoch:  62 val_loss: 0.09365577
# epoch:  62 val_accuracy: 0.97656486
# epoch:  63 train_loss: 0.07605478
# epoch:  63 train_accuracy: 0.97817501
# epoch:  63 val_loss: 0.08414381
# epoch:  63 val_accuracy: 0.97718741
# epoch:  64 train_loss: 0.07436551
# epoch:  64 train_accuracy: 0.97819796
# epoch:  64 val_loss: 0.08052159
# epoch:  64 val_accuracy: 0.97734776
# epoch:  65 train_loss: 0.07411889
# epoch:  65 train_accuracy: 0.97766166
# epoch:  65 val_loss: 0.09255533
# epoch:  65 val_accuracy: 0.97547068
# epoch:  66 train_loss: 0.07239271
# epoch:  66 train_accuracy: 0.97878136
# epoch:  66 val_loss: 0.08703136
# epoch:  66 val_accuracy: 0.97567348
# epoch:  67 train_loss: 0.06982517
# epoch:  67 train_accuracy: 0.97926088
# epoch:  67 val_loss: 0.09205103
# epoch:  67 val_accuracy: 0.97636206
# epoch:  68 train_loss: 0.06989831
# epoch:  68 train_accuracy: 0.97978268
# epoch:  68 val_loss: 0.08639437
# epoch:  68 val_accuracy: 0.97651770
# epoch:  69 train_loss: 0.07083160
# epoch:  69 train_accuracy: 0.97945535
# epoch:  69 val_loss: 0.07898426
# epoch:  69 val_accuracy: 0.97698932
# epoch:  70 train_loss: 0.06880476
# epoch:  70 train_accuracy: 0.97993246
# epoch:  70 val_loss: 0.09342289
# epoch:  70 val_accuracy: 0.97510753
# epoch:  71 train_loss: 0.06848259
# epoch:  71 train_accuracy: 0.98003996
# epoch:  71 val_loss: 0.08222258
# epoch:  71 val_accuracy: 0.97697517
# epoch:  72 train_loss: 0.06736995
# epoch:  72 train_accuracy: 0.97989018
# epoch:  72 val_loss: 0.08672208
# epoch:  72 val_accuracy: 0.97565462
# epoch:  73 train_loss: 0.06821198
# epoch:  73 train_accuracy: 0.97943119
# epoch:  73 val_loss: 0.10562518
# epoch:  73 val_accuracy: 0.97419729
# epoch:  74 train_loss: 0.06956390
# epoch:  74 train_accuracy: 0.97992762
# epoch:  74 val_loss: 0.09418012
# epoch:  74 val_accuracy: 0.97493303
# epoch:  75 train_loss: 0.06722307
# epoch:  75 train_accuracy: 0.98014142
# epoch:  75 val_loss: 0.10858096
# epoch:  75 val_accuracy: 0.97340967
# epoch:  76 train_loss: 0.06854583
# epoch:  76 train_accuracy: 0.98005324
# epoch:  76 val_loss: 0.10538955
# epoch:  76 val_accuracy: 0.97492831
# epoch:  77 train_loss: 0.06576261
# epoch:  77 train_accuracy: 0.98068979
# epoch:  77 val_loss: 0.10462203
# epoch:  77 val_accuracy: 0.97441896
# epoch:  78 train_loss: 0.06500591
# epoch:  78 train_accuracy: 0.98043251
# epoch:  78 val_loss: 0.09700277
# epoch:  78 val_accuracy: 0.97512168
# epoch:  79 train_loss: 0.06616984
# epoch:  79 train_accuracy: 0.98027549
# epoch:  79 val_loss: 0.10265995
# epoch:  79 val_accuracy: 0.97464062
# epoch:  80 train_loss: 0.06465191
# epoch:  80 train_accuracy: 0.98088184
# epoch:  80 val_loss: 0.10478661
# epoch:  80 val_accuracy: 0.97419257
# epoch:  81 train_loss: 0.06377080
# epoch:  81 train_accuracy: 0.98134566
# epoch:  81 val_loss: 0.10374140
# epoch:  81 val_accuracy: 0.97256546
# epoch:  82 train_loss: 0.06368292
# epoch:  82 train_accuracy: 0.98103645
# epoch:  82 val_loss: 0.10417551
# epoch:  82 val_accuracy: 0.97448027
# epoch:  83 train_loss: 0.06219352
# epoch:  83 train_accuracy: 0.98187350
# epoch:  83 val_loss: 0.10516504
# epoch:  83 val_accuracy: 0.97585742
# epoch:  84 train_loss: 0.06258543
# epoch:  84 train_accuracy: 0.98118139
# epoch:  84 val_loss: 0.10823199
# epoch:  84 val_accuracy: 0.97514054
# epoch:  85 train_loss: 0.06227211
# epoch:  85 train_accuracy: 0.98131909
# epoch:  85 val_loss: 0.11494558
# epoch:  85 val_accuracy: 0.97373510
# epoch:  86 train_loss: 0.06233989
# epoch:  86 train_accuracy: 0.98131305
# epoch:  86 val_loss: 0.11982208
# epoch:  86 val_accuracy: 0.97353701
# epoch:  87 train_loss: 0.06333175
# epoch:  87 train_accuracy: 0.98118019
# epoch:  87 val_loss: 0.12157549
# epoch:  87 val_accuracy: 0.97291918
# epoch:  88 train_loss: 0.06335437
# epoch:  88 train_accuracy: 0.98122729
# epoch:  88 val_loss: 0.11848536
# epoch:  88 val_accuracy: 0.97390960
# epoch:  89 train_loss: 0.06231532
# epoch:  89 train_accuracy: 0.98181552
# epoch:  89 val_loss: 0.10488097
# epoch:  89 val_accuracy: 0.97448970
# epoch:  90 train_loss: 0.06445185
# epoch:  90 train_accuracy: 0.98111858
# epoch:  90 val_loss: 0.11286341
# epoch:  90 val_accuracy: 0.97435764
# epoch:  91 train_loss: 0.06151728
# epoch:  91 train_accuracy: 0.98172493
# epoch:  91 val_loss: 0.11361645
# epoch:  91 val_accuracy: 0.97491416
# epoch:  92 train_loss: 0.06225710
# epoch:  92 train_accuracy: 0.98138311
# epoch:  92 val_loss: 0.11186844
# epoch:  92 val_accuracy: 0.97353230
# epoch:  93 train_loss: 0.06291392
# epoch:  93 train_accuracy: 0.98121642
# epoch:  93 val_loss: 0.10709516
# epoch:  93 val_accuracy: 0.97507923
# epoch:  94 train_loss: 0.06180771
# epoch:  94 train_accuracy: 0.98118260
# epoch:  94 val_loss: 0.10195320
# epoch:  94 val_accuracy: 0.97427747
# epoch:  95 train_loss: 0.06478514
# epoch:  95 train_accuracy: 0.98050499
# epoch:  95 val_loss: 0.10812746
# epoch:  95 val_accuracy: 0.97372095
# epoch:  96 train_loss: 0.06546568
# epoch:  96 train_accuracy: 0.98121884
# epoch:  96 val_loss: 0.10692029
# epoch:  96 val_accuracy: 0.97471136
# epoch:  97 train_loss: 0.06229989
# epoch:  97 train_accuracy: 0.98188075
# epoch:  97 val_loss: 0.10742891
# epoch:  97 val_accuracy: 0.97501792
# epoch:  98 train_loss: 0.06268861
# epoch:  98 train_accuracy: 0.98154979
# epoch:  98 val_loss: 0.12481334
# epoch:  98 val_accuracy: 0.97526317
# epoch:  99 train_loss: 0.06314919
# epoch:  99 train_accuracy: 0.98115361
# epoch:  99 val_loss: 0.09488117
# epoch:  99 val_accuracy: 0.97732889

# %%
import matplotlib.pyplot as plt

print('训练过程的损失随epoch变化趋势：')
plt.plot(train_loss_record, label='train_loss')
plt.plot(val_loss_record, label='val_loss')
plt.legend()
plt.show()

print('训练过程的准确率随epoch变化趋势：')
plt.plot(train_accuracy_record, label='train_accuracy')
plt.plot(val_accuracy_record, label='val_accuracy')
plt.legend()
plt.show()
# Out:
# 训练过程的损失随epoch变化趋势：
# 训练过程的准确率随epoch变化趋势：

# %% [markdown]
# ## 6. 验证模型，绘制结果

# %%
epoch_loss = 0
epoch_acc = 0
predicted_labels = []  # 模型结果标签，用于混淆矩阵
true_labels = []  # 模型真值标签，用于混淆矩阵

model.eval()
with torch.no_grad():
    for seq, labels in test_data:
        x,y = seq.to(device), labels.to(device)
        y_pred = model(x)
        y_pred = torch.squeeze(y_pred, dim=1) # 去除额外维度
        single_loss = loss_function(y_pred, y)
        
        # 获取预测正确的样本个数，由于pred为最大值所在位置的索引，
        # 因此不需要将label_test转换为one_hot编码
        # 当tensor为标量的时候，tensor.item()可以将其转换为ndarray类型
        # correct = pred.eq(label_test).sum().float().item()
        correct = torch.eq(y.argmax(dim=1), y_pred.argmax(dim=1))
        predicted_labels += y_pred.argmax(dim=1).tolist()
        true_labels += y.argmax(dim=1).tolist()
        
        epoch_acc += correct.sum().item()/ y.shape[0]
        epoch_loss += single_loss.item()

# 去平均
epoch_loss /= len(test_data)
epoch_acc /= len(test_data)

print(f'测试集平均损失：{epoch_loss}, \n测试集平均准确率：{epoch_acc}')
# Out:
# 测试集平均损失：0.09521899253798752,
# 测试集平均准确率：0.9773854889827951

# %% [markdown]
# ### 修改结果储存路径，并存储结果

# %%
# 绘制混淆矩阵
# 混淆矩阵
from sklearn.metrics import confusion_matrix
# 初始化混淆矩阵
num_classes = 5
conf_matrix = np.zeros((num_classes, num_classes), dtype=int)
# 更新混淆矩阵
conf_matrix += confusion_matrix(true_labels, predicted_labels, labels=range(num_classes))
# 打印混淆矩阵
print("Confusion Matrix:")
print(conf_matrix)

plt.figure(figsize=(12, 9))
# 设置颜色映射
cmap = plt.cm.Blues
# 绘制混淆矩阵图
plt.imshow(conf_matrix, interpolation='nearest', cmap=cmap)
# 添加文字标签
for i in range(len(conf_matrix)):
    for j in range(len(conf_matrix)):
        plt.text(j, i, conf_matrix[i, j], ha='center', va='center', color='black')
# 添加颜色条
plt.colorbar()
# 添加标题和标签
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
# 显示图形
plt.show()
# Out:
# Confusion Matrix:
# [[ 2938     0     1   264     0]
#  [    0 23273   806     4    53]
#  [   32  1241 81309   450   122]
#  [  242    33   721 62776     3]
#  [    0     4   110   709 36906]]

# %%
# 绘制百分比混淆矩阵
from sklearn.metrics import confusion_matrix

num_classes = 5
conf_matrix = np.zeros((num_classes, num_classes), dtype=int)
conf_matrix += confusion_matrix(true_labels, predicted_labels, labels=range(num_classes))

# 转换为百分比混淆矩阵
conf_matrix_percentage = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis] * 100

# 打印混淆矩阵
print("Confusion Matrix (Percentage):")
print(conf_matrix_percentage)

# 绘制百分比混淆矩阵
plt.figure(figsize=(16, 12))
cmap = plt.cm.Blues
plt.imshow(conf_matrix_percentage, interpolation='nearest', cmap=cmap)

# 添加文字标签
for i in range(num_classes):
    for j in range(num_classes):
        plt.text(j, i, f'{conf_matrix_percentage[i, j]:.1f}%', ha='center', va='center', color='black')

# 添加颜色条
plt.colorbar()

# 添加标题和标签
plt.title('Confusion Matrix (Percentage)')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')

# 显示图形
plt.show()
# Out:
# Confusion Matrix (Percentage):
# [[9.17265064e+01 0.00000000e+00 3.12207306e-02 8.24227287e+00
#   0.00000000e+00]
#  [0.00000000e+00 9.64244282e+01 3.33941001e+00 1.65727544e-02
#   2.19588996e-01]
#  [3.84828150e-02 1.49241167e+00 9.77812252e+01 5.41164586e-01
#   1.46715732e-01]
#  [3.79459036e-01 5.17444140e-02 1.13053704e+00 9.84335555e+01
#   4.70403763e-03]
#  [0.00000000e+00 1.06019242e-02 2.91552917e-01 1.87919107e+00
#   9.78186541e+01]]

# %%
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# 计算总体的准确率、精确率、召回率、F1分数
def calculate_metrics_overall_by_sklearn(matrix):
    # 提取真实标签和预测标签
    true_labels = []
    pred_labels = []

    num_classes = matrix.shape[0]

    for i in range(num_classes):
        for j in range(num_classes):
            true_labels.extend([i] * matrix[i, j])
            pred_labels.extend([j] * matrix[i, j])

    # 计算总体的准确率、精确率、召回率和F1分数
    overall_accuracy = accuracy_score(true_labels, pred_labels)
    overall_precision = precision_score(true_labels, pred_labels, average='macro')
    overall_recall = recall_score(true_labels, pred_labels, average='macro')
    overall_f1 = f1_score(true_labels, pred_labels, average='macro')

    return overall_precision, overall_recall, overall_f1, overall_accuracy

real_overall_precision, real_overall_recall, real_overall_f1_score, real_overall_accuracy = calculate_metrics_overall_by_sklearn(conf_matrix)
print("总体精确率（Precision）: ", real_overall_precision)
print("总体召回率（Recall）: ", real_overall_recall)
print("总体F1 分数（F1 Score）: ", real_overall_f1_score)
print("总体准确率（Accuracy）: ", real_overall_accuracy)
# Out:
# 总体精确率（Precision）:  0.9631732297938133
# 总体召回率（Recall）:  0.9643687387820133
# 总体F1 分数（F1 Score）:  0.9637395636927557
# 总体准确率（Accuracy）:  0.9773817554021991
