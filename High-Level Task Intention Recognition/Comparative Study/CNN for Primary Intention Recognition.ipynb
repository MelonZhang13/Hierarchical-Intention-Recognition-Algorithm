# %%
import pandas as pd

import torch
import torch.nn as nn
import torch.nn.functional as F

from sklearn.preprocessing import OneHotEncoder

# %% [markdown]
# ## 1. 读取结构化数据集

# %%
df = pd.read_csv(f'../Dataset/Final_Dataset_2.csv')
df = df.drop(columns=['Time', 'Secondary Intent'])
df.head()
# Out:
#    User  ID  Hotas_Axis_X  Hotas_Axis_Y  Hotas_Axis_Z  Hotas_Btn_Create_Fleet  \
# 0     1   1           0.0           0.0     -0.307087                   False
# 1     1   1           0.0           0.0     -0.307087                   False
# 2     1   1           0.0           0.0     -0.307087                   False
# 3     1   1           0.0           0.0     -0.307087                   False
# 4     1   1           0.0           0.0     -0.307087                   False
#
#    Hotas_Btn_Select_UAV1  Hotas_Btn_Select_UAV2  Hotas_Btn_Select_UAV3  \
# 0                  False                  False                  False
# 1                  False                  False                  False
# 2                  False                  False                  False
# 3                  False                  False                  False
# 4                  False                  False                  False
#
#    Hotas_Btn_Select_UAV4  ...  Target_Area_State  Target_Area_Pos_X  \
# 0                  False  ...              False               -1.0
# 1                  False  ...              False               -1.0
# 2                  False  ...              False               -1.0
# 3                  False  ...              False               -1.0
# 4                  False  ...              False               -1.0
#
#    Target_Area_Pos_Y  Trapped_People_State  Trapped_People_Pos_X  \
# 0               -1.0                 False                  -1.0
# 1               -1.0                 False                  -1.0
# 2               -1.0                 False                  -1.0
# 3               -1.0                 False                  -1.0
# 4               -1.0                 False                  -1.0
#
#    Trapped_People_Pos_Y  Gaze point X  Gaze point Y  AOI  Primary Intent
# 0                  -1.0        2067.0        1195.0    4        Intent_0
# 1                  -1.0        2046.0        1204.0    4        Intent_0
# 2                  -1.0        2046.0        1200.0    4        Intent_0
# 3                  -1.0        2053.0        1221.0    4        Intent_0
# 4                  -1.0        2068.0        1209.0    4        Intent_0
#
# [5 rows x 55 columns]

# %%
df['New Intent'] = None
for index, row in df.iterrows():
    if row['Primary Intent'] == 'Intent_0':
        df.at[index, 'New Intent'] = '00'
    if row['Primary Intent'] == 'Intent_1':
        df.at[index, 'New Intent'] = '01'
    if row['Primary Intent'] == 'Intent_2':
        df.at[index, 'New Intent'] = '02'
    if row['Primary Intent'] == 'Intent_3':
        df.at[index, 'New Intent'] = '03'
    if row['Primary Intent'] == 'Intent_4':
        df.at[index, 'New Intent'] = '04'
    if row['Primary Intent'] == 'Intent_5':
        df.at[index, 'New Intent'] = '05'
   

df.drop(columns=['Primary Intent'], inplace=True)
df.rename(columns={'New Intent': 'Intent'}, inplace=True)
df.head()
# Out:
#    User  ID  Hotas_Axis_X  Hotas_Axis_Y  Hotas_Axis_Z  Hotas_Btn_Create_Fleet  \
# 0     1   1           0.0           0.0     -0.307087                   False
# 1     1   1           0.0           0.0     -0.307087                   False
# 2     1   1           0.0           0.0     -0.307087                   False
# 3     1   1           0.0           0.0     -0.307087                   False
# 4     1   1           0.0           0.0     -0.307087                   False
#
#    Hotas_Btn_Select_UAV1  Hotas_Btn_Select_UAV2  Hotas_Btn_Select_UAV3  \
# 0                  False                  False                  False
# 1                  False                  False                  False
# 2                  False                  False                  False
# 3                  False                  False                  False
# 4                  False                  False                  False
#
#    Hotas_Btn_Select_UAV4  ...  Target_Area_State  Target_Area_Pos_X  \
# 0                  False  ...              False               -1.0
# 1                  False  ...              False               -1.0
# 2                  False  ...              False               -1.0
# 3                  False  ...              False               -1.0
# 4                  False  ...              False               -1.0
#
#    Target_Area_Pos_Y  Trapped_People_State  Trapped_People_Pos_X  \
# 0               -1.0                 False                  -1.0
# 1               -1.0                 False                  -1.0
# 2               -1.0                 False                  -1.0
# 3               -1.0                 False                  -1.0
# 4               -1.0                 False                  -1.0
#
#    Trapped_People_Pos_Y  Gaze point X  Gaze point Y  AOI  Intent
# 0                  -1.0        2067.0        1195.0    4      00
# 1                  -1.0        2046.0        1204.0    4      00
# 2                  -1.0        2046.0        1200.0    4      00
# 3                  -1.0        2053.0        1221.0    4      00
# 4                  -1.0        2068.0        1209.0    4      00
#
# [5 rows x 55 columns]

# %%
# 离散特征变量使用One-Hot编码，通过DataFrame实现
df = pd.get_dummies(df, columns=['Flight_Fleet_State', 'Flight_Fly_Mode', 'UAV_Selected_Now', 'UAV1_Task_State', 'UAV2_Task_State',
                                 'UAV3_Task_State', 'UAV4_Task_State', 'AOI', 'Intent'])
df.head()
# Out:
#    User  ID  Hotas_Axis_X  Hotas_Axis_Y  Hotas_Axis_Z  Hotas_Btn_Create_Fleet  \
# 0     1   1           0.0           0.0     -0.307087                   False
# 1     1   1           0.0           0.0     -0.307087                   False
# 2     1   1           0.0           0.0     -0.307087                   False
# 3     1   1           0.0           0.0     -0.307087                   False
# 4     1   1           0.0           0.0     -0.307087                   False
#
#    Hotas_Btn_Select_UAV1  Hotas_Btn_Select_UAV2  Hotas_Btn_Select_UAV3  \
# 0                  False                  False                  False
# 1                  False                  False                  False
# 2                  False                  False                  False
# 3                  False                  False                  False
# 4                  False                  False                  False
#
#    Hotas_Btn_Select_UAV4  ...  AOI_3  AOI_4  AOI_5  AOI_6  Intent_00  \
# 0                  False  ...  False   True  False  False       True
# 1                  False  ...  False   True  False  False       True
# 2                  False  ...  False   True  False  False       True
# 3                  False  ...  False   True  False  False       True
# 4                  False  ...  False   True  False  False       True
#
#    Intent_01  Intent_02  Intent_03  Intent_04  Intent_05
# 0      False      False      False      False      False
# 1      False      False      False      False      False
# 2      False      False      False      False      False
# 3      False      False      False      False      False
# 4      False      False      False      False      False
#
# [5 rows x 85 columns]

# %%
# 设置训练集和测试集
train_ids = [i for i in range(1, 51) if i % 5 != 0]
test_ids = [i for i in range(1, 51) if i % 5 == 0]
print("train IDs:", train_ids)
print("test IDs:", test_ids)

df_train = df[df['ID'].isin(train_ids)]
df_test = df[df['ID'].isin(test_ids)]
print(df_train.shape, df_test.shape)
# Out:
# train IDs: [1, 2, 3, 4, 6, 7, 8, 9, 11, 12, 13, 14, 16, 17, 18, 19, 21, 22, 23, 24, 26, 27, 28, 29, 31, 32, 33, 34, 36, 37, 38, 39, 41, 42, 43, 44, 46, 47, 48, 49]
# test IDs: [5, 10, 15, 20, 25, 30, 35, 40, 45, 50]
# (941603, 85) (233086, 85)

# %%
# 数据归一化-训练集
df_train.loc[:, 'Hotas_Axis_X']  = (df_train['Hotas_Axis_X']+1)/2
df_train.loc[:, 'Hotas_Axis_Y']  = (df_train['Hotas_Axis_Y']+1)/2
df_train.loc[:, 'Hotas_Axis_Z']  = (df_train['Hotas_Axis_Z']+1)/2

df_train.loc[:, 'Flight_Pos_X']  = (df_train['Flight_Pos_X']-df_train['Flight_Pos_X'].min())/(df_train['Flight_Pos_X'].max()-df_train['Flight_Pos_X'].min())
df_train.loc[:, 'Flight_Pos_Y']  = (df_train['Flight_Pos_Y']-df_train['Flight_Pos_Y'].min())/(df_train['Flight_Pos_Y'].max()-df_train['Flight_Pos_Y'].min())
df_train.loc[:, 'Flight_Speed']  = (df_train['Flight_Speed']-df_train['Flight_Speed'].min())/(df_train['Flight_Speed'].max()-df_train['Flight_Speed'].min())
df_train.loc[:, 'Flight_Height']  = (df_train['Flight_Height']-df_train['Flight_Height'].min())/(df_train['Flight_Height'].max()-df_train['Flight_Height'].min())
df_train.loc[:, 'Flight_Heading']  = (df_train['Flight_Heading']-df_train['Flight_Heading'].min())/(df_train['Flight_Heading'].max()-df_train['Flight_Heading'].min())

df_train.loc[:, 'UAV1_Pos_X']  = df_train['UAV1_Pos_X']/3840
df_train.loc[:, 'UAV1_Pos_Y']  = df_train['UAV1_Pos_Y']/2160
df_train.loc[:, 'UAV2_Pos_X']  = df_train['UAV2_Pos_X']/3840
df_train.loc[:, 'UAV2_Pos_Y']  = df_train['UAV2_Pos_Y']/2160
df_train.loc[:, 'UAV3_Pos_X']  = df_train['UAV3_Pos_X']/3840
df_train.loc[:, 'UAV3_Pos_Y']  = df_train['UAV3_Pos_Y']/2160
df_train.loc[:, 'UAV4_Pos_X']  = df_train['UAV4_Pos_X']/3840
df_train.loc[:, 'UAV4_Pos_Y']  = df_train['UAV4_Pos_Y']/2160

df_train.loc[:, 'Target_Area_Pos_X']  = (df_train['Target_Area_Pos_X']-df_train['Target_Area_Pos_X'].min())/(df_train['Target_Area_Pos_X'].max()-df_train['Target_Area_Pos_X'].min())
df_train.loc[:, 'Target_Area_Pos_Y']  = (df_train['Target_Area_Pos_Y']-df_train['Target_Area_Pos_Y'].min())/(df_train['Target_Area_Pos_Y'].max()-df_train['Target_Area_Pos_Y'].min())
df_train.loc[:, 'Trapped_People_Pos_X']  = (df_train['Trapped_People_Pos_X']-df_train['Trapped_People_Pos_X'].min())/(df_train['Trapped_People_Pos_X'].max()-df_train['Trapped_People_Pos_X'].min())
df_train.loc[:, 'Trapped_People_Pos_Y']  = (df_train['Trapped_People_Pos_Y']-df_train['Trapped_People_Pos_Y'].min())/(df_train['Trapped_People_Pos_Y'].max()-df_train['Trapped_People_Pos_Y'].min())

df_train.loc[:, 'Gaze point X']  = df_train['Gaze point X']/3840
df_train.loc[:, 'Gaze point Y']  = df_train['Gaze point Y']/2160

# 数据归一化-测试集
df_test.loc[:, 'Hotas_Axis_X']  = (df_test['Hotas_Axis_X']+1)/2
df_test.loc[:, 'Hotas_Axis_Y']  = (df_test['Hotas_Axis_Y']+1)/2
df_test.loc[:, 'Hotas_Axis_Z']  = (df_test['Hotas_Axis_Z']+1)/2

df_test.loc[:, 'Flight_Pos_X']  = (df_test['Flight_Pos_X']-df_test['Flight_Pos_X'].min())/(df_test['Flight_Pos_X'].max()-df_test['Flight_Pos_X'].min())
df_test.loc[:, 'Flight_Pos_Y']  = (df_test['Flight_Pos_Y']-df_train['Flight_Pos_Y'].min())/(df_test['Flight_Pos_Y'].max()-df_test['Flight_Pos_Y'].min())
df_test.loc[:, 'Flight_Speed']  = (df_test['Flight_Speed']-df_train['Flight_Speed'].min())/(df_test['Flight_Speed'].max()-df_test['Flight_Speed'].min())
df_test.loc[:, 'Flight_Height']  = (df_test['Flight_Height']-df_test['Flight_Height'].min())/(df_test['Flight_Height'].max()-df_test['Flight_Height'].min())
df_test.loc[:, 'Flight_Heading']  = (df_test['Flight_Heading']-df_test['Flight_Heading'].min())/(df_test['Flight_Heading'].max()-df_test['Flight_Heading'].min())

df_test.loc[:, 'UAV1_Pos_X']  = df_test['UAV1_Pos_X']/3840
df_test.loc[:, 'UAV1_Pos_Y']  = df_test['UAV1_Pos_Y']/2160
df_test.loc[:, 'UAV2_Pos_X']  = df_test['UAV2_Pos_X']/3840
df_test.loc[:, 'UAV2_Pos_Y']  = df_test['UAV2_Pos_Y']/2160
df_test.loc[:, 'UAV3_Pos_X']  = df_test['UAV3_Pos_X']/3840
df_test.loc[:, 'UAV3_Pos_Y']  = df_test['UAV3_Pos_Y']/2160
df_test.loc[:, 'UAV4_Pos_X']  = df_test['UAV4_Pos_X']/3840
df_test.loc[:, 'UAV4_Pos_Y']  = df_test['UAV4_Pos_Y']/2160

df_test.loc[:, 'Target_Area_Pos_X']  = (df_test['Target_Area_Pos_X']-df_test['Target_Area_Pos_X'].min())/(df_test['Target_Area_Pos_X'].max()-df_test['Target_Area_Pos_X'].min())
df_test.loc[:, 'Target_Area_Pos_Y']  = (df_test['Target_Area_Pos_Y']-df_test['Target_Area_Pos_Y'].min())/(df_test['Target_Area_Pos_Y'].max()-df_test['Target_Area_Pos_Y'].min())
df_test.loc[:, 'Trapped_People_Pos_X']  = (df_test['Trapped_People_Pos_X']-df_test['Trapped_People_Pos_X'].min())/(df_test['Trapped_People_Pos_X'].max()-df_test['Trapped_People_Pos_X'].min())
df_test.loc[:, 'Trapped_People_Pos_Y']  = (df_test['Trapped_People_Pos_Y']-df_test['Trapped_People_Pos_Y'].min())/(df_test['Trapped_People_Pos_Y'].max()-df_test['Trapped_People_Pos_Y'].min())

df_test.loc[:, 'Gaze point X']  = df_test['Gaze point X']/3840
df_test.loc[:, 'Gaze point Y']  = df_test['Gaze point Y']/2160

pd.set_option('display.max_columns', None)
df_train.head()
# Out:
#    User  ID  Hotas_Axis_X  Hotas_Axis_Y  Hotas_Axis_Z  Hotas_Btn_Create_Fleet  \
# 0     1   1           0.5           0.5      0.346457                   False
# 1     1   1           0.5           0.5      0.346457                   False
# 2     1   1           0.5           0.5      0.346457                   False
# 3     1   1           0.5           0.5      0.346457                   False
# 4     1   1           0.5           0.5      0.346457                   False
#
#    Hotas_Btn_Select_UAV1  Hotas_Btn_Select_UAV2  Hotas_Btn_Select_UAV3  \
# 0                  False                  False                  False
# 1                  False                  False                  False
# 2                  False                  False                  False
# 3                  False                  False                  False
# 4                  False                  False                  False
#
#    Hotas_Btn_Select_UAV4  Hotas_Btn_Assign_Up  Hotas_Btn_Assign_Down  \
# 0                  False                False                  False
# 1                  False                False                  False
# 2                  False                False                  False
# 3                  False                False                  False
# 4                  False                False                  False
#
#    Hotas_Btn_Assign_Left  Hotas_Btn_Assign_Right  Hotas_Btn_Change_Mode  \
# 0                  False                   False                  False
# 1                  False                   False                  False
# 2                  False                   False                  False
# 3                  False                   False                  False
# 4                  False                   False                  False
#
#    Hotas_Btn_Open_UAV_Sensor  Hotas_Btn_Open_Helicopter_Sensor  \
# 0                      False                             False
# 1                      False                             False
# 2                      False                             False
# 3                      False                             False
# 4                      False                             False
#
#    Hotas_Btn_Select_Normal  Hotas_Btn_Select_Fire  Hotas_Btn_Select_Person  \
# 0                    False                  False                    False
# 1                    False                  False                    False
# 2                    False                  False                    False
# 3                    False                  False                    False
# 4                    False                  False                    False
#
#    Hotas_Btn_Submit_Result  Hotas_Btn_Area_Assign  Flight_Pos_X  Flight_Pos_Y  \
# 0                    False                  False        0.4499      0.127802
# 1                    False                  False        0.4499      0.127802
# 2                    False                  False        0.4499      0.127802
# 3                    False                  False        0.4499      0.127802
# 4                    False                  False        0.4499      0.127802
#
#    Flight_Speed  Flight_Height  Flight_Heading  Flight_Sensor  UAV1_Pos_X  \
# 0           0.0        0.40634        0.000016          False    0.495825
# 1           0.0        0.40634        0.000016          False    0.495825
# 2           0.0        0.40634        0.000016          False    0.495825
# 3           0.0        0.40634        0.000016          False    0.495825
# 4           0.0        0.40634        0.000016          False    0.495825
#
#    UAV1_Pos_Y  UAV2_Pos_X  UAV2_Pos_Y  UAV3_Pos_X  UAV3_Pos_Y  UAV4_Pos_X  \
# 0      0.1839    0.534825      0.1839    0.495825    0.130567    0.534825
# 1      0.1839    0.534825      0.1839    0.495825    0.130567    0.534825
# 2      0.1839    0.534825      0.1839    0.495825    0.130567    0.534825
# 3      0.1839    0.534825      0.1839    0.495825    0.130567    0.534825
# 4      0.1839    0.534825      0.1839    0.495825    0.130567    0.534825
#
#    UAV4_Pos_Y  UAV_Sensor_State  Task_List_State  Target_Area_State  \
# 0    0.130567             False             True              False
# 1    0.130567             False             True              False
# 2    0.130567             False             True              False
# 3    0.130567             False             True              False
# 4    0.130567             False             True              False
#
#    Target_Area_Pos_X  Target_Area_Pos_Y  Trapped_People_State  \
# 0                0.0                0.0                 False
# 1                0.0                0.0                 False
# 2                0.0                0.0                 False
# 3                0.0                0.0                 False
# 4                0.0                0.0                 False
#
#    Trapped_People_Pos_X  Trapped_People_Pos_Y  Gaze point X  Gaze point Y  \
# 0                   0.0                   0.0      0.538281      0.553241
# 1                   0.0                   0.0      0.532813      0.557407
# 2                   0.0                   0.0      0.532813      0.555556
# 3                   0.0                   0.0      0.534635      0.565278
# 4                   0.0                   0.0      0.538542      0.559722
#
#    Flight_Fleet_State_0  Flight_Fleet_State_1  Flight_Fleet_State_2  \
# 0                  True                 False                 False
# 1                  True                 False                 False
# 2                  True                 False                 False
# 3                  True                 False                 False
# 4                  True                 False                 False
#
#    Flight_Fly_Mode_0  Flight_Fly_Mode_1  UAV_Selected_Now_-1.0  \
# 0               True              False                   True
# 1               True              False                   True
# 2               True              False                   True
# 3               True              False                   True
# 4               True              False                   True
#
#    UAV_Selected_Now_1.0  UAV_Selected_Now_2.0  UAV_Selected_Now_3.0  \
# 0                 False                 False                 False
# 1                 False                 False                 False
# 2                 False                 False                 False
# 3                 False                 False                 False
# 4                 False                 False                 False
#
#    UAV_Selected_Now_4.0  UAV1_Task_State_0  UAV1_Task_State_1  \
# 0                 False               True              False
# 1                 False               True              False
# 2                 False               True              False
# 3                 False               True              False
# 4                 False               True              False
#
#    UAV1_Task_State_2  UAV1_Task_State_3  UAV2_Task_State_0  UAV2_Task_State_1  \
# 0              False              False               True              False
# 1              False              False               True              False
# 2              False              False               True              False
# 3              False              False               True              False
# 4              False              False               True              False
#
#    UAV2_Task_State_2  UAV2_Task_State_3  UAV3_Task_State_0  UAV3_Task_State_1  \
# 0              False              False               True              False
# 1              False              False               True              False
# 2              False              False               True              False
# 3              False              False               True              False
# 4              False              False               True              False
#
#    UAV3_Task_State_2  UAV3_Task_State_3  UAV4_Task_State_0  UAV4_Task_State_1  \
# 0              False              False               True              False
# 1              False              False               True              False
# 2              False              False               True              False
# 3              False              False               True              False
# 4              False              False               True              False
#
#    UAV4_Task_State_2  UAV4_Task_State_3  AOI_0  AOI_1  AOI_2  AOI_3  AOI_4  \
# 0              False              False  False  False  False  False   True
# 1              False              False  False  False  False  False   True
# 2              False              False  False  False  False  False   True
# 3              False              False  False  False  False  False   True
# 4              False              False  False  False  False  False   True
#
#    AOI_5  AOI_6  Intent_00  Intent_01  Intent_02  Intent_03  Intent_04  \
# 0  False  False       True      False      False      False      False
# 1  False  False       True      False      False      False      False
# 2  False  False       True      False      False      False      False
# 3  False  False       True      False      False      False      False
# 4  False  False       True      False      False      False      False
#
#    Intent_05
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False

# %% [markdown]
# ## 2. 定义Dataset和DataLoader

# %%
from torch.utils.data import DataLoader, Dataset
import numpy as np

class MyDataset(Dataset):
    # 实例化调用，数据集初始化
    def __init__(self, df, time_step):
        # 初始化输入输出
        x = []
        y = []
        num_intent_0 = 0
        
        # 根据test_id划分DataFrame
        grouped = df.groupby('ID')
        
        for _, group in grouped:
            # test_id放在最后
            origin_data = group.drop(columns=['ID', 'User'])
            # 将表格中的bool型转换为int型
            for column in origin_data.columns:
                if origin_data[column].dtype == bool:
                    origin_data[column] = origin_data[column].astype(int)
            # 将表格数据转换为Numpy
            dataset = (origin_data).to_numpy()
            for i in range(len(dataset) - time_step):
                input_seq = dataset[i:(i+time_step), 0:-6]
                output_seq = dataset[i+time_step-1, -6:]
                
#                 x.append(input_seq)
#                 y.append(output_seq)
                
                if output_seq[0] == 1:
                    num_intent_0 += 1
                else:
                    x.append(input_seq)
                    y.append(output_seq[1:])
        
        x = np.array(x)
        y = np.array(y)
        print(f'shape_input:{x.shape},shape_output:{y.shape}')
        print(f'delete Intent_0:{num_intent_0}')
        
        self.data_tensor = torch.tensor(x, dtype=torch.float32)
        self.label_tensor = torch.tensor(y, dtype=torch.float32)
    
    # 返回数据集的长度    
    def __len__(self):
        return self.data_tensor.shape[0]
    
    # 根据指定下标返回数据集内容    
    def __getitem__(self, i):
        # 读取数据
        data = self.data_tensor[i]
        # 读取标签
        label = self.label_tensor[i]

        return data, label  # 返回数据和标签
  
train_dataset = MyDataset(df_train, 20)
test_dataset = MyDataset(df_test, 20)

# 加载数据集
train_data = DataLoader(train_dataset, batch_size=64, shuffle=False) # shuffle是否打乱
test_data = DataLoader(test_dataset, batch_size=64, shuffle=False)

print(f'输入张量：{train_dataset.data_tensor.shape} 输出张量：{train_dataset.label_tensor.shape}')
# Out:
# shape_input:(827893, 20, 77),shape_output:(827893, 5)
# delete Intent_0:112910
# shape_input:(211997, 20, 77),shape_output:(211997, 5)
# delete Intent_0:20889
# 输入张量：torch.Size([827893, 20, 77]) 输出张量：torch.Size([827893, 5])

# %% [markdown]
# ## 3. 定义LSTM模型

# %% [markdown]
# ### 模型1:CNN模型

# %%
class CNN(nn.Module):
    def __init__(self, input_size=77, hidden_size=128, output_size=5, num_layers=3, bidirectional=True, num_cnn_filters=16, kernel_size=3):
        super().__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.num_layers = num_layers
        self.bidirectional = bidirectional
        self.num_directions = 2 if bidirectional else 1 # 单向LSTM模型
        self.num_cnn_filters = num_cnn_filters
        self.kernel_size = kernel_size
        
        self.conv1 = nn.Conv1d(self.input_size, self.num_cnn_filters, self.kernel_size, padding=1)
        self.relu = nn.ReLU()
        self.linear = nn.Linear(self.num_cnn_filters, self.output_size)

    def forward(self, input_seq):
        batch_size, seq_len = input_seq.shape[0], input_seq.shape[1]
        h_0 = torch.randn(self.num_directions * self.num_layers, batch_size, self.hidden_size).to(device)
        c_0 = torch.randn(self.num_directions * self.num_layers, batch_size, self.hidden_size).to(device)
        
        # change shape to (batch_size, input_size, seq_len) for Conv1d
        input_seq = input_seq.transpose(1, 2)
        cnn_out = self.conv1(input_seq)
        cnn_out = self.relu(cnn_out)
        cnn_out = cnn_out.transpose(1, 2) # change shape to (batch_size, seq_len, input_size) for LSTM
        
        predictions = self.linear(cnn_out[:,-1,:])# LSTM只输出最后一个时间步
        return predictions

# %% [markdown]
# ## 4. 实例化模型，定义超参数

# %%
device = 'cuda'
model = CNN().to(device)
# 损失函数
loss_function = nn.CrossEntropyLoss()
# 优化器
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %% [markdown]
# ## 5. 训练模型

# %%
epochs = 100
train_loss_record = []
train_accuracy_record = []
val_loss_record = []
val_accuracy_record = []

for i in range(epochs):
    # 模型训练
    model.train()
    train_loss = 0
    train_accuracy = 0
    
    for seq, labels in train_data:
        optimizer.zero_grad()
        x,y = seq.to(device), labels.to(device)
        y_pred = model(x)
        y_pred = torch.squeeze(y_pred, dim=1) # 去除额外维度
        loss = loss_function(y_pred, y)
        loss.backward()
        optimizer.step()
        
        # 计算训练准确率
        train_loss += loss.item()
        train_correct = torch.eq(y.argmax(dim=1), y_pred.argmax(dim=1))
        train_accuracy += train_correct.sum().item()/ y.shape[0]

    # if i%1 == 1:
    avg_train_loss = train_loss / len(train_data)
    print(f'epoch: {i:3} train_loss: {avg_train_loss:10.8f}')
    train_loss_record.append(avg_train_loss)
    
    avg_train_accuracy = train_accuracy / len(train_data)
    print(f'epoch: {i:3} train_accuracy: {avg_train_accuracy:10.8f}')
    train_accuracy_record.append(avg_train_accuracy)
    

    # 模型验证
    model.eval()
    val_loss = 0
    val_accuracy = 0
    
    with torch.no_grad():
        for seq, labels in test_data:
            x,y = seq.to(device), labels.to(device)
            y_pred = model(x)
            y_pred = torch.squeeze(y_pred, dim=1) # 去除额外维度
            loss = loss_function(y_pred, y)
            val_loss += loss.item()
            val_correct = torch.eq(y.argmax(dim=1), y_pred.argmax(dim=1))
            val_accuracy += val_correct.sum().item()/ y.shape[0]
    
    avg_val_loss = val_loss / len(test_data)
    print(f'epoch: {i:3} val_loss: {avg_val_loss:10.8f}')
    val_loss_record.append(avg_val_loss)
    
    avg_val_accuracy = val_accuracy / len(test_data)
    print(f'epoch: {i:3} val_accuracy: {avg_val_accuracy:10.8f}')
    val_accuracy_record.append(avg_val_accuracy)
# Out:
# epoch:   0 train_loss: 0.33794985
# epoch:   0 train_accuracy: 0.87356384
# epoch:   0 val_loss: 0.17530057
# epoch:   0 val_accuracy: 0.94667314
# epoch:   1 train_loss: 0.18753810
# epoch:   1 train_accuracy: 0.94201622
# epoch:   1 val_loss: 0.14647392
# epoch:   1 val_accuracy: 0.95894959
# epoch:   2 train_loss: 0.16737722
# epoch:   2 train_accuracy: 0.94708082
# epoch:   2 val_loss: 0.12589541
# epoch:   2 val_accuracy: 0.96604758
# epoch:   3 train_loss: 0.15350119
# epoch:   3 train_accuracy: 0.95316848
# epoch:   3 val_loss: 0.11460985
# epoch:   3 val_accuracy: 0.96696253
# epoch:   4 train_loss: 0.14121527
# epoch:   4 train_accuracy: 0.95626063
# epoch:   4 val_loss: 0.09738805
# epoch:   4 val_accuracy: 0.97135338
# epoch:   5 train_loss: 0.13321449
# epoch:   5 train_accuracy: 0.95908342
# epoch:   5 val_loss: 0.09482838
# epoch:   5 val_accuracy: 0.97131093
# epoch:   6 train_loss: 0.12685266
# epoch:   6 train_accuracy: 0.96007146
# epoch:   6 val_loss: 0.09897068
# epoch:   6 val_accuracy: 0.97017431
# epoch:   7 train_loss: 0.12063315
# epoch:   7 train_accuracy: 0.96209222
# epoch:   7 val_loss: 0.10032639
# epoch:   7 val_accuracy: 0.97068367
# epoch:   8 train_loss: 0.11817816
# epoch:   8 train_accuracy: 0.96297880
# epoch:   8 val_loss: 0.10561618
# epoch:   8 val_accuracy: 0.97117416
# epoch:   9 train_loss: 0.11563868
# epoch:   9 train_accuracy: 0.96494521
# epoch:   9 val_loss: 0.10219314
# epoch:   9 val_accuracy: 0.97282957
# epoch:  10 train_loss: 0.11230041
# epoch:  10 train_accuracy: 0.96633305
# epoch:  10 val_loss: 0.10705448
# epoch:  10 val_accuracy: 0.97169295
# epoch:  11 train_loss: 0.11097609
# epoch:  11 train_accuracy: 0.96712058
# epoch:  11 val_loss: 0.10269800
# epoch:  11 val_accuracy: 0.97138168
# epoch:  12 train_loss: 0.10905723
# epoch:  12 train_accuracy: 0.96761460
# epoch:  12 val_loss: 0.10550409
# epoch:  12 val_accuracy: 0.97169295
# epoch:  13 train_loss: 0.10477640
# epoch:  13 train_accuracy: 0.96845166
# epoch:  13 val_loss: 0.10844480
# epoch:  13 val_accuracy: 0.97068839
# epoch:  14 train_loss: 0.10260787
# epoch:  14 train_accuracy: 0.96883817
# epoch:  14 val_loss: 0.08895868
# epoch:  14 val_accuracy: 0.97204667
# epoch:  15 train_loss: 0.10703010
# epoch:  15 train_accuracy: 0.96852292
# epoch:  15 val_loss: 0.10641461
# epoch:  15 val_accuracy: 0.97188160
# epoch:  16 train_loss: 0.10076459
# epoch:  16 train_accuracy: 0.96983829
# epoch:  16 val_loss: 0.10673858
# epoch:  16 val_accuracy: 0.96963194
# epoch:  17 train_loss: 0.09827397
# epoch:  17 train_accuracy: 0.97054973
# epoch:  17 val_loss: 0.09421745
# epoch:  17 val_accuracy: 0.97320216
# epoch:  18 train_loss: 0.09848508
# epoch:  18 train_accuracy: 0.97115849
# epoch:  18 val_loss: 0.09232348
# epoch:  18 val_accuracy: 0.97074498
# epoch:  19 train_loss: 0.10234759
# epoch:  19 train_accuracy: 0.97192911
# epoch:  19 val_loss: 0.09937017
# epoch:  19 val_accuracy: 0.97292390
# epoch:  20 train_loss: 0.09771240
# epoch:  20 train_accuracy: 0.96999652
# epoch:  20 val_loss: 0.09606238
# epoch:  20 val_accuracy: 0.97334836
# epoch:  21 train_loss: 0.09867360
# epoch:  21 train_accuracy: 0.97107153
# epoch:  21 val_loss: 0.08922711
# epoch:  21 val_accuracy: 0.97592816
# epoch:  22 train_loss: 0.09694418
# epoch:  22 train_accuracy: 0.97055818
# epoch:  22 val_loss: 0.09069540
# epoch:  22 val_accuracy: 0.97378226
# epoch:  23 train_loss: 0.09581788
# epoch:  23 train_accuracy: 0.97179383
# epoch:  23 val_loss: 0.09244104
# epoch:  23 val_accuracy: 0.97571121
# epoch:  24 train_loss: 0.09913413
# epoch:  24 train_accuracy: 0.97152448
# epoch:  24 val_loss: 0.08736877
# epoch:  24 val_accuracy: 0.97558859
# epoch:  25 train_loss: 0.09567083
# epoch:  25 train_accuracy: 0.97167063
# epoch:  25 val_loss: 0.09151298
# epoch:  25 val_accuracy: 0.97455573
# epoch:  26 train_loss: 0.09381657
# epoch:  26 train_accuracy: 0.97283260
# epoch:  26 val_loss: 0.08995549
# epoch:  26 val_accuracy: 0.97581026
# epoch:  27 train_loss: 0.09486375
# epoch:  27 train_accuracy: 0.97220209
# epoch:  27 val_loss: 0.09047983
# epoch:  27 val_accuracy: 0.97454629
# epoch:  28 train_loss: 0.09281320
# epoch:  28 train_accuracy: 0.97353316
# epoch:  28 val_loss: 0.08596082
# epoch:  28 val_accuracy: 0.97712609
# epoch:  29 train_loss: 0.09293137
# epoch:  29 train_accuracy: 0.97346915
# epoch:  29 val_loss: 0.09044515
# epoch:  29 val_accuracy: 0.97678652
# epoch:  30 train_loss: 0.09190440
# epoch:  30 train_accuracy: 0.97316356
# epoch:  30 val_loss: 0.08898352
# epoch:  30 val_accuracy: 0.97750811
# epoch:  31 train_loss: 0.09248550
# epoch:  31 train_accuracy: 0.97322757
# epoch:  31 val_loss: 0.08750594
# epoch:  31 val_accuracy: 0.97775807
# epoch:  32 train_loss: 0.08971520
# epoch:  32 train_accuracy: 0.97385929
# epoch:  32 val_loss: 0.09049421
# epoch:  32 val_accuracy: 0.97797974
# epoch:  33 train_loss: 0.08968307
# epoch:  33 train_accuracy: 0.97396316
# epoch:  33 val_loss: 0.08925503
# epoch:  33 val_accuracy: 0.97688556
# epoch:  34 train_loss: 0.08786749
# epoch:  34 train_accuracy: 0.97445718
# epoch:  34 val_loss: 0.09253527
# epoch:  34 val_accuracy: 0.97759772
# epoch:  35 train_loss: 0.08989849
# epoch:  35 train_accuracy: 0.97430258
# epoch:  35 val_loss: 0.09186118
# epoch:  35 val_accuracy: 0.97805520
# epoch:  36 train_loss: 0.08821896
# epoch:  36 train_accuracy: 0.97461300
# epoch:  36 val_loss: 0.09008055
# epoch:  36 val_accuracy: 0.97780524
# epoch:  37 train_loss: 0.08751501
# epoch:  37 train_accuracy: 0.97460696
# epoch:  37 val_loss: 0.09088588
# epoch:  37 val_accuracy: 0.97722985
# epoch:  38 train_loss: 0.08697589
# epoch:  38 train_accuracy: 0.97442578
# epoch:  38 val_loss: 0.09049103
# epoch:  38 val_accuracy: 0.97817311
# epoch:  39 train_loss: 0.08680218
# epoch:  39 train_accuracy: 0.97497053
# epoch:  39 val_loss: 0.08984344
# epoch:  39 val_accuracy: 0.97852211
# epoch:  40 train_loss: 0.08611478
# epoch:  40 train_accuracy: 0.97521935
# epoch:  40 val_loss: 0.08928094
# epoch:  40 val_accuracy: 0.97795616
# epoch:  41 train_loss: 0.08556467
# epoch:  41 train_accuracy: 0.97532443
# epoch:  41 val_loss: 0.09218521
# epoch:  41 val_accuracy: 0.97803162
# epoch:  42 train_loss: 0.08565925
# epoch:  42 train_accuracy: 0.97526162
# epoch:  42 val_loss: 0.09011354
# epoch:  42 val_accuracy: 0.97711666
# epoch:  43 train_loss: 0.08498378
# epoch:  43 train_accuracy: 0.97547663
# epoch:  43 val_loss: 0.09309694
# epoch:  43 val_accuracy: 0.97731003
# epoch:  44 train_loss: 0.08536561
# epoch:  44 train_accuracy: 0.97565418
# epoch:  44 val_loss: 0.09734267
# epoch:  44 val_accuracy: 0.97810708
# epoch:  45 train_loss: 0.08624305
# epoch:  45 train_accuracy: 0.97526525
# epoch:  45 val_loss: 0.09555343
# epoch:  45 val_accuracy: 0.97830516
# epoch:  46 train_loss: 0.08739412
# epoch:  46 train_accuracy: 0.97546817
# epoch:  46 val_loss: 0.09870938
# epoch:  46 val_accuracy: 0.97834289
# epoch:  47 train_loss: 0.08802912
# epoch:  47 train_accuracy: 0.97524230
# epoch:  47 val_loss: 0.09493923
# epoch:  47 val_accuracy: 0.97869661
# epoch:  48 train_loss: 0.08678557
# epoch:  48 train_accuracy: 0.97530632
# epoch:  48 val_loss: 0.09689046
# epoch:  48 val_accuracy: 0.97841364
# epoch:  49 train_loss: 0.08649965
# epoch:  49 train_accuracy: 0.97536912
# epoch:  49 val_loss: 0.09436175
# epoch:  49 val_accuracy: 0.97792314
# epoch:  50 train_loss: 0.08859789
# epoch:  50 train_accuracy: 0.97546575
# epoch:  50 val_loss: 0.09935125
# epoch:  50 val_accuracy: 0.97781467
# epoch:  51 train_loss: 0.08746412
# epoch:  51 train_accuracy: 0.97550441
# epoch:  51 val_loss: 0.09482404
# epoch:  51 val_accuracy: 0.97831459
# epoch:  52 train_loss: 0.08822976
# epoch:  52 train_accuracy: 0.97607090
# epoch:  52 val_loss: 0.09473604
# epoch:  52 val_accuracy: 0.97847966
# epoch:  53 train_loss: 0.08496978
# epoch:  53 train_accuracy: 0.97610834
# epoch:  53 val_loss: 0.10605928
# epoch:  53 val_accuracy: 0.97729116
# epoch:  54 train_loss: 0.08659696
# epoch:  54 train_accuracy: 0.97558533
# epoch:  54 val_loss: 0.09983708
# epoch:  54 val_accuracy: 0.97780052
# epoch:  55 train_loss: 0.08664955
# epoch:  55 train_accuracy: 0.97526162
# epoch:  55 val_loss: 0.09702405
# epoch:  55 val_accuracy: 0.97773921
# epoch:  56 train_loss: 0.08514985
# epoch:  56 train_accuracy: 0.97661323
# epoch:  56 val_loss: 0.10001334
# epoch:  56 val_accuracy: 0.97811651
# epoch:  57 train_loss: 0.08504216
# epoch:  57 train_accuracy: 0.97620376
# epoch:  57 val_loss: 0.09996235
# epoch:  57 val_accuracy: 0.97799860
# epoch:  58 train_loss: 0.08447465
# epoch:  58 train_accuracy: 0.97654921
# epoch:  58 val_loss: 0.10047124
# epoch:  58 val_accuracy: 0.97865888
# epoch:  59 train_loss: 0.08450344
# epoch:  59 train_accuracy: 0.97622913
# epoch:  59 val_loss: 0.10036723
# epoch:  59 val_accuracy: 0.97786655
# epoch:  60 train_loss: 0.08559982
# epoch:  60 train_accuracy: 0.97601534
# epoch:  60 val_loss: 0.09915999
# epoch:  60 val_accuracy: 0.97843722
# epoch:  61 train_loss: 0.08261531
# epoch:  61 train_accuracy: 0.97617357
# epoch:  61 val_loss: 0.09276982
# epoch:  61 val_accuracy: 0.97873434
# epoch:  62 train_loss: 0.08370735
# epoch:  62 train_accuracy: 0.97637528
# epoch:  62 val_loss: 0.09826646
# epoch:  62 val_accuracy: 0.97796087
# epoch:  63 train_loss: 0.08247282
# epoch:  63 train_accuracy: 0.97724857
# epoch:  63 val_loss: 0.09750338
# epoch:  63 val_accuracy: 0.97717326
# epoch:  64 train_loss: 0.08323174
# epoch:  64 train_accuracy: 0.97645742
# epoch:  64 val_loss: 0.10181080
# epoch:  64 val_accuracy: 0.97709308
# epoch:  65 train_loss: 0.08418926
# epoch:  65 train_accuracy: 0.97682702
# epoch:  65 val_loss: 0.09948414
# epoch:  65 val_accuracy: 0.97658844
# epoch:  66 train_loss: 0.08387220
# epoch:  66 train_accuracy: 0.97701183
# epoch:  66 val_loss: 0.10175906
# epoch:  66 val_accuracy: 0.97741379
# epoch:  67 train_loss: 0.08259124
# epoch:  67 train_accuracy: 0.97725702
# epoch:  67 val_loss: 0.10367044
# epoch:  67 val_accuracy: 0.97664503
# epoch:  68 train_loss: 0.08406950
# epoch:  68 train_accuracy: 0.97725461
# epoch:  68 val_loss: 0.11036869
# epoch:  68 val_accuracy: 0.97702234
# epoch:  69 train_loss: 0.08192970
# epoch:  69 train_accuracy: 0.97747082
# epoch:  69 val_loss: 0.10874643
# epoch:  69 val_accuracy: 0.97618284
# epoch:  70 train_loss: 0.08432235
# epoch:  70 train_accuracy: 0.97715194
# epoch:  70 val_loss: 0.11445266
# epoch:  70 val_accuracy: 0.97596118
# epoch:  71 train_loss: 0.08098000
# epoch:  71 train_accuracy: 0.97762422
# epoch:  71 val_loss: 0.11274618
# epoch:  71 val_accuracy: 0.97576309
# epoch:  72 train_loss: 0.08233185
# epoch:  72 train_accuracy: 0.97719905
# epoch:  72 val_loss: 0.12166944
# epoch:  72 val_accuracy: 0.97584327
# epoch:  73 train_loss: 0.08084760
# epoch:  73 train_accuracy: 0.97780057
# epoch:  73 val_loss: 0.11344014
# epoch:  73 val_accuracy: 0.97666390
# epoch:  74 train_loss: 0.08054497
# epoch:  74 train_accuracy: 0.97786579
# epoch:  74 val_loss: 0.11503714
# epoch:  74 val_accuracy: 0.97605078
# epoch:  75 train_loss: 0.08030822
# epoch:  75 train_accuracy: 0.97792015
# epoch:  75 val_loss: 0.11752805
# epoch:  75 val_accuracy: 0.97555558
# epoch:  76 train_loss: 0.08118132
# epoch:  76 train_accuracy: 0.97792256
# epoch:  76 val_loss: 0.12019045
# epoch:  76 val_accuracy: 0.97558387
# epoch:  77 train_loss: 0.08043210
# epoch:  77 train_accuracy: 0.97787062
# epoch:  77 val_loss: 0.11830067
# epoch:  77 val_accuracy: 0.97589515
# epoch:  78 train_loss: 0.08360760
# epoch:  78 train_accuracy: 0.97748048
# epoch:  78 val_loss: 0.11870611
# epoch:  78 val_accuracy: 0.97575838
# epoch:  79 train_loss: 0.08020839
# epoch:  79 train_accuracy: 0.97726910
# epoch:  79 val_loss: 0.11826889
# epoch:  79 val_accuracy: 0.97591873
# epoch:  80 train_loss: 0.08086395
# epoch:  80 train_accuracy: 0.97712174
# epoch:  80 val_loss: 0.12197402
# epoch:  80 val_accuracy: 0.97432935
# epoch:  81 train_loss: 0.08248119
# epoch:  81 train_accuracy: 0.97734641
# epoch:  81 val_loss: 0.11509459
# epoch:  81 val_accuracy: 0.97597532
# epoch:  82 train_loss: 0.08161440
# epoch:  82 train_accuracy: 0.97738144
# epoch:  82 val_loss: 0.12039031
# epoch:  82 val_accuracy: 0.97481512
# epoch:  83 train_loss: 0.08041255
# epoch:  83 train_accuracy: 0.97752396
# epoch:  83 val_loss: 0.11713881
# epoch:  83 val_accuracy: 0.97570178
# epoch:  84 train_loss: 0.07982318
# epoch:  84 train_accuracy: 0.97749981
# epoch:  84 val_loss: 0.11872169
# epoch:  84 val_accuracy: 0.97569706
# epoch:  85 train_loss: 0.07992369
# epoch:  85 train_accuracy: 0.97751672
# epoch:  85 val_loss: 0.11497649
# epoch:  85 val_accuracy: 0.97583855
# epoch:  86 train_loss: 0.07908144
# epoch:  86 train_accuracy: 0.97758677
# epoch:  86 val_loss: 0.11875540
# epoch:  86 val_accuracy: 0.97540937
# epoch:  87 train_loss: 0.08026981
# epoch:  87 train_accuracy: 0.97741163
# epoch:  87 val_loss: 0.11909650
# epoch:  87 val_accuracy: 0.97539994
# epoch:  88 train_loss: 0.07927198
# epoch:  88 train_accuracy: 0.97731500
# epoch:  88 val_loss: 0.12178292
# epoch:  88 val_accuracy: 0.97497548
# epoch:  89 train_loss: 0.07958890
# epoch:  89 train_accuracy: 0.97726790
# epoch:  89 val_loss: 0.12072634
# epoch:  89 val_accuracy: 0.97544239
# epoch:  90 train_loss: 0.07936860
# epoch:  90 train_accuracy: 0.97725461
# epoch:  90 val_loss: 0.12086081
# epoch:  90 val_accuracy: 0.97551785
# epoch:  91 train_loss: 0.07905244
# epoch:  91 train_accuracy: 0.97707101
# epoch:  91 val_loss: 0.12422902
# epoch:  91 val_accuracy: 0.97482455
# epoch:  92 train_loss: 0.08001193
# epoch:  92 train_accuracy: 0.97709638
# epoch:  92 val_loss: 0.12457039
# epoch:  92 val_accuracy: 0.97513111
# epoch:  93 train_loss: 0.07983454
# epoch:  93 train_accuracy: 0.97704082
# epoch:  93 val_loss: 0.12835025
# epoch:  93 val_accuracy: 0.97434350
# epoch:  94 train_loss: 0.07906980
# epoch:  94 train_accuracy: 0.97715798
# epoch:  94 val_loss: 0.12350759
# epoch:  94 val_accuracy: 0.97521129
# epoch:  95 train_loss: 0.07930151
# epoch:  95 train_accuracy: 0.97715677
# epoch:  95 val_loss: 0.12731952
# epoch:  95 val_accuracy: 0.97450385
# epoch:  96 train_loss: 0.07961176
# epoch:  96 train_accuracy: 0.97726186
# epoch:  96 val_loss: 0.12674307
# epoch:  96 val_accuracy: 0.97449913
# epoch:  97 train_loss: 0.08030749
# epoch:  97 train_accuracy: 0.97697559
# epoch:  97 val_loss: 0.12579339
# epoch:  97 val_accuracy: 0.97434821
# epoch:  98 train_loss: 0.07971833
# epoch:  98 train_accuracy: 0.97738627
# epoch:  98 val_loss: 0.12642238
# epoch:  98 val_accuracy: 0.97477268
# epoch:  99 train_loss: 0.07979162
# epoch:  99 train_accuracy: 0.97743217
# epoch:  99 val_loss: 0.12494523
# epoch:  99 val_accuracy: 0.97500377

# %%
import matplotlib.pyplot as plt

print('训练过程的损失随epoch变化趋势：')
plt.plot(train_loss_record, label='train_loss')
plt.plot(val_loss_record, label='val_loss')
plt.legend()
plt.show()

print('训练过程的准确率随epoch变化趋势：')
plt.plot(train_accuracy_record, label='train_accuracy')
plt.plot(val_accuracy_record, label='val_accuracy')
plt.legend()
plt.show()
# Out:
# 训练过程的损失随epoch变化趋势：
# 训练过程的准确率随epoch变化趋势：

# %% [markdown]
# ## 6. 验证模型，绘制结果

# %%
epoch_loss = 0
epoch_acc = 0
predicted_labels = []  # 模型结果标签，用于混淆矩阵
true_labels = []  # 模型真值标签，用于混淆矩阵

model.eval()
with torch.no_grad():
    for seq, labels in test_data:
        x,y = seq.to(device), labels.to(device)
        y_pred = model(x)
        y_pred = torch.squeeze(y_pred, dim=1) # 去除额外维度
        single_loss = loss_function(y_pred, y)
        
        # 获取预测正确的样本个数，由于pred为最大值所在位置的索引，
        # 因此不需要将label_test转换为one_hot编码
        # 当tensor为标量的时候，tensor.item()可以将其转换为ndarray类型
        # correct = pred.eq(label_test).sum().float().item()
        correct = torch.eq(y.argmax(dim=1), y_pred.argmax(dim=1))
        predicted_labels += y_pred.argmax(dim=1).tolist()
        true_labels += y.argmax(dim=1).tolist()
        
        epoch_acc += correct.sum().item()/ y.shape[0]
        epoch_loss += single_loss.item()

# 去平均
epoch_loss /= len(test_data)
epoch_acc /= len(test_data)

print(f'测试集平均损失：{epoch_loss}, \n测试集平均准确率：{epoch_acc}')
# Out:
# 测试集平均损失：0.12494523357352776,
# 测试集平均准确率：0.9750037730153939

# %% [markdown]
# ### 修改结果储存路径，并存储结果

# %%
# 绘制混淆矩阵
# 混淆矩阵
from sklearn.metrics import confusion_matrix
# 初始化混淆矩阵
num_classes = 5
conf_matrix = np.zeros((num_classes, num_classes), dtype=int)
# 更新混淆矩阵
conf_matrix += confusion_matrix(true_labels, predicted_labels, labels=range(num_classes))
# 打印混淆矩阵
print("Confusion Matrix:")
print(conf_matrix)

plt.figure(figsize=(12, 9))
# 设置颜色映射
cmap = plt.cm.Blues
# 绘制混淆矩阵图
plt.imshow(conf_matrix, interpolation='nearest', cmap=cmap)
# 添加文字标签
for i in range(len(conf_matrix)):
    for j in range(len(conf_matrix)):
        plt.text(j, i, conf_matrix[i, j], ha='center', va='center', color='black')
# 添加颜色条
plt.colorbar()
# 添加标题和标签
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
# 显示图形
plt.show()
# Out:
# Confusion Matrix:
# [[ 2776     0     3   424     0]
#  [    0 22787  1307    15    27]
#  [    8   495 81962   498   191]
#  [  242     9  1414 62110     0]
#  [    0     0    40   627 37062]]

# %%
# 绘制百分比混淆矩阵
from sklearn.metrics import confusion_matrix

num_classes = 5
conf_matrix = np.zeros((num_classes, num_classes), dtype=int)
conf_matrix += confusion_matrix(true_labels, predicted_labels, labels=range(num_classes))

# 转换为百分比混淆矩阵
conf_matrix_percentage = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis] * 100

# 打印混淆矩阵
print("Confusion Matrix (Percentage):")
print(conf_matrix_percentage)

# 绘制百分比混淆矩阵
plt.figure(figsize=(16, 12))
cmap = plt.cm.Blues
plt.imshow(conf_matrix_percentage, interpolation='nearest', cmap=cmap)

# 添加文字标签
for i in range(num_classes):
    for j in range(num_classes):
        plt.text(j, i, f'{conf_matrix_percentage[i, j]:.1f}%', ha='center', va='center', color='black')

# 添加颜色条
plt.colorbar()

# 添加标题和标签
plt.title('Confusion Matrix (Percentage)')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')

# 显示图形
plt.show()
# Out:
# Confusion Matrix (Percentage):
# [[8.66687480e+01 0.00000000e+00 9.36621917e-02 1.32375898e+01
#   0.00000000e+00]
#  [0.00000000e+00 9.44108386e+01 5.41514750e+00 6.21478290e-02
#   1.11866092e-01]
#  [9.62070375e-03 5.95281045e-01 9.85665151e+01 5.98888809e-01
#   2.29694302e-01]
#  [3.79459036e-01 1.41121129e-02 2.21716974e+00 9.73892591e+01
#   0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 1.06019242e-01 1.66185163e+00
#   9.82321291e+01]]

# %%
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# 计算总体的准确率、精确率、召回率、F1分数
def calculate_metrics_overall_by_sklearn(matrix):
    # 提取真实标签和预测标签
    true_labels = []
    pred_labels = []

    num_classes = matrix.shape[0]

    for i in range(num_classes):
        for j in range(num_classes):
            true_labels.extend([i] * matrix[i, j])
            pred_labels.extend([j] * matrix[i, j])

    # 计算总体的准确率、精确率、召回率和F1分数
    overall_accuracy = accuracy_score(true_labels, pred_labels)
    overall_precision = precision_score(true_labels, pred_labels, average='macro')
    overall_recall = recall_score(true_labels, pred_labels, average='macro')
    overall_f1 = f1_score(true_labels, pred_labels, average='macro')

    return overall_precision, overall_recall, overall_f1, overall_accuracy

real_overall_precision, real_overall_recall, real_overall_f1_score, real_overall_accuracy = calculate_metrics_overall_by_sklearn(conf_matrix)
print("总体精确率（Precision）: ", real_overall_precision)
print("总体召回率（Recall）: ", real_overall_recall)
print("总体F1 分数（F1 Score）: ", real_overall_f1_score)
print("总体准确率（Accuracy）: ", real_overall_accuracy)
# Out:
# 总体精确率（Precision）:  0.9665420721324889
# 总体召回率（Recall）:  0.9505349800323387
# 总体F1 分数（F1 Score）:  0.9583091173516994
# 总体准确率（Accuracy）:  0.9749996462214088
