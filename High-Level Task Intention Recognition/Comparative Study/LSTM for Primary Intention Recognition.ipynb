# %%
import pandas as pd

import torch
import torch.nn as nn
import torch.nn.functional as F

from sklearn.preprocessing import OneHotEncoder

# %% [markdown]
# ## 1. 读取结构化数据集

# %%
df = pd.read_csv(f'../Dataset/Final_Dataset_2.csv')
df = df.drop(columns=['Time', 'Secondary Intent'])
df.head()
# Out:
#    User  ID  Hotas_Axis_X  Hotas_Axis_Y  Hotas_Axis_Z  Hotas_Btn_Create_Fleet  \
# 0     1   1           0.0           0.0     -0.307087                   False
# 1     1   1           0.0           0.0     -0.307087                   False
# 2     1   1           0.0           0.0     -0.307087                   False
# 3     1   1           0.0           0.0     -0.307087                   False
# 4     1   1           0.0           0.0     -0.307087                   False
#
#    Hotas_Btn_Select_UAV1  Hotas_Btn_Select_UAV2  Hotas_Btn_Select_UAV3  \
# 0                  False                  False                  False
# 1                  False                  False                  False
# 2                  False                  False                  False
# 3                  False                  False                  False
# 4                  False                  False                  False
#
#    Hotas_Btn_Select_UAV4  ...  Target_Area_State  Target_Area_Pos_X  \
# 0                  False  ...              False               -1.0
# 1                  False  ...              False               -1.0
# 2                  False  ...              False               -1.0
# 3                  False  ...              False               -1.0
# 4                  False  ...              False               -1.0
#
#    Target_Area_Pos_Y  Trapped_People_State  Trapped_People_Pos_X  \
# 0               -1.0                 False                  -1.0
# 1               -1.0                 False                  -1.0
# 2               -1.0                 False                  -1.0
# 3               -1.0                 False                  -1.0
# 4               -1.0                 False                  -1.0
#
#    Trapped_People_Pos_Y  Gaze point X  Gaze point Y  AOI  Primary Intent
# 0                  -1.0        2067.0        1195.0    4        Intent_0
# 1                  -1.0        2046.0        1204.0    4        Intent_0
# 2                  -1.0        2046.0        1200.0    4        Intent_0
# 3                  -1.0        2053.0        1221.0    4        Intent_0
# 4                  -1.0        2068.0        1209.0    4        Intent_0
#
# [5 rows x 55 columns]

# %%
df['New Intent'] = None
for index, row in df.iterrows():
    if row['Primary Intent'] == 'Intent_0':
        df.at[index, 'New Intent'] = '00'
    if row['Primary Intent'] == 'Intent_1':
        df.at[index, 'New Intent'] = '01'
    if row['Primary Intent'] == 'Intent_2':
        df.at[index, 'New Intent'] = '02'
    if row['Primary Intent'] == 'Intent_3':
        df.at[index, 'New Intent'] = '03'
    if row['Primary Intent'] == 'Intent_4':
        df.at[index, 'New Intent'] = '04'
    if row['Primary Intent'] == 'Intent_5':
        df.at[index, 'New Intent'] = '05'
   

df.drop(columns=['Primary Intent'], inplace=True)
df.rename(columns={'New Intent': 'Intent'}, inplace=True)
df.head()
# Out:
#    User  ID  Hotas_Axis_X  Hotas_Axis_Y  Hotas_Axis_Z  Hotas_Btn_Create_Fleet  \
# 0     1   1           0.0           0.0     -0.307087                   False
# 1     1   1           0.0           0.0     -0.307087                   False
# 2     1   1           0.0           0.0     -0.307087                   False
# 3     1   1           0.0           0.0     -0.307087                   False
# 4     1   1           0.0           0.0     -0.307087                   False
#
#    Hotas_Btn_Select_UAV1  Hotas_Btn_Select_UAV2  Hotas_Btn_Select_UAV3  \
# 0                  False                  False                  False
# 1                  False                  False                  False
# 2                  False                  False                  False
# 3                  False                  False                  False
# 4                  False                  False                  False
#
#    Hotas_Btn_Select_UAV4  ...  Target_Area_State  Target_Area_Pos_X  \
# 0                  False  ...              False               -1.0
# 1                  False  ...              False               -1.0
# 2                  False  ...              False               -1.0
# 3                  False  ...              False               -1.0
# 4                  False  ...              False               -1.0
#
#    Target_Area_Pos_Y  Trapped_People_State  Trapped_People_Pos_X  \
# 0               -1.0                 False                  -1.0
# 1               -1.0                 False                  -1.0
# 2               -1.0                 False                  -1.0
# 3               -1.0                 False                  -1.0
# 4               -1.0                 False                  -1.0
#
#    Trapped_People_Pos_Y  Gaze point X  Gaze point Y  AOI  Intent
# 0                  -1.0        2067.0        1195.0    4      00
# 1                  -1.0        2046.0        1204.0    4      00
# 2                  -1.0        2046.0        1200.0    4      00
# 3                  -1.0        2053.0        1221.0    4      00
# 4                  -1.0        2068.0        1209.0    4      00
#
# [5 rows x 55 columns]

# %%
# 离散特征变量使用One-Hot编码，通过DataFrame实现
df = pd.get_dummies(df, columns=['Flight_Fleet_State', 'Flight_Fly_Mode', 'UAV_Selected_Now', 'UAV1_Task_State', 'UAV2_Task_State',
                                 'UAV3_Task_State', 'UAV4_Task_State', 'AOI', 'Intent'])
df.head()
# Out:
#    User  ID  Hotas_Axis_X  Hotas_Axis_Y  Hotas_Axis_Z  Hotas_Btn_Create_Fleet  \
# 0     1   1           0.0           0.0     -0.307087                   False
# 1     1   1           0.0           0.0     -0.307087                   False
# 2     1   1           0.0           0.0     -0.307087                   False
# 3     1   1           0.0           0.0     -0.307087                   False
# 4     1   1           0.0           0.0     -0.307087                   False
#
#    Hotas_Btn_Select_UAV1  Hotas_Btn_Select_UAV2  Hotas_Btn_Select_UAV3  \
# 0                  False                  False                  False
# 1                  False                  False                  False
# 2                  False                  False                  False
# 3                  False                  False                  False
# 4                  False                  False                  False
#
#    Hotas_Btn_Select_UAV4  ...  AOI_3  AOI_4  AOI_5  AOI_6  Intent_00  \
# 0                  False  ...  False   True  False  False       True
# 1                  False  ...  False   True  False  False       True
# 2                  False  ...  False   True  False  False       True
# 3                  False  ...  False   True  False  False       True
# 4                  False  ...  False   True  False  False       True
#
#    Intent_01  Intent_02  Intent_03  Intent_04  Intent_05
# 0      False      False      False      False      False
# 1      False      False      False      False      False
# 2      False      False      False      False      False
# 3      False      False      False      False      False
# 4      False      False      False      False      False
#
# [5 rows x 85 columns]

# %%
# 设置训练集和测试集
train_ids = [i for i in range(1, 51) if i % 5 != 0]
test_ids = [i for i in range(1, 51) if i % 5 == 0]
print("train IDs:", train_ids)
print("test IDs:", test_ids)

df_train = df[df['ID'].isin(train_ids)]
df_test = df[df['ID'].isin(test_ids)]
print(df_train.shape, df_test.shape)
# Out:
# train IDs: [1, 2, 3, 4, 6, 7, 8, 9, 11, 12, 13, 14, 16, 17, 18, 19, 21, 22, 23, 24, 26, 27, 28, 29, 31, 32, 33, 34, 36, 37, 38, 39, 41, 42, 43, 44, 46, 47, 48, 49]
# test IDs: [5, 10, 15, 20, 25, 30, 35, 40, 45, 50]
# (941603, 85) (233086, 85)

# %%
# 数据归一化-训练集
df_train.loc[:, 'Hotas_Axis_X']  = (df_train['Hotas_Axis_X']+1)/2
df_train.loc[:, 'Hotas_Axis_Y']  = (df_train['Hotas_Axis_Y']+1)/2
df_train.loc[:, 'Hotas_Axis_Z']  = (df_train['Hotas_Axis_Z']+1)/2

df_train.loc[:, 'Flight_Pos_X']  = (df_train['Flight_Pos_X']-df_train['Flight_Pos_X'].min())/(df_train['Flight_Pos_X'].max()-df_train['Flight_Pos_X'].min())
df_train.loc[:, 'Flight_Pos_Y']  = (df_train['Flight_Pos_Y']-df_train['Flight_Pos_Y'].min())/(df_train['Flight_Pos_Y'].max()-df_train['Flight_Pos_Y'].min())
df_train.loc[:, 'Flight_Speed']  = (df_train['Flight_Speed']-df_train['Flight_Speed'].min())/(df_train['Flight_Speed'].max()-df_train['Flight_Speed'].min())
df_train.loc[:, 'Flight_Height']  = (df_train['Flight_Height']-df_train['Flight_Height'].min())/(df_train['Flight_Height'].max()-df_train['Flight_Height'].min())
df_train.loc[:, 'Flight_Heading']  = (df_train['Flight_Heading']-df_train['Flight_Heading'].min())/(df_train['Flight_Heading'].max()-df_train['Flight_Heading'].min())

df_train.loc[:, 'UAV1_Pos_X']  = df_train['UAV1_Pos_X']/3840
df_train.loc[:, 'UAV1_Pos_Y']  = df_train['UAV1_Pos_Y']/2160
df_train.loc[:, 'UAV2_Pos_X']  = df_train['UAV2_Pos_X']/3840
df_train.loc[:, 'UAV2_Pos_Y']  = df_train['UAV2_Pos_Y']/2160
df_train.loc[:, 'UAV3_Pos_X']  = df_train['UAV3_Pos_X']/3840
df_train.loc[:, 'UAV3_Pos_Y']  = df_train['UAV3_Pos_Y']/2160
df_train.loc[:, 'UAV4_Pos_X']  = df_train['UAV4_Pos_X']/3840
df_train.loc[:, 'UAV4_Pos_Y']  = df_train['UAV4_Pos_Y']/2160

df_train.loc[:, 'Target_Area_Pos_X']  = (df_train['Target_Area_Pos_X']-df_train['Target_Area_Pos_X'].min())/(df_train['Target_Area_Pos_X'].max()-df_train['Target_Area_Pos_X'].min())
df_train.loc[:, 'Target_Area_Pos_Y']  = (df_train['Target_Area_Pos_Y']-df_train['Target_Area_Pos_Y'].min())/(df_train['Target_Area_Pos_Y'].max()-df_train['Target_Area_Pos_Y'].min())
df_train.loc[:, 'Trapped_People_Pos_X']  = (df_train['Trapped_People_Pos_X']-df_train['Trapped_People_Pos_X'].min())/(df_train['Trapped_People_Pos_X'].max()-df_train['Trapped_People_Pos_X'].min())
df_train.loc[:, 'Trapped_People_Pos_Y']  = (df_train['Trapped_People_Pos_Y']-df_train['Trapped_People_Pos_Y'].min())/(df_train['Trapped_People_Pos_Y'].max()-df_train['Trapped_People_Pos_Y'].min())

df_train.loc[:, 'Gaze point X']  = df_train['Gaze point X']/3840
df_train.loc[:, 'Gaze point Y']  = df_train['Gaze point Y']/2160

# 数据归一化-测试集
df_test.loc[:, 'Hotas_Axis_X']  = (df_test['Hotas_Axis_X']+1)/2
df_test.loc[:, 'Hotas_Axis_Y']  = (df_test['Hotas_Axis_Y']+1)/2
df_test.loc[:, 'Hotas_Axis_Z']  = (df_test['Hotas_Axis_Z']+1)/2

df_test.loc[:, 'Flight_Pos_X']  = (df_test['Flight_Pos_X']-df_test['Flight_Pos_X'].min())/(df_test['Flight_Pos_X'].max()-df_test['Flight_Pos_X'].min())
df_test.loc[:, 'Flight_Pos_Y']  = (df_test['Flight_Pos_Y']-df_train['Flight_Pos_Y'].min())/(df_test['Flight_Pos_Y'].max()-df_test['Flight_Pos_Y'].min())
df_test.loc[:, 'Flight_Speed']  = (df_test['Flight_Speed']-df_train['Flight_Speed'].min())/(df_test['Flight_Speed'].max()-df_test['Flight_Speed'].min())
df_test.loc[:, 'Flight_Height']  = (df_test['Flight_Height']-df_test['Flight_Height'].min())/(df_test['Flight_Height'].max()-df_test['Flight_Height'].min())
df_test.loc[:, 'Flight_Heading']  = (df_test['Flight_Heading']-df_test['Flight_Heading'].min())/(df_test['Flight_Heading'].max()-df_test['Flight_Heading'].min())

df_test.loc[:, 'UAV1_Pos_X']  = df_test['UAV1_Pos_X']/3840
df_test.loc[:, 'UAV1_Pos_Y']  = df_test['UAV1_Pos_Y']/2160
df_test.loc[:, 'UAV2_Pos_X']  = df_test['UAV2_Pos_X']/3840
df_test.loc[:, 'UAV2_Pos_Y']  = df_test['UAV2_Pos_Y']/2160
df_test.loc[:, 'UAV3_Pos_X']  = df_test['UAV3_Pos_X']/3840
df_test.loc[:, 'UAV3_Pos_Y']  = df_test['UAV3_Pos_Y']/2160
df_test.loc[:, 'UAV4_Pos_X']  = df_test['UAV4_Pos_X']/3840
df_test.loc[:, 'UAV4_Pos_Y']  = df_test['UAV4_Pos_Y']/2160

df_test.loc[:, 'Target_Area_Pos_X']  = (df_test['Target_Area_Pos_X']-df_test['Target_Area_Pos_X'].min())/(df_test['Target_Area_Pos_X'].max()-df_test['Target_Area_Pos_X'].min())
df_test.loc[:, 'Target_Area_Pos_Y']  = (df_test['Target_Area_Pos_Y']-df_test['Target_Area_Pos_Y'].min())/(df_test['Target_Area_Pos_Y'].max()-df_test['Target_Area_Pos_Y'].min())
df_test.loc[:, 'Trapped_People_Pos_X']  = (df_test['Trapped_People_Pos_X']-df_test['Trapped_People_Pos_X'].min())/(df_test['Trapped_People_Pos_X'].max()-df_test['Trapped_People_Pos_X'].min())
df_test.loc[:, 'Trapped_People_Pos_Y']  = (df_test['Trapped_People_Pos_Y']-df_test['Trapped_People_Pos_Y'].min())/(df_test['Trapped_People_Pos_Y'].max()-df_test['Trapped_People_Pos_Y'].min())

df_test.loc[:, 'Gaze point X']  = df_test['Gaze point X']/3840
df_test.loc[:, 'Gaze point Y']  = df_test['Gaze point Y']/2160

pd.set_option('display.max_columns', None)
df_train.head()
# Out:
#    User  ID  Hotas_Axis_X  Hotas_Axis_Y  Hotas_Axis_Z  Hotas_Btn_Create_Fleet  \
# 0     1   1           0.5           0.5      0.346457                   False
# 1     1   1           0.5           0.5      0.346457                   False
# 2     1   1           0.5           0.5      0.346457                   False
# 3     1   1           0.5           0.5      0.346457                   False
# 4     1   1           0.5           0.5      0.346457                   False
#
#    Hotas_Btn_Select_UAV1  Hotas_Btn_Select_UAV2  Hotas_Btn_Select_UAV3  \
# 0                  False                  False                  False
# 1                  False                  False                  False
# 2                  False                  False                  False
# 3                  False                  False                  False
# 4                  False                  False                  False
#
#    Hotas_Btn_Select_UAV4  Hotas_Btn_Assign_Up  Hotas_Btn_Assign_Down  \
# 0                  False                False                  False
# 1                  False                False                  False
# 2                  False                False                  False
# 3                  False                False                  False
# 4                  False                False                  False
#
#    Hotas_Btn_Assign_Left  Hotas_Btn_Assign_Right  Hotas_Btn_Change_Mode  \
# 0                  False                   False                  False
# 1                  False                   False                  False
# 2                  False                   False                  False
# 3                  False                   False                  False
# 4                  False                   False                  False
#
#    Hotas_Btn_Open_UAV_Sensor  Hotas_Btn_Open_Helicopter_Sensor  \
# 0                      False                             False
# 1                      False                             False
# 2                      False                             False
# 3                      False                             False
# 4                      False                             False
#
#    Hotas_Btn_Select_Normal  Hotas_Btn_Select_Fire  Hotas_Btn_Select_Person  \
# 0                    False                  False                    False
# 1                    False                  False                    False
# 2                    False                  False                    False
# 3                    False                  False                    False
# 4                    False                  False                    False
#
#    Hotas_Btn_Submit_Result  Hotas_Btn_Area_Assign  Flight_Pos_X  Flight_Pos_Y  \
# 0                    False                  False        0.4499      0.127802
# 1                    False                  False        0.4499      0.127802
# 2                    False                  False        0.4499      0.127802
# 3                    False                  False        0.4499      0.127802
# 4                    False                  False        0.4499      0.127802
#
#    Flight_Speed  Flight_Height  Flight_Heading  Flight_Sensor  UAV1_Pos_X  \
# 0           0.0        0.40634        0.000016          False    0.495825
# 1           0.0        0.40634        0.000016          False    0.495825
# 2           0.0        0.40634        0.000016          False    0.495825
# 3           0.0        0.40634        0.000016          False    0.495825
# 4           0.0        0.40634        0.000016          False    0.495825
#
#    UAV1_Pos_Y  UAV2_Pos_X  UAV2_Pos_Y  UAV3_Pos_X  UAV3_Pos_Y  UAV4_Pos_X  \
# 0      0.1839    0.534825      0.1839    0.495825    0.130567    0.534825
# 1      0.1839    0.534825      0.1839    0.495825    0.130567    0.534825
# 2      0.1839    0.534825      0.1839    0.495825    0.130567    0.534825
# 3      0.1839    0.534825      0.1839    0.495825    0.130567    0.534825
# 4      0.1839    0.534825      0.1839    0.495825    0.130567    0.534825
#
#    UAV4_Pos_Y  UAV_Sensor_State  Task_List_State  Target_Area_State  \
# 0    0.130567             False             True              False
# 1    0.130567             False             True              False
# 2    0.130567             False             True              False
# 3    0.130567             False             True              False
# 4    0.130567             False             True              False
#
#    Target_Area_Pos_X  Target_Area_Pos_Y  Trapped_People_State  \
# 0                0.0                0.0                 False
# 1                0.0                0.0                 False
# 2                0.0                0.0                 False
# 3                0.0                0.0                 False
# 4                0.0                0.0                 False
#
#    Trapped_People_Pos_X  Trapped_People_Pos_Y  Gaze point X  Gaze point Y  \
# 0                   0.0                   0.0      0.538281      0.553241
# 1                   0.0                   0.0      0.532813      0.557407
# 2                   0.0                   0.0      0.532813      0.555556
# 3                   0.0                   0.0      0.534635      0.565278
# 4                   0.0                   0.0      0.538542      0.559722
#
#    Flight_Fleet_State_0  Flight_Fleet_State_1  Flight_Fleet_State_2  \
# 0                  True                 False                 False
# 1                  True                 False                 False
# 2                  True                 False                 False
# 3                  True                 False                 False
# 4                  True                 False                 False
#
#    Flight_Fly_Mode_0  Flight_Fly_Mode_1  UAV_Selected_Now_-1.0  \
# 0               True              False                   True
# 1               True              False                   True
# 2               True              False                   True
# 3               True              False                   True
# 4               True              False                   True
#
#    UAV_Selected_Now_1.0  UAV_Selected_Now_2.0  UAV_Selected_Now_3.0  \
# 0                 False                 False                 False
# 1                 False                 False                 False
# 2                 False                 False                 False
# 3                 False                 False                 False
# 4                 False                 False                 False
#
#    UAV_Selected_Now_4.0  UAV1_Task_State_0  UAV1_Task_State_1  \
# 0                 False               True              False
# 1                 False               True              False
# 2                 False               True              False
# 3                 False               True              False
# 4                 False               True              False
#
#    UAV1_Task_State_2  UAV1_Task_State_3  UAV2_Task_State_0  UAV2_Task_State_1  \
# 0              False              False               True              False
# 1              False              False               True              False
# 2              False              False               True              False
# 3              False              False               True              False
# 4              False              False               True              False
#
#    UAV2_Task_State_2  UAV2_Task_State_3  UAV3_Task_State_0  UAV3_Task_State_1  \
# 0              False              False               True              False
# 1              False              False               True              False
# 2              False              False               True              False
# 3              False              False               True              False
# 4              False              False               True              False
#
#    UAV3_Task_State_2  UAV3_Task_State_3  UAV4_Task_State_0  UAV4_Task_State_1  \
# 0              False              False               True              False
# 1              False              False               True              False
# 2              False              False               True              False
# 3              False              False               True              False
# 4              False              False               True              False
#
#    UAV4_Task_State_2  UAV4_Task_State_3  AOI_0  AOI_1  AOI_2  AOI_3  AOI_4  \
# 0              False              False  False  False  False  False   True
# 1              False              False  False  False  False  False   True
# 2              False              False  False  False  False  False   True
# 3              False              False  False  False  False  False   True
# 4              False              False  False  False  False  False   True
#
#    AOI_5  AOI_6  Intent_00  Intent_01  Intent_02  Intent_03  Intent_04  \
# 0  False  False       True      False      False      False      False
# 1  False  False       True      False      False      False      False
# 2  False  False       True      False      False      False      False
# 3  False  False       True      False      False      False      False
# 4  False  False       True      False      False      False      False
#
#    Intent_05
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False

# %% [markdown]
# ## 2. 定义Dataset和DataLoader

# %%
from torch.utils.data import DataLoader, Dataset
import numpy as np

class MyDataset(Dataset):
    # 实例化调用，数据集初始化
    def __init__(self, df, time_step):
        # 初始化输入输出
        x = []
        y = []
        num_intent_0 = 0
        
        # 根据test_id划分DataFrame
        grouped = df.groupby('ID')
        
        for _, group in grouped:
            # test_id放在最后
            origin_data = group.drop(columns=['ID', 'User'])
            # 将表格中的bool型转换为int型
            for column in origin_data.columns:
                if origin_data[column].dtype == bool:
                    origin_data[column] = origin_data[column].astype(int)
            # 将表格数据转换为Numpy
            dataset = (origin_data).to_numpy()
            for i in range(len(dataset) - time_step):
                input_seq = dataset[i:(i+time_step), 0:-6]
                output_seq = dataset[i+time_step-1, -6:]
                
#                 x.append(input_seq)
#                 y.append(output_seq)
                
                if output_seq[0] == 1:
                    num_intent_0 += 1
                else:
                    x.append(input_seq)
                    y.append(output_seq[1:])
        
        x = np.array(x)
        y = np.array(y)
        print(f'shape_input:{x.shape},shape_output:{y.shape}')
        print(f'delete Intent_0:{num_intent_0}')
        
        self.data_tensor = torch.tensor(x, dtype=torch.float32)
        self.label_tensor = torch.tensor(y, dtype=torch.float32)
    
    # 返回数据集的长度    
    def __len__(self):
        return self.data_tensor.shape[0]
    
    # 根据指定下标返回数据集内容    
    def __getitem__(self, i):
        # 读取数据
        data = self.data_tensor[i]
        # 读取标签
        label = self.label_tensor[i]

        return data, label  # 返回数据和标签
  
train_dataset = MyDataset(df_train, 20)
test_dataset = MyDataset(df_test, 20)

# 加载数据集
train_data = DataLoader(train_dataset, batch_size=64, shuffle=False) # shuffle是否打乱
test_data = DataLoader(test_dataset, batch_size=64, shuffle=False)

print(f'输入张量：{train_dataset.data_tensor.shape} 输出张量：{train_dataset.label_tensor.shape}')
# Out:
# shape_input:(827893, 20, 77),shape_output:(827893, 5)
# delete Intent_0:112910
# shape_input:(211997, 20, 77),shape_output:(211997, 5)
# delete Intent_0:20889
# 输入张量：torch.Size([827893, 20, 77]) 输出张量：torch.Size([827893, 5])

# %% [markdown]
# ## 3. 定义LSTM模型

# %% [markdown]
# ### 模型1:LSTM模型

# %%
class LSTM(nn.Module):
    def __init__(self, input_size=77, hidden_size=128, output_size=5, num_layers=1, bidirectional=False):
        super().__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.num_layers = num_layers
        self.bidirectional = bidirectional
        self.num_directions = 2 if bidirectional else 1 # 单向LSTM模型
        
        self.lstm = nn.LSTM(self.input_size, self.hidden_size, self.num_layers, batch_first=True, bidirectional=self.bidirectional)
        self.linear = nn.Linear(self.hidden_size * self.num_directions, self.output_size)

    def forward(self, input_seq):
        batch_size, seq_len = input_seq.shape[0], input_seq.shape[1]
        h_0 = torch.randn(self.num_directions * self.num_layers, batch_size, self.hidden_size).to(device)
        c_0 = torch.randn(self.num_directions * self.num_layers, batch_size, self.hidden_size).to(device)
        
        lstm_out, self.hidden_cell = self.lstm(input_seq, (h_0, c_0))
        predictions = self.linear(lstm_out[:,-1,:])# LSTM只输出最后一个时间步
        return predictions

# %% [markdown]
# ## 4. 实例化模型，定义超参数

# %%
device = 'cuda'
model = LSTM().to(device)
# 损失函数
loss_function = nn.CrossEntropyLoss()
# 优化器
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %% [markdown]
# ## 5. 训练模型

# %%
epochs = 100
train_loss_record = []
train_accuracy_record = []
val_loss_record = []
val_accuracy_record = []

for i in range(epochs):
    # 模型训练
    model.train()
    train_loss = 0
    train_accuracy = 0
    
    for seq, labels in train_data:
        optimizer.zero_grad()
        x,y = seq.to(device), labels.to(device)
        y_pred = model(x)
        y_pred = torch.squeeze(y_pred, dim=1) # 去除额外维度
        loss = loss_function(y_pred, y)
        loss.backward()
        optimizer.step()
        
        # 计算训练准确率
        train_loss += loss.item()
        train_correct = torch.eq(y.argmax(dim=1), y_pred.argmax(dim=1))
        train_accuracy += train_correct.sum().item()/ y.shape[0]

    # if i%1 == 1:
    avg_train_loss = train_loss / len(train_data)
    print(f'epoch: {i:3} train_loss: {avg_train_loss:10.8f}')
    train_loss_record.append(avg_train_loss)
    
    avg_train_accuracy = train_accuracy / len(train_data)
    print(f'epoch: {i:3} train_accuracy: {avg_train_accuracy:10.8f}')
    train_accuracy_record.append(avg_train_accuracy)
    

    # 模型验证
    model.eval()
    val_loss = 0
    val_accuracy = 0
    
    with torch.no_grad():
        for seq, labels in test_data:
            x,y = seq.to(device), labels.to(device)
            y_pred = model(x)
            y_pred = torch.squeeze(y_pred, dim=1) # 去除额外维度
            loss = loss_function(y_pred, y)
            val_loss += loss.item()
            val_correct = torch.eq(y.argmax(dim=1), y_pred.argmax(dim=1))
            val_accuracy += val_correct.sum().item()/ y.shape[0]
    
    avg_val_loss = val_loss / len(test_data)
    print(f'epoch: {i:3} val_loss: {avg_val_loss:10.8f}')
    val_loss_record.append(avg_val_loss)
    
    avg_val_accuracy = val_accuracy / len(test_data)
    print(f'epoch: {i:3} val_accuracy: {avg_val_accuracy:10.8f}')
    val_accuracy_record.append(avg_val_accuracy)
# Out:
# epoch:   0 train_loss: 0.39819812
# epoch:   0 train_accuracy: 0.85844736
# epoch:   0 val_loss: 0.21116567
# epoch:   0 val_accuracy: 0.93842439
# epoch:   1 train_loss: 0.19594643
# epoch:   1 train_accuracy: 0.93911251
# epoch:   1 val_loss: 0.17708857
# epoch:   1 val_accuracy: 0.95659146
# epoch:   2 train_loss: 0.15171113
# epoch:   2 train_accuracy: 0.95658917
# epoch:   2 val_loss: 0.18602160
# epoch:   2 val_accuracy: 0.95142243
# epoch:   3 train_loss: 0.13180409
# epoch:   3 train_accuracy: 0.96054011
# epoch:   3 val_loss: 0.11187110
# epoch:   3 val_accuracy: 0.97287674
# epoch:   4 train_loss: 0.11293427
# epoch:   4 train_accuracy: 0.96585957
# epoch:   4 val_loss: 0.10666181
# epoch:   4 val_accuracy: 0.97322574
# epoch:   5 train_loss: 0.09698802
# epoch:   5 train_accuracy: 0.96956169
# epoch:   5 val_loss: 0.09777709
# epoch:   5 val_accuracy: 0.97631961
# epoch:   6 train_loss: 0.09288228
# epoch:   6 train_accuracy: 0.97137228
# epoch:   6 val_loss: 0.09960543
# epoch:   6 val_accuracy: 0.97636677
# epoch:   7 train_loss: 0.08363385
# epoch:   7 train_accuracy: 0.97431949
# epoch:   7 val_loss: 0.10290346
# epoch:   7 val_accuracy: 0.97787598
# epoch:   8 train_loss: 0.07939438
# epoch:   8 train_accuracy: 0.97587160
# epoch:   8 val_loss: 0.08401572
# epoch:   8 val_accuracy: 0.97863058
# epoch:   9 train_loss: 0.07593688
# epoch:   9 train_accuracy: 0.97647312
# epoch:   9 val_loss: 0.13218780
# epoch:   9 val_accuracy: 0.97379169
# epoch:  10 train_loss: 0.07128117
# epoch:  10 train_accuracy: 0.97786579
# epoch:  10 val_loss: 0.10747515
# epoch:  10 val_accuracy: 0.97554614
# epoch:  11 train_loss: 0.07538444
# epoch:  11 train_accuracy: 0.97729930
# epoch:  11 val_loss: 0.10023843
# epoch:  11 val_accuracy: 0.97577252
# epoch:  12 train_loss: 0.06609352
# epoch:  12 train_accuracy: 0.97985878
# epoch:  12 val_loss: 0.10247244
# epoch:  12 val_accuracy: 0.97664975
# epoch:  13 train_loss: 0.06446602
# epoch:  13 train_accuracy: 0.97994816
# epoch:  13 val_loss: 0.09649338
# epoch:  13 val_accuracy: 0.97846080
# epoch:  14 train_loss: 0.06299856
# epoch:  14 train_accuracy: 0.98001097
# epoch:  14 val_loss: 0.13519431
# epoch:  14 val_accuracy: 0.97414070
# epoch:  15 train_loss: 0.06009980
# epoch:  15 train_accuracy: 0.98116448
# epoch:  15 val_loss: 0.12028110
# epoch:  15 val_accuracy: 0.97910221
# epoch:  16 train_loss: 0.06215916
# epoch:  16 train_accuracy: 0.98073690
# epoch:  16 val_loss: 0.12716187
# epoch:  16 val_accuracy: 0.97560274
# epoch:  17 train_loss: 0.06076957
# epoch:  17 train_accuracy: 0.98082386
# epoch:  17 val_loss: 0.28269457
# epoch:  17 val_accuracy: 0.97576781
# epoch:  18 train_loss: 0.05950994
# epoch:  18 train_accuracy: 0.98064872
# epoch:  18 val_loss: 0.09200533
# epoch:  18 val_accuracy: 0.97731003
# epoch:  19 train_loss: 0.06238918
# epoch:  19 train_accuracy: 0.98018248
# epoch:  19 val_loss: 0.11452627
# epoch:  19 val_accuracy: 0.97501321
# epoch:  20 train_loss: 0.06218638
# epoch:  20 train_accuracy: 0.98131788
# epoch:  20 val_loss: 0.13281344
# epoch:  20 val_accuracy: 0.97724400
# epoch:  21 train_loss: 0.05803166
# epoch:  21 train_accuracy: 0.98097726
# epoch:  21 val_loss: 0.19997982
# epoch:  21 val_accuracy: 0.97370680
# epoch:  22 train_loss: 0.05611354
# epoch:  22 train_accuracy: 0.98235665
# epoch:  22 val_loss: 0.13012326
# epoch:  22 val_accuracy: 0.97755999
# epoch:  23 train_loss: 0.05468768
# epoch:  23 train_accuracy: 0.98242671
# epoch:  23 val_loss: 0.13162985
# epoch:  23 val_accuracy: 0.97446612
# epoch:  24 train_loss: 0.05507124
# epoch:  24 train_accuracy: 0.98106906
# epoch:  24 val_loss: 0.13992249
# epoch:  24 val_accuracy: 0.97460761
# epoch:  25 train_loss: 0.05597509
# epoch:  25 train_accuracy: 0.98176359
# epoch:  25 val_loss: 0.19515542
# epoch:  25 val_accuracy: 0.97124962
# epoch:  26 train_loss: 0.05643460
# epoch:  26 train_accuracy: 0.98201724
# epoch:  26 val_loss: 0.08885389
# epoch:  26 val_accuracy: 0.97882867
# epoch:  27 train_loss: 0.05235120
# epoch:  27 train_accuracy: 0.98254629
# epoch:  27 val_loss: 0.14705455
# epoch:  27 val_accuracy: 0.97594703
# epoch:  28 train_loss: 0.05367015
# epoch:  28 train_accuracy: 0.98239168
# epoch:  28 val_loss: 0.14387108
# epoch:  28 val_accuracy: 0.97579611
# epoch:  29 train_loss: 0.05278485
# epoch:  29 train_accuracy: 0.98225398
# epoch:  29 val_loss: 0.17078976
# epoch:  29 val_accuracy: 0.97402751
# epoch:  30 train_loss: 0.05021866
# epoch:  30 train_accuracy: 0.98370584
# epoch:  30 val_loss: 0.12143998
# epoch:  30 val_accuracy: 0.97703177
# epoch:  31 train_loss: 0.04967542
# epoch:  31 train_accuracy: 0.98341958
# epoch:  31 val_loss: 0.13517666
# epoch:  31 val_accuracy: 0.97495661
# epoch:  32 train_loss: 0.05187706
# epoch:  32 train_accuracy: 0.98303426
# epoch:  32 val_loss: 0.14516875
# epoch:  32 val_accuracy: 0.97484342
# epoch:  33 train_loss: 0.04801892
# epoch:  33 train_accuracy: 0.98337005
# epoch:  33 val_loss: 0.19390193
# epoch:  33 val_accuracy: 0.97315028
# epoch:  34 train_loss: 0.05339575
# epoch:  34 train_accuracy: 0.98262842
# epoch:  34 val_loss: 0.11075048
# epoch:  34 val_accuracy: 0.97405109
# epoch:  35 train_loss: 0.05035206
# epoch:  35 train_accuracy: 0.98350775
# epoch:  35 val_loss: 0.15245463
# epoch:  35 val_accuracy: 0.97103739
# epoch:  36 train_loss: 0.04891006
# epoch:  36 train_accuracy: 0.98402109
# epoch:  36 val_loss: 0.13215170
# epoch:  36 val_accuracy: 0.97665447
# epoch:  37 train_loss: 0.05120864
# epoch:  37 train_accuracy: 0.98312365
# epoch:  37 val_loss: 0.09750336
# epoch:  37 val_accuracy: 0.97966345
# epoch:  38 train_loss: 0.05189729
# epoch:  38 train_accuracy: 0.98332295
# epoch:  38 val_loss: 0.13004047
# epoch:  38 val_accuracy: 0.97377754
# epoch:  39 train_loss: 0.04993029
# epoch:  39 train_accuracy: 0.98345581
# epoch:  39 val_loss: 0.18654703
# epoch:  39 val_accuracy: 0.97130150
# epoch:  40 train_loss: 0.04984112
# epoch:  40 train_accuracy: 0.98385803
# epoch:  40 val_loss: 0.16100983
# epoch:  40 val_accuracy: 0.97458403
# epoch:  41 train_loss: 0.05392238
# epoch:  41 train_accuracy: 0.98316351
# epoch:  41 val_loss: 0.21311157
# epoch:  41 val_accuracy: 0.97377754
# epoch:  42 train_loss: 0.05113555
# epoch:  42 train_accuracy: 0.98373241
# epoch:  42 val_loss: 0.20031391
# epoch:  42 val_accuracy: 0.97436236
# epoch:  43 train_loss: 0.05075633
# epoch:  43 train_accuracy: 0.98355969
# epoch:  43 val_loss: 0.14031212
# epoch:  43 val_accuracy: 0.97649411
# epoch:  44 train_loss: 0.05110441
# epoch:  44 train_accuracy: 0.98356210
# epoch:  44 val_loss: 0.19536188
# epoch:  44 val_accuracy: 0.97357003
# epoch:  45 train_loss: 0.05090428
# epoch:  45 train_accuracy: 0.98380005
# epoch:  45 val_loss: 0.27912513
# epoch:  45 val_accuracy: 0.96891979
# epoch:  46 train_loss: 0.04935489
# epoch:  46 train_accuracy: 0.98396674
# epoch:  46 val_loss: 0.20103192
# epoch:  46 val_accuracy: 0.97590458
# epoch:  47 train_loss: 0.05083484
# epoch:  47 train_accuracy: 0.98378194
# epoch:  47 val_loss: 0.19361403
# epoch:  47 val_accuracy: 0.97627245
# epoch:  48 train_loss: 0.04957465
# epoch:  48 train_accuracy: 0.98392326
# epoch:  48 val_loss: 0.18642592
# epoch:  48 val_accuracy: 0.97057520
# epoch:  49 train_loss: 0.05090054
# epoch:  49 train_accuracy: 0.98365753
# epoch:  49 val_loss: 0.22296602
# epoch:  49 val_accuracy: 0.97231550
# epoch:  50 train_loss: 0.04900274
# epoch:  50 train_accuracy: 0.98487627
# epoch:  50 val_loss: 0.13269560
# epoch:  50 val_accuracy: 0.97265979
# epoch:  51 train_loss: 0.05801373
# epoch:  51 train_accuracy: 0.98227693
# epoch:  51 val_loss: 0.12283066
# epoch:  51 val_accuracy: 0.97616398
# epoch:  52 train_loss: 0.04778136
# epoch:  52 train_accuracy: 0.98402109
# epoch:  52 val_loss: 0.22529205
# epoch:  52 val_accuracy: 0.97397563
# epoch:  53 train_loss: 0.04795049
# epoch:  53 train_accuracy: 0.98443056
# epoch:  53 val_loss: 0.24499389
# epoch:  53 val_accuracy: 0.96879716
# epoch:  54 train_loss: 0.04979467
# epoch:  54 train_accuracy: 0.98368772
# epoch:  54 val_loss: 0.24659029
# epoch:  54 val_accuracy: 0.97175426
# epoch:  55 train_loss: 0.05324448
# epoch:  55 train_accuracy: 0.98338817
# epoch:  55 val_loss: 0.18592880
# epoch:  55 val_accuracy: 0.97390960
# epoch:  56 train_loss: 0.04864906
# epoch:  56 train_accuracy: 0.98451753
# epoch:  56 val_loss: 0.16979151
# epoch:  56 val_accuracy: 0.97336723
# epoch:  57 train_loss: 0.04939997
# epoch:  57 train_accuracy: 0.98422039
# epoch:  57 val_loss: 0.21131899
# epoch:  57 val_accuracy: 0.96973570
# epoch:  58 train_loss: 0.04917640
# epoch:  58 train_accuracy: 0.98420711
# epoch:  58 val_loss: 0.17488076
# epoch:  58 val_accuracy: 0.97572065
# epoch:  59 train_loss: 0.05037141
# epoch:  59 train_accuracy: 0.98317800
# epoch:  59 val_loss: 0.19098097
# epoch:  59 val_accuracy: 0.97438123
# epoch:  60 train_loss: 0.04940349
# epoch:  60 train_accuracy: 0.98412980
# epoch:  60 val_loss: 0.20140151
# epoch:  60 val_accuracy: 0.96922163
# epoch:  61 train_loss: 0.05154067
# epoch:  61 train_accuracy: 0.98375295
# epoch:  61 val_loss: 0.16855258
# epoch:  61 val_accuracy: 0.97101381
# epoch:  62 train_loss: 0.04671483
# epoch:  62 train_accuracy: 0.98491733
# epoch:  62 val_loss: 0.22968208
# epoch:  62 val_accuracy: 0.97142884
# epoch:  63 train_loss: 0.04622086
# epoch:  63 train_accuracy: 0.98490163
# epoch:  63 val_loss: 0.20154502
# epoch:  63 val_accuracy: 0.97229663
# epoch:  64 train_loss: 0.04680836
# epoch:  64 train_accuracy: 0.98507073
# epoch:  64 val_loss: 0.21027857
# epoch:  64 val_accuracy: 0.97516413
# epoch:  65 train_loss: 0.05050809
# epoch:  65 train_accuracy: 0.98439916
# epoch:  65 val_loss: 0.20448543
# epoch:  65 val_accuracy: 0.97318329
# epoch:  66 train_loss: 0.04873225
# epoch:  66 train_accuracy: 0.98432427
# epoch:  66 val_loss: 0.30041945
# epoch:  66 val_accuracy: 0.96548634
# epoch:  67 train_loss: 0.04795633
# epoch:  67 train_accuracy: 0.98447042
# epoch:  67 val_loss: 0.18904157
# epoch:  67 val_accuracy: 0.97132037
# epoch:  68 train_loss: 0.04687929
# epoch:  68 train_accuracy: 0.98444506
# epoch:  68 val_loss: 0.22722130
# epoch:  68 val_accuracy: 0.96825951
# epoch:  69 train_loss: 0.04842430
# epoch:  69 train_accuracy: 0.98400781
# epoch:  69 val_loss: 0.21889232
# epoch:  69 val_accuracy: 0.96797182
# epoch:  70 train_loss: 0.04579452
# epoch:  70 train_accuracy: 0.98537270
# epoch:  70 val_loss: 0.18989125
# epoch:  70 val_accuracy: 0.97115530
# epoch:  71 train_loss: 0.04520081
# epoch:  71 train_accuracy: 0.98506469
# epoch:  71 val_loss: 0.19007102
# epoch:  71 val_accuracy: 0.97038183
# epoch:  72 train_loss: 0.04585293
# epoch:  72 train_accuracy: 0.98490042
# epoch:  72 val_loss: 0.18235923
# epoch:  72 val_accuracy: 0.97154675
# epoch:  73 train_loss: 0.04701557
# epoch:  73 train_accuracy: 0.98511059
# epoch:  73 val_loss: 0.17279763
# epoch:  73 val_accuracy: 0.97106097
# epoch:  74 train_loss: 0.04654154
# epoch:  74 train_accuracy: 0.98454048
# epoch:  74 val_loss: 0.16885858
# epoch:  74 val_accuracy: 0.97271167
# epoch:  75 train_loss: 0.04703672
# epoch:  75 train_accuracy: 0.98532922
# epoch:  75 val_loss: 0.15627551
# epoch:  75 val_accuracy: 0.97116473
# epoch:  76 train_loss: 0.04776636
# epoch:  76 train_accuracy: 0.98436413
# epoch:  76 val_loss: 0.20536986
# epoch:  76 val_accuracy: 0.96962251
# epoch:  77 train_loss: 0.04498612
# epoch:  77 train_accuracy: 0.98545000
# epoch:  77 val_loss: 0.20593569
# epoch:  77 val_accuracy: 0.96678332
# epoch:  78 train_loss: 0.04741735
# epoch:  78 train_accuracy: 0.98500188
# epoch:  78 val_loss: 0.17787454
# epoch:  78 val_accuracy: 0.97127792
# epoch:  79 train_loss: 0.04297114
# epoch:  79 train_accuracy: 0.98564206
# epoch:  79 val_loss: 0.15693398
# epoch:  79 val_accuracy: 0.97393318
# epoch:  80 train_loss: 0.04576264
# epoch:  80 train_accuracy: 0.98547537
# epoch:  80 val_loss: 0.19242656
# epoch:  80 val_accuracy: 0.97305595
# epoch:  81 train_loss: 0.04621149
# epoch:  81 train_accuracy: 0.98455256
# epoch:  81 val_loss: 0.16711033
# epoch:  81 val_accuracy: 0.97176841
# epoch:  82 train_loss: 0.04377041
# epoch:  82 train_accuracy: 0.98597301
# epoch:  82 val_loss: 0.16713788
# epoch:  82 val_accuracy: 0.97456988
# epoch:  83 train_loss: 0.04813983
# epoch:  83 train_accuracy: 0.98511301
# epoch:  83 val_loss: 0.19251693
# epoch:  83 val_accuracy: 0.97374453
# epoch:  84 train_loss: 0.04613847
# epoch:  84 train_accuracy: 0.98505141
# epoch:  84 val_loss: 0.16790612
# epoch:  84 val_accuracy: 0.97371152
# epoch:  85 train_loss: 0.04644892
# epoch:  85 train_accuracy: 0.98524587
# epoch:  85 val_loss: 0.19455440
# epoch:  85 val_accuracy: 0.96949517
# epoch:  86 train_loss: 0.04415070
# epoch:  86 train_accuracy: 0.98554180
# epoch:  86 val_loss: 0.21742978
# epoch:  86 val_accuracy: 0.97000453
# epoch:  87 train_loss: 0.04503969
# epoch:  87 train_accuracy: 0.98523983
# epoch:  87 val_loss: 0.17761014
# epoch:  87 val_accuracy: 0.97514998
# epoch:  88 train_loss: 0.04640015
# epoch:  88 train_accuracy: 0.98502725
# epoch:  88 val_loss: 0.19598242
# epoch:  88 val_accuracy: 0.97615454
# epoch:  89 train_loss: 0.04445437
# epoch:  89 train_accuracy: 0.98596093
# epoch:  89 val_loss: 0.21893328
# epoch:  89 val_accuracy: 0.96998095
# epoch:  90 train_loss: 0.04368447
# epoch:  90 train_accuracy: 0.98579545
# epoch:  90 val_loss: 0.21014552
# epoch:  90 val_accuracy: 0.97261262
# epoch:  91 train_loss: 0.04446173
# epoch:  91 train_accuracy: 0.98553576
# epoch:  91 val_loss: 0.20832332
# epoch:  91 val_accuracy: 0.97305124
# epoch:  92 train_loss: 0.04674627
# epoch:  92 train_accuracy: 0.98505261
# epoch:  92 val_loss: 0.18459337
# epoch:  92 val_accuracy: 0.96983946
# epoch:  93 train_loss: 0.04748487
# epoch:  93 train_accuracy: 0.98466489
# epoch:  93 val_loss: 0.17829551
# epoch:  93 val_accuracy: 0.97351815
# epoch:  94 train_loss: 0.05056889
# epoch:  94 train_accuracy: 0.98391118
# epoch:  94 val_loss: 0.15497167
# epoch:  94 val_accuracy: 0.96932538
# epoch:  95 train_loss: 0.04562369
# epoch:  95 train_accuracy: 0.98523621
# epoch:  95 val_loss: 0.13727017
# epoch:  95 val_accuracy: 0.97342854
# epoch:  96 train_loss: 0.04659953
# epoch:  96 train_accuracy: 0.98516012
# epoch:  96 val_loss: 0.17607097
# epoch:  96 val_accuracy: 0.96946216
# epoch:  97 train_loss: 0.04391455
# epoch:  97 train_accuracy: 0.98591383
# epoch:  97 val_loss: 0.20161737
# epoch:  97 val_accuracy: 0.97326819
# epoch:  98 train_loss: 0.04246702
# epoch:  98 train_accuracy: 0.98598992
# epoch:  98 val_loss: 0.19749938
# epoch:  98 val_accuracy: 0.97073555
# epoch:  99 train_loss: 0.04927439
# epoch:  99 train_accuracy: 0.98412376
# epoch:  99 val_loss: 0.15344006
# epoch:  99 val_accuracy: 0.97155146

# %%
import matplotlib.pyplot as plt

print('训练过程的损失随epoch变化趋势：')
plt.plot(train_loss_record, label='train_loss')
plt.plot(val_loss_record, label='val_loss')
plt.legend()
plt.show()

print('训练过程的准确率随epoch变化趋势：')
plt.plot(train_accuracy_record, label='train_accuracy')
plt.plot(val_accuracy_record, label='val_accuracy')
plt.legend()
plt.show()
# Out:
# 训练过程的损失随epoch变化趋势：
# 训练过程的准确率随epoch变化趋势：

# %% [markdown]
# ## 6. 验证模型，绘制结果

# %%
epoch_loss = 0
epoch_acc = 0
predicted_labels = []  # 模型结果标签，用于混淆矩阵
true_labels = []  # 模型真值标签，用于混淆矩阵

model.eval()
with torch.no_grad():
    for seq, labels in test_data:
        x,y = seq.to(device), labels.to(device)
        y_pred = model(x)
        y_pred = torch.squeeze(y_pred, dim=1) # 去除额外维度
        single_loss = loss_function(y_pred, y)
        
        # 获取预测正确的样本个数，由于pred为最大值所在位置的索引，
        # 因此不需要将label_test转换为one_hot编码
        # 当tensor为标量的时候，tensor.item()可以将其转换为ndarray类型
        # correct = pred.eq(label_test).sum().float().item()
        correct = torch.eq(y.argmax(dim=1), y_pred.argmax(dim=1))
        predicted_labels += y_pred.argmax(dim=1).tolist()
        true_labels += y.argmax(dim=1).tolist()
        
        epoch_acc += correct.sum().item()/ y.shape[0]
        epoch_loss += single_loss.item()

# 去平均
epoch_loss /= len(test_data)
epoch_acc /= len(test_data)

print(f'测试集平均损失：{epoch_loss}, \n测试集平均准确率：{epoch_acc}')
# Out:
# 测试集平均损失：0.1531393160920648,
# 测试集平均准确率：0.9715090175067914

# %% [markdown]
# ### 修改结果储存路径，并存储结果

# %%
# 绘制混淆矩阵
# 混淆矩阵
from sklearn.metrics import confusion_matrix
# 初始化混淆矩阵
num_classes = 5
conf_matrix = np.zeros((num_classes, num_classes), dtype=int)
# 更新混淆矩阵
conf_matrix += confusion_matrix(true_labels, predicted_labels, labels=range(num_classes))
# 打印混淆矩阵
print("Confusion Matrix:")
print(conf_matrix)

plt.figure(figsize=(12, 9))
# 设置颜色映射
cmap = plt.cm.Blues
# 绘制混淆矩阵图
plt.imshow(conf_matrix, interpolation='nearest', cmap=cmap)
# 添加文字标签
for i in range(len(conf_matrix)):
    for j in range(len(conf_matrix)):
        plt.text(j, i, conf_matrix[i, j], ha='center', va='center', color='black')
# 添加颜色条
plt.colorbar()
# 添加标题和标签
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
# 显示图形
plt.show()
# Out:
# Confusion Matrix:
# [[ 2885     0     0   318     0]
#  [    0 23128   980     3    25]
#  [   25  1489 81243   371    26]
#  [  130    14  1294 62337     0]
#  [    1   113   350   902 36363]]

# %%
# 绘制百分比混淆矩阵
from sklearn.metrics import confusion_matrix

num_classes = 5
conf_matrix = np.zeros((num_classes, num_classes), dtype=int)
conf_matrix += confusion_matrix(true_labels, predicted_labels, labels=range(num_classes))

# 转换为百分比混淆矩阵
conf_matrix_percentage = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis] * 100

# 打印混淆矩阵
print("Confusion Matrix (Percentage):")
print(conf_matrix_percentage)

# 绘制百分比混淆矩阵
plt.figure(figsize=(16, 12))
cmap = plt.cm.Blues
plt.imshow(conf_matrix_percentage, interpolation='nearest', cmap=cmap)

# 添加文字标签
for i in range(num_classes):
    for j in range(num_classes):
        plt.text(j, i, f'{conf_matrix_percentage[i, j]:.1f}%', ha='center', va='center', color='black')

# 添加颜色条
plt.colorbar()

# 添加标题和标签
plt.title('Confusion Matrix (Percentage)')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')

# 显示图形
plt.show()
# Out:
# Confusion Matrix (Percentage):
# [[9.00718077e+01 0.00000000e+00 0.00000000e+00 9.92819232e+00
#   0.00000000e+00]
#  [0.00000000e+00 9.58236659e+01 4.06032483e+00 1.24295658e-02
#   1.03579715e-01]
#  [3.00646992e-02 1.79065349e+00 9.77018544e+01 4.46160137e-01
#   3.12672872e-02]
#  [2.03841631e-01 2.19521756e-02 2.02900823e+00 9.77451980e+01
#   0.00000000e+00]
#  [2.65048106e-03 2.99504360e-01 9.27668372e-01 2.39073392e+00
#   9.63794429e+01]]

# %%
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# 计算总体的准确率、精确率、召回率、F1分数
def calculate_metrics_overall_by_sklearn(matrix):
    # 提取真实标签和预测标签
    true_labels = []
    pred_labels = []

    num_classes = matrix.shape[0]

    for i in range(num_classes):
        for j in range(num_classes):
            true_labels.extend([i] * matrix[i, j])
            pred_labels.extend([j] * matrix[i, j])

    # 计算总体的准确率、精确率、召回率和F1分数
    overall_accuracy = accuracy_score(true_labels, pred_labels)
    overall_precision = precision_score(true_labels, pred_labels, average='macro')
    overall_recall = recall_score(true_labels, pred_labels, average='macro')
    overall_f1 = f1_score(true_labels, pred_labels, average='macro')

    return overall_precision, overall_recall, overall_f1, overall_accuracy

real_overall_precision, real_overall_recall, real_overall_f1_score, real_overall_accuracy = calculate_metrics_overall_by_sklearn(conf_matrix)
print("总体精确率（Precision）: ", real_overall_precision)
print("总体召回率（Recall）: ", real_overall_recall)
print("总体F1 分数（F1 Score）: ", real_overall_f1_score)
print("总体准确率（Accuracy）: ", real_overall_accuracy)
# Out:
# 总体精确率（Precision）:  0.965154199640288
# 总体召回率（Recall）:  0.9554439375893684
# 总体F1 分数（F1 Score）:  0.9600797225240265
# 总体准确率（Accuracy）:  0.9715043137402888
